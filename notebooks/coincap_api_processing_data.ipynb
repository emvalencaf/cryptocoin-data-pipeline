# %% [markdown]
# # Processing Data fetched from CoinCap API

# %% [markdown]
# In this `notebook` we will use `apache/spark` to deal with data fetched from [CoinCap API](https://docs.coincap.io/)

# %%
import requests
from datetime import datetime
import re

# %% [markdown]
# ## Setup PySpark

# %% [markdown]
# First of all we need to setup `PySpark`

# %%
# !apt-get update -qq

# !apt-get install openjdk-8-jdk-headless -qq > /dev/null

# !wget -q https://archive.apache.org/dist/spark/spark-3.1.2/spark-3.1.2-bin-hadoop2.7.tgz

# !tar xf spark-3.1.2-bin-hadoop2.7.tgz

# !pip install -q findspark

import os

os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"

os.environ["SPARK_HOME"] = "/content/spark-3.1.2-bin-hadoop2.7"

import findspark

findspark.init()

from pyspark.sql import SparkSession

spark = SparkSession.builder\
  .master('local[*]')\
  .appName("Iniciando com Spark")\
  .getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://95d61b6d0b35:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Iniciando com Spark</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ## Fetching data from CoinCap

# %% [markdown]
# functions to fetch data from CoinCap's API:

# %%
API_URL = "https://api.coincap.io/v2"

# %%
def getCryptoCurrencyRealTimeData(asset: str = ""):
  try:
    res = requests.get(API_URL + f'/assets/{asset}')

    if res.status_code == 200:
      return res.json()
    else:
      print(f'Error: {res.status_code}')
  except requests.exceptions.RequestException as err:
    print(f'Error: {err}')

# %%
def getCryptoCurrencyDataRates(asset: str = ""):
  try:
    res = requests.get(API_URL + f'/rates/{asset}')
    print(res)
    if res.status_code == 200:
      return res.json()
    else:
      print(f'Error: {res.status_code}')
  except requests.exceptions.RequestException as err:
    print(f'Error: {err}')

# %%
json_assets = getCryptoCurrencyRealTimeData()

# %%
data_assets = json_assets['data']

for i,register in enumerate(data_assets):
  register['timestamp'] = json_assets['timestamp']
  data_assets[i] = register

print(data_assets)
# Out:
# [{'id': 'bitcoin', 'rank': '1', 'symbol': 'BTC', 'name': 'Bitcoin', 'supply': '19672556.0000000000000000', 'maxSupply': '21000000.0000000000000000', 'marketCapUsd': '1287527683208.3377486213377160', 'volumeUsd24Hr': '9128967839.9910500037656694', 'priceUsd': '65447.9104397180391110', 'changePercent24Hr': '-1.2472524950286412', 'vwap24Hr': '66196.8854766610679226', 'explorer': 'https://blockchain.info/', 'timestamp': 1712204418514}, {'id': 'ethereum', 'rank': '2', 'symbol': 'ETH', 'name': 'Ethereum', 'supply': '120069288.4506371900000000', 'maxSupply': None, 'marketCapUsd': '392055139115.6319969789802531', 'volumeUsd24Hr': '5961011343.9732881373458441', 'priceUsd': '3265.2407969987550817', 'changePercent24Hr': '-1.5500001114446777', 'vwap24Hr': '3323.1744263414114457', 'explorer': 'https://etherscan.io/', 'timestamp': 1712204418514}, {'id': 'tether', 'rank': '3', 'symbol': 'USDT', 'name': 'Tether', 'supply': '106149786847.0736100000000000', 'maxSupply': None, 'marketCapUsd': '106248583747.4410387572134720', 'volumeUsd24Hr': '20918434581.7752009239091818', 'priceUsd': '1.0009307310292555', 'changePercent24Hr': '-0.0542370947432367', 'vwap24Hr': '1.0011168533403610', 'explorer': 'https://www.omniexplorer.info/asset/31', 'timestamp': 1712204418514}, {'id': 'binance-coin', 'rank': '4', 'symbol': 'BNB', 'name': 'BNB', 'supply': '166801148.0000000000000000', 'maxSupply': '166801148.0000000000000000', 'marketCapUsd': '96031406438.8554716276281396', 'volumeUsd24Hr': '635961667.9616051277987003', 'priceUsd': '575.7238939318059827', 'changePercent24Hr': '3.0516055784743504', 'vwap24Hr': '563.9876177804584883', 'explorer': 'https://etherscan.io/token/0xB8c77482e45F1F44dE1745F52C74426C631bDD52', 'timestamp': 1712204418514}, {'id': 'solana', 'rank': '5', 'symbol': 'SOL', 'name': 'Solana', 'supply': '444814259.0549971500000000', 'maxSupply': None, 'marketCapUsd': '80518326399.1206948554739795', 'volumeUsd24Hr': '1118161212.2628943007749581', 'priceUsd': '181.0156144053946615', 'changePercent24Hr': '-3.4302642204895921', 'vwap24Hr': '187.8447800915203446', 'explorer': 'https://explorer.solana.com/', 'timestamp': 1712204418514}, {'id': 'usd-coin', 'rank': '6', 'symbol': 'USDC', 'name': 'USDC', 'supply': '32873084251.4569400000000000', 'maxSupply': None, 'marketCapUsd': '32889636542.2281344353508414', 'volumeUsd24Hr': '1917088233.7527846897979021', 'priceUsd': '1.0005035210765312', 'changePercent24Hr': '-0.0593153914916286', 'vwap24Hr': '1.0005437259766494', 'explorer': 'https://etherscan.io/token/0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48', 'timestamp': 1712204418514}, {'id': 'xrp', 'rank': '7', 'symbol': 'XRP', 'name': 'XRP', 'supply': '45404028640.0000000000000000', 'maxSupply': '100000000000.0000000000000000', 'marketCapUsd': '25648660272.9768663946024320', 'volumeUsd24Hr': '526920985.3875760451385797', 'priceUsd': '0.5648983370251188', 'changePercent24Hr': '-3.4795299736998682', 'vwap24Hr': '0.5814336816602908', 'explorer': 'https://xrpcharts.ripple.com/#/graph/', 'timestamp': 1712204418514}, {'id': 'dogecoin', 'rank': '8', 'symbol': 'DOGE', 'name': 'Dogecoin', 'supply': '143741036383.7053000000000000', 'maxSupply': None, 'marketCapUsd': '24856144527.3658222212924335', 'volumeUsd24Hr': '1091916708.9791864776437292', 'priceUsd': '0.1729230924773237', 'changePercent24Hr': '-6.8427118251859948', 'vwap24Hr': '0.1798329362503708', 'explorer': 'http://dogechain.info/chain/Dogecoin', 'timestamp': 1712204418514}, {'id': 'cardano', 'rank': '9', 'symbol': 'ADA', 'name': 'Cardano', 'supply': '35597279591.3190000000000000', 'maxSupply': '45000000000.0000000000000000', 'marketCapUsd': '20062179747.8242636983705338', 'volumeUsd24Hr': '192253375.1784538700811823', 'priceUsd': '0.5635874420223046', 'changePercent24Hr': '-4.0834634566650883', 'vwap24Hr': '0.5816131694467827', 'explorer': 'https://cardanoexplorer.com/', 'timestamp': 1712204418514}, {'id': 'avalanche', 'rank': '10', 'symbol': 'AVAX', 'name': 'Avalanche', 'supply': '377709834.5777809000000000 ...

# %% [markdown]
# ### Loading Data

# %% [markdown]
# Loading data in a local `/Raw` zone

# %%
import json

# %%
objects_uploaded = []

# %%
def dataExtracted(dataset: list[dict[str,any]]):
  print(dataset)
  return [{**data,
           "timestamp":dataset["timestamp"]} for data in dataset["data"]]

# %%
def _loadingBatch(batch_data:list[dict[str, any]],
                  endpoint: str,
                  batch_name:str):
  current_date = datetime.now()

  month = str(current_date.month).zfill(2)
  day = str(current_date.day).zfill(2)

  object_key=f"{endpoint.capitalize()}/{current_date.year}/{month}/{day}"

  directory = f"/content/dataset/Raw/JSON/{object_key}"
  os.makedirs(directory, exist_ok=True)
  filename = f"{current_date.timestamp()}-{batch_name}.json"
  filepath = f"{directory}/{filename}"

  with open(filepath, "w") as file:
    json.dump(batch_data, file, indent=2)

  objects_uploaded.append(f"{object_key}/{filename}")

def loadingData():
  assets = dataExtracted(dataset=getCryptoCurrencyRealTimeData())
  rates = dataExtracted(dataset=getCryptoCurrencyDataRates())

  batches_assets = [assets[i:i + 100] for i in range(1,len(assets), 100)]
  batches_rates = [rates[i:i + 100] for i in range(1,len(rates), 100)]


  for i, data in enumerate(batches_assets):
    _loadingBatch(batch_data=data,
                  batch_name=f"batch_{i}",
                  endpoint="assets")

  for i, data in enumerate(batches_rates):
    _loadingBatch(batch_data=data, batch_name=f"batch_{i}",endpoint="rates")

loadingData()
# Out:
# {'data': [{'id': 'bitcoin', 'rank': '1', 'symbol': 'BTC', 'name': 'Bitcoin', 'supply': '19672556.0000000000000000', 'maxSupply': '21000000.0000000000000000', 'marketCapUsd': '1287527683208.3377486213377160', 'volumeUsd24Hr': '9128967839.9910500037656694', 'priceUsd': '65447.9104397180391110', 'changePercent24Hr': '-1.2472524950286412', 'vwap24Hr': '66196.8854766610679226', 'explorer': 'https://blockchain.info/'}, {'id': 'ethereum', 'rank': '2', 'symbol': 'ETH', 'name': 'Ethereum', 'supply': '120069288.4506371900000000', 'maxSupply': None, 'marketCapUsd': '392055139115.6319969789802531', 'volumeUsd24Hr': '5961011343.9732881373458441', 'priceUsd': '3265.2407969987550817', 'changePercent24Hr': '-1.5500001114446777', 'vwap24Hr': '3323.1744263414114457', 'explorer': 'https://etherscan.io/'}, {'id': 'tether', 'rank': '3', 'symbol': 'USDT', 'name': 'Tether', 'supply': '106149786847.0736100000000000', 'maxSupply': None, 'marketCapUsd': '106248583747.4410387572134720', 'volumeUsd24Hr': '20918434581.7752009239091818', 'priceUsd': '1.0009307310292555', 'changePercent24Hr': '-0.0542370947432367', 'vwap24Hr': '1.0011168533403610', 'explorer': 'https://www.omniexplorer.info/asset/31'}, {'id': 'binance-coin', 'rank': '4', 'symbol': 'BNB', 'name': 'BNB', 'supply': '166801148.0000000000000000', 'maxSupply': '166801148.0000000000000000', 'marketCapUsd': '96031406438.8554716276281396', 'volumeUsd24Hr': '635961667.9616051277987003', 'priceUsd': '575.7238939318059827', 'changePercent24Hr': '3.0516055784743504', 'vwap24Hr': '563.9876177804584883', 'explorer': 'https://etherscan.io/token/0xB8c77482e45F1F44dE1745F52C74426C631bDD52'}, {'id': 'solana', 'rank': '5', 'symbol': 'SOL', 'name': 'Solana', 'supply': '444814259.0549971500000000', 'maxSupply': None, 'marketCapUsd': '80518326399.1206948554739795', 'volumeUsd24Hr': '1118161212.2628943007749581', 'priceUsd': '181.0156144053946615', 'changePercent24Hr': '-3.4302642204895921', 'vwap24Hr': '187.8447800915203446', 'explorer': 'https://explorer.solana.com/'}, {'id': 'usd-coin', 'rank': '6', 'symbol': 'USDC', 'name': 'USDC', 'supply': '32873084251.4569400000000000', 'maxSupply': None, 'marketCapUsd': '32889636542.2281344353508414', 'volumeUsd24Hr': '1917088233.7527846897979021', 'priceUsd': '1.0005035210765312', 'changePercent24Hr': '-0.0593153914916286', 'vwap24Hr': '1.0005437259766494', 'explorer': 'https://etherscan.io/token/0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48'}, {'id': 'xrp', 'rank': '7', 'symbol': 'XRP', 'name': 'XRP', 'supply': '45404028640.0000000000000000', 'maxSupply': '100000000000.0000000000000000', 'marketCapUsd': '25648660272.9768663946024320', 'volumeUsd24Hr': '526920985.3875760451385797', 'priceUsd': '0.5648983370251188', 'changePercent24Hr': '-3.4795299736998682', 'vwap24Hr': '0.5814336816602908', 'explorer': 'https://xrpcharts.ripple.com/#/graph/'}, {'id': 'dogecoin', 'rank': '8', 'symbol': 'DOGE', 'name': 'Dogecoin', 'supply': '143741036383.7053000000000000', 'maxSupply': None, 'marketCapUsd': '24856144527.3658222212924335', 'volumeUsd24Hr': '1091916708.9791864776437292', 'priceUsd': '0.1729230924773237', 'changePercent24Hr': '-6.8427118251859948', 'vwap24Hr': '0.1798329362503708', 'explorer': 'http://dogechain.info/chain/Dogecoin'}, {'id': 'cardano', 'rank': '9', 'symbol': 'ADA', 'name': 'Cardano', 'supply': '35597279591.3190000000000000', 'maxSupply': '45000000000.0000000000000000', 'marketCapUsd': '20062179747.8242636983705338', 'volumeUsd24Hr': '192253375.1784538700811823', 'priceUsd': '0.5635874420223046', 'changePercent24Hr': '-4.0834634566650883', 'vwap24Hr': '0.5816131694467827', 'explorer': 'https://cardanoexplorer.com/'}, {'id': 'avalanche', 'rank': '10', 'symbol': 'AVAX', 'name': 'Avalanche', 'supply': '377709834.5777809000000000', 'maxSupply': '715748719.0000000000000000', 'marketCapUsd': '17251745524.1393631928945924', 'volumeUsd24Hr': '188909196.9466287795178680', 'priceUsd': '45.6745997716052366', 'changePercent24Hr': '-4.0586224484431319', 'vwap24Hr': '46.7748401 ...
# <Response [200]>
# {'data': [{'id': 'british-pound-sterling', 'symbol': 'GBP', 'currencySymbol': '£', 'type': 'fiat', 'rateUsd': '1.2653006480869920'}, {'id': 'argentine-peso', 'symbol': 'ARS', 'currencySymbol': '$', 'type': 'fiat', 'rateUsd': '0.0011661671584005'}, {'id': 'binance-coin', 'symbol': 'BNB', 'currencySymbol': None, 'type': 'crypto', 'rateUsd': '576.3704085034755740'}, {'id': 'dogecoin', 'symbol': 'DOGE', 'currencySymbol': None, 'type': 'crypto', 'rateUsd': '0.1729080419634195'}, {'id': 'australian-dollar', 'symbol': 'AUD', 'currencySymbol': '$', 'type': 'fiat', 'rateUsd': '0.6581172843974871'}, {'id': 'norwegian-krone', 'symbol': 'NOK', 'currencySymbol': 'kr', 'type': 'fiat', 'rateUsd': '0.0934400418611388'}, {'id': 'sri-lankan-rupee', 'symbol': 'LKR', 'currencySymbol': '₨', 'type': 'fiat', 'rateUsd': '0.0033387981668796'}, {'id': 'afghan-afghani', 'symbol': 'AFN', 'currencySymbol': '؋ ', 'type': 'fiat', 'rateUsd': '0.0141399973708089'}, {'id': 'ghanaian-cedi', 'symbol': 'GHS', 'currencySymbol': '¢', 'type': 'fiat', 'rateUsd': '0.0753778256979742'}, {'id': 'bitcoin', 'symbol': 'BTC', 'currencySymbol': '₿', 'type': 'crypto', 'rateUsd': '65419.9176204681074996'}, {'id': 'yemeni-rial', 'symbol': 'YER', 'currencySymbol': '﷼', 'type': 'fiat', 'rateUsd': '0.0039940098160300'}, {'id': 'jordanian-dinar', 'symbol': 'JOD', 'currencySymbol': None, 'type': 'fiat', 'rateUsd': '1.4106361969248131'}, {'id': 'congolese-franc', 'symbol': 'CDF', 'currencySymbol': None, 'type': 'fiat', 'rateUsd': '0.0003547253851467'}, {'id': 'turkmenistani-manat', 'symbol': 'TMT', 'currencySymbol': None, 'type': 'fiat', 'rateUsd': '0.2853067047075606'}, {'id': 'dominican-peso', 'symbol': 'DOP', 'currencySymbol': 'RD$', 'type': 'fiat', 'rateUsd': '0.0169108900771345'}, {'id': 'omani-rial', 'symbol': 'OMR', 'currencySymbol': '﷼', 'type': 'fiat', 'rateUsd': '2.5977534628053660'}, {'id': 'netherlands-antillean-guilder', 'symbol': 'ANG', 'currencySymbol': 'ƒ', 'type': 'fiat', 'rateUsd': '0.5552344449682156'}, {'id': 'eos', 'symbol': 'EOS', 'currencySymbol': None, 'type': 'crypto', 'rateUsd': '0.9463932695785425'}, {'id': 'colombian-peso', 'symbol': 'COP', 'currencySymbol': '$', 'type': 'fiat', 'rateUsd': '0.0002638209486373'}, {'id': 'zcash', 'symbol': 'ZEC', 'currencySymbol': None, 'type': 'crypto', 'rateUsd': '27.2945379096806833'}, {'id': 'armenian-dram', 'symbol': 'AMD', 'currencySymbol': '֏', 'type': 'fiat', 'rateUsd': '0.0025903259077600'}, {'id': 'pakistani-rupee', 'symbol': 'PKR', 'currencySymbol': '₨', 'type': 'fiat', 'rateUsd': '0.0035994343560898'}, {'id': 'salvadoran-colón', 'symbol': 'SVC', 'currencySymbol': '$', 'type': 'fiat', 'rateUsd': '0.1143562492202333'}, {'id': 'fijian-dollar', 'symbol': 'FJD', 'currencySymbol': '$', 'type': 'fiat', 'rateUsd': '0.4451864218141347'}, {'id': 'ethiopian-birr', 'symbol': 'ETB', 'currencySymbol': 'Br', 'type': 'fiat', 'rateUsd': '0.0175824175824176'}, {'id': 'chilean-unit-of-account-(uf)', 'symbol': 'CLF', 'currencySymbol': None, 'type': 'fiat', 'rateUsd': '28.8967231115991470'}, {'id': 'qatari-rial', 'symbol': 'QAR', 'currencySymbol': '﷼', 'type': 'fiat', 'rateUsd': '0.2746045694200351'}, {'id': 'burundian-franc', 'symbol': 'BIF', 'currencySymbol': None, 'type': 'fiat', 'rateUsd': '0.0003495703196814'}, {'id': 'cambodian-riel', 'symbol': 'KHR', 'currencySymbol': '៛', 'type': 'fiat', 'rateUsd': '0.0002490076670955'}, {'id': 'thorchain', 'symbol': 'RUNE', 'currencySymbol': None, 'type': 'crypto', 'rateUsd': '7.1996244459165128'}, {'id': 'euro', 'symbol': 'EUR', 'currencySymbol': '€', 'type': 'fiat', 'rateUsd': '1.0842917568887767'}, {'id': 'honduran-lempira', 'symbol': 'HNL', 'currencySymbol': 'L', 'type': 'fiat', 'rateUsd': '0.0406151291274770'}, {'id': 'iraqi-dinar', 'symbol': 'IQD', 'currencySymbol': 'د.ع', 'type': 'fiat', 'rateUsd': '0.0007633587786260'}, {'id': 'kyrgystani-som', 'symbol': 'KGS', 'currencySymbol': 'лв', 'type': 'fiat', 'rateUsd': '0.0111919418019026'}, {'id': 'saint-helena-pound', 'symbol': 'SHP', 'cur ...

# %% [markdown]
# ## Glueing Data

# %%
from pyspark.sql.functions import col, substring
from pyspark.sql.types import DecimalType, StructType, StructField, StringType, LongType
from pyspark.sql import DataFrame

# %% [markdown]
# ### Treating data

# %%
TREATING_ENDPOINTS="assets,rates"
TREATING_INPUT_ZONE="Raw"
TREATING_TARGET_ZONE="Trusted"
TREATING_OBJECTS_KEY=','.join(objects_uploaded)

# %%
# utils functions
def getS3Path(prefix: str,
              endpoint: str,
              subdir:str = "",
              typeFile: str = "",
              filename:str = ""):

    endpoint = endpoint.lower().capitalize()

    filename = f'{subdir}/{filename}.{typeFile.lower()}' if subdir and typeFile and filename else ""

    return f"{prefix}/{endpoint}/{filename}"

def getTimestampFromKeyObject(object_key: str):

    timestamp_prefix = object_key.split("/")[-1].split("-")[0]

    return timestamp_prefix

def getDateSubDirFromKeyObject(object_key: str):
    regex_pattern_extract_subdir = r'(\d{4}/\d{2}/\d{2})'
    match = re.search(regex_pattern_extract_subdir, object_key)
    if match:
        return match.group()
    else:
        raise ValueError("No date subdirectory found in object key: {}".format(object_key))


# ETL functions
def extractData(prefix: str,
                endpoint: str,
                subdir: str = "",
                filename: str = "",
                typeFile: str = ""):

    objects_key = getS3Path(prefix=prefix,
                            endpoint=endpoint,
                            subdir=subdir,
                            filename=filename,
                            typeFile=typeFile)

    return spark.read.option("multiline","true").json(objects_key)


def transformData(endpoint: str,
                  df: DataFrame) -> DataFrame:
    if endpoint.lower() == "assets":
        cols_name = df.columns

        for col_name in cols_name:
            if col_name == 'marketCapUsd' or col_name == 'maxSupply' or col_name == 'priceUsd' or col_name == 'supply' or col_name == 'volumeUsd24Hr' or col_name == 'vwap24Hr':
                df = df.withColumn(col_name, col(col_name).cast(DecimalType(38, 18)))

        return df
    if endpoint.lower() == "rates":
        df = df.withColumn("rateUsd", col("rateUsd").cast(DecimalType(38, 18)))

        return df

    raise Exception("Invalid endpoint")

def loadData(prefix: str,
             endpoint: str,
             subdir_date: str,
             object_key: str,
             df: DataFrame) -> DataFrame:

    path = getS3Path(prefix=prefix,
                     endpoint=endpoint)
    print(path)
    df.show()
    df.write.parquet(f'{path}/{subdir_date}/{getTimestampFromKeyObject(object_key=object_key)}',
                     mode="overwrite")


def execute_job():
    extract_prefix = f"/content/dataset/{TREATING_INPUT_ZONE}/JSON"

    load_prefix = f"/content/dataset/{TREATING_TARGET_ZONE}"

    print(f"[GLUE_JOB_SYSTEM] - Starting to processing data from {extract_prefix} to store into {load_prefix}...")
    print(TREATING_OBJECTS_KEY)
    objects_key = TREATING_OBJECTS_KEY.split(",")
    print(objects_key)
    for endpoint in TREATING_ENDPOINTS.split(","):
        _objects_key = list(filter(lambda object_key: endpoint.lower().capitalize() in object_key,
                              objects_key))
        print(_objects_key)
        _str_objects_key = ", ".join(map(str, _objects_key))

        print(f"[GLUE_JOB_SYSTEM] - Starting processing data stores in {endpoint}...")
        print("[GLUE_JOB_SYSTEM] - The following files will be processed: {}".format(_str_objects_key))

        for object_key in _objects_key:
            print(f"[GLUE_JOB_SYSTEM] -  Starting extracting the data from {endpoint}...")

            subdir= getDateSubDirFromKeyObject(object_key=object_key)
            print(subdir)
            filename = f'{getTimestampFromKeyObject(object_key=object_key)}-*'
            print(f"{extract_prefix}/{endpoint.capitalize()}/{subdir}/{filename}")
            df = extractData(prefix=extract_prefix,
                             endpoint=endpoint,
                             subdir=subdir,
                             filename=filename,
                             typeFile="json")

            print(f"[GLUE_JOB_SYSTEM] - The data extracted has the following scheme:")
            df.printSchema()

            print(f"[GLUE_JOB_SYSTEM] - Starting transforming the data from {endpoint}...")

            df = transformData(endpoint=endpoint,
                               df=df)

            print(f"[GLUE_JOB_SYSTEM] - The data transformed has the following scheme:")
            df.printSchema()

            print(f"[GLUE_JOB_SYSTEM] - Starting to load the transformed data into {load_prefix}...")

            loadData(prefix=load_prefix,
                     endpoint=endpoint,
                     subdir_date=subdir,
                     object_key=object_key,
                     df=df)

            print(f"[GLUE_JOB_SYSTEM] - The data was succefully loaded into {load_prefix}")

execute_job()
# Out:
# [GLUE_JOB_SYSTEM] - Starting to processing data from /content/dataset/Raw/JSON to store into /content/dataset/Trusted...
# Assets/2024/04/04/1712204419.123182-batch_0.json,Rates/2024/04/04/1712204419.126377-batch_0.json,Rates/2024/04/04/1712204419.127783-batch_1.json
# ['Assets/2024/04/04/1712204419.123182-batch_0.json', 'Rates/2024/04/04/1712204419.126377-batch_0.json', 'Rates/2024/04/04/1712204419.127783-batch_1.json']
# ['Assets/2024/04/04/1712204419.123182-batch_0.json']
# [GLUE_JOB_SYSTEM] - Starting processing data stores in assets...
# [GLUE_JOB_SYSTEM] - The following files will be processed: Assets/2024/04/04/1712204419.123182-batch_0.json
# [GLUE_JOB_SYSTEM] -  Starting extracting the data from assets...
# 2024/04/04
# /content/dataset/Raw/JSON/Assets/2024/04/04/1712204419.123182-*
# [GLUE_JOB_SYSTEM] - The data extracted has the following scheme:
# root
#  |-- changePercent24Hr: string (nullable = true)
#  |-- explorer: string (nullable = true)
#  |-- id: string (nullable = true)
#  |-- marketCapUsd: string (nullable = true)
#  |-- maxSupply: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- priceUsd: string (nullable = true)
#  |-- rank: string (nullable = true)
#  |-- supply: string (nullable = true)
#  |-- symbol: string (nullable = true)
#  |-- timestamp: long (nullable = true)
#  |-- volumeUsd24Hr: string (nullable = true)
#  |-- vwap24Hr: string (nullable = true)
#
# [GLUE_JOB_SYSTEM] - Starting transforming the data from assets...
# [GLUE_JOB_SYSTEM] - The data transformed has the following scheme:
# root
#  |-- changePercent24Hr: string (nullable = true)
#  |-- explorer: string (nullable = true)
#  |-- id: string (nullable = true)
#  |-- marketCapUsd: decimal(38,18) (nullable = true)
#  |-- maxSupply: decimal(38,18) (nullable = true)
#  |-- name: string (nullable = true)
#  |-- priceUsd: decimal(38,18) (nullable = true)
#  |-- rank: string (nullable = true)
#  |-- supply: decimal(38,18) (nullable = true)
#  |-- symbol: string (nullable = true)
#  |-- timestamp: long (nullable = true)
#  |-- volumeUsd24Hr: decimal(38,18) (nullable = true)
#  |-- vwap24Hr: decimal(38,18) (nullable = true)
#
# [GLUE_JOB_SYSTEM] - Starting to load the transformed data into /content/dataset/Trusted...
# /content/dataset/Trusted/Assets/
# +-------------------+--------------------+-----------------+--------------------+--------------------+-----------------+--------------------+----+--------------------+------+-------------+--------------------+--------------------+
# |  changePercent24Hr|            explorer|               id|        marketCapUsd|           maxSupply|             name|            priceUsd|rank|              supply|symbol|    timestamp|       volumeUsd24Hr|            vwap24Hr|
# +-------------------+--------------------+-----------------+--------------------+--------------------+-----------------+--------------------+----+--------------------+------+-------------+--------------------+--------------------+
# |-1.5500001114446777|https://etherscan...|         ethereum|392055139115.6319...|                null|         Ethereum|3265.240796998755...|   2|120069288.4506371...|   ETH|1712204418804|5961011343.973288...|3323.174426341411...|
# |-0.0542370947432367|https://www.omnie...|           tether|106248583747.4410...|                null|           Tether|1.000930731029255500|   3|106149786847.0736...|  USDT|1712204418804|20918434581.77520...|1.001116853340361000|
# | 3.0516055784743504|https://etherscan...|     binance-coin|96031406438.85547...|166801148.0000000...|              BNB|575.7238939318059...|   4|166801148.0000000...|   BNB|1712204418804|635961667.9616051...|563.9876177804584...|
# |-3.4302642204895921|https://explorer....|           solana|80518326399.12069...|                null|           Solana|181.0156144053946...|   5|444814259.0549971...|   SOL|1712204418804|1118161212.262894...|187.8447800915203...|
# |-0.0593153914916286|https://etherscan...|         usd-coin|32889636542.22813...|                null|             USDC|1.000503521076531200|   6|32873084251.45694...|  USDC|1712204418804|1917088233.752784...|1.000543725976649400|
# |-3.4795299736998682|https://xrpcharts...|              xrp|25648660272.97686...|100000000000.0000...|              XRP|0.564898337025118800|   7|45404028640.00000...|   XRP|1712204418804|526920985.3875760...|0.581433681660290800|
# |-6.8427118251859948|http://dogechain....|         dogecoin|24856144527.36582...|                null|         Dogecoin|0.172923092477323700|   8|143741036383.7053...|  DOGE|1712204418804|1091916708.979186...|0.179832936250370800|
# |-4.0834634566650883|https://cardanoex...|          cardano|20062179747.82426...|45000000000.00000...|          Cardano|0.563587442022304600|   9|35597279591.31900...|   ADA|1712204418804|192253375.1784538...|0.581613169446782700|
# |-4.0586224484431319|https://avascan.i...|        avalanche|17251745524.13936...|715748719.0000000...|        Avalanche|45.67459977160523...|  10|377709834.5777809...|  AVAX|1712204418804|188909196.9466287...|46.77484015292932...|
# |-4.4277286848057009|https://etherscan...|        shiba-inu|15316209835.14785...|                null|        Shiba Inu|0.000025990980924000|  11|589289410812691.0...|  SHIB|1712204418804|276578934.7233604...|0.000026795145554800|
# |-3.1422153287787486|https://blockchai...|     bitcoin-cash|12061821952.76627...|21000000.00000000...|     Bitcoin Cash|612.6634859631394...|  12|19687515.62500000...|   BCH|1712204418804|582521462.9833124...|600.0848221737396...|
# |-4.1064863724490711|https://polkascan...|         polkadot|11184330602.44886...|                null|         Polkadot|8.293239560267095600|  13|1348608167.070560...|   DOT|1712204418804|109347280.9488019...|8.598038579959527900|
# |-0.1533705822377922|https://tronscan....|             tron|10283539335.39688...|                null|             TRON|0.117247048797026300|  14|87708300045.99403...|   TRX|1712204418804|132560785.5997803...|0.117770572317276000|
# |-3.4164416631492508|https://etherscan...|        chainlink|10264277294.17176...|1000000000.000000...|        Chainlink|17.48301449624615...|  15|587099970.4527867...|  LINK|1712204418804|180620278.6562776...|17.90660727113310...|
# |-1.2282419716016693|https://etherscan...|  wrapped-bitcoin|10173955210.88728...|                null|  Wrapped Bitcoin|65461.96285907065...|  16|155417.8146596400...|  WBTC|1712204418804|71030063.18987485...|66268.73281942683...|
# |-3.5590116452796168|https://etherscan...|          polygon|8682195913.285101...|10000000000.00000...|          Polygon|0.876790725810953700|  17|9902244238.788954...| MATIC|1712204418804|101595364.2344776...|0.905476793069751600|
# |-0.4282686870523165|https://www.dfini...|internet-computer|8375580666.918358...|                null|Internet Computer|18.14410508444279...|  18|461614426.7208741...|   ICP|1712204418804|117581821.3734827...|18.23572141874460...|
# |-5.2180541951228828|http://explorer.l...|         litecoin|7258787555.734381...|84000000.00000000...|         Litecoin|97.58613050160707...|  19|74383393.60750493...|   LTC|1712204418804|457689549.1612071...|100.1278472992571...|
# |-0.5815965041883912|https://explorer....|    near-protocol|6696161915.605056...|                null|    NEAR Protocol|6.352996475831634100|  20|1054016312.000000...|  NEAR|1712204418804|189108801.3645544...|6.681045350075365900|
# |-2.1468938215969034|https://etherscan...|          uniswap|6445012634.584160...|1000000000.000000...|          Uniswap|10.76436214073502...|  21|598736139.7100000...|   UNI|1712204418804|93300759.09304664...|11.00912095437501...|
# +-------------------+--------------------+-----------------+--------------------+--------------------+-----------------+--------------------+----+--------------------+------+-------------+--------------------+--------------------+
# only showing top 20 rows
#
# [GLUE_JOB_SYSTEM] - The data was succefully loaded into /content/dataset/Trusted
# ['Rates/2024/04/04/1712204419.126377-batch_0.json', 'Rates/2024/04/04/1712204419.127783-batch_1.json']
# [GLUE_JOB_SYSTEM] - Starting processing data stores in rates...
# [GLUE_JOB_SYSTEM] - The following files will be processed: Rates/2024/04/04/1712204419.126377-batch_0.json, Rates/2024/04/04/1712204419.127783-batch_1.json
# [GLUE_JOB_SYSTEM] -  Starting extracting the data from rates...
# 2024/04/04
# /content/dataset/Raw/JSON/Rates/2024/04/04/1712204419.126377-*
# [GLUE_JOB_SYSTEM] - The data extracted has the following scheme:
# root
#  |-- currencySymbol: string (nullable = true)
#  |-- id: string (nullable = true)
#  |-- rateUsd: string (nullable = true)
#  |-- symbol: string (nullable = true)
#  |-- timestamp: long (nullable = true)
#  |-- type: string (nullable = true)
#
# [GLUE_JOB_SYSTEM] - Starting transforming the data from rates...
# [GLUE_JOB_SYSTEM] - The data transformed has the following scheme:
# root
#  |-- currencySymbol: string (nullable = true)
#  |-- id: string (nullable = true)
#  |-- rateUsd: decimal(38,18) (nullable = true)
#  |-- symbol: string (nullable = true)
#  |-- timestamp: long (nullable = true)
#  |-- type: string (nullable = true)
#
# [GLUE_JOB_SYSTEM] - Starting to load the transformed data into /content/dataset/Trusted...
# /content/dataset/Trusted/Rates/
# +--------------+--------------------+--------------------+------+-------------+------+
# |currencySymbol|                  id|             rateUsd|symbol|    timestamp|  type|
# +--------------+--------------------+--------------------+------+-------------+------+
# |             $|      argentine-peso|0.001166167158400500|   ARS|1712204419037|  fiat|
# |          null|        binance-coin|576.3704085034755...|   BNB|1712204419037|crypto|
# |          null|            dogecoin|0.172908041963419500|  DOGE|1712204419037|crypto|
# |             $|   australian-dollar|0.658117284397487100|   AUD|1712204419037|  fiat|
# |            kr|     norwegian-krone|0.093440041861138800|   NOK|1712204419037|  fiat|
# |             ₨|    sri-lankan-rupee|0.003338798166879600|   LKR|1712204419037|  fiat|
# |            ؋ |      afghan-afghani|0.014139997370808900|   AFN|1712204419037|  fiat|
# |             ¢|       ghanaian-cedi|0.075377825697974200|   GHS|1712204419037|  fiat|
# |             ₿|             bitcoin|65419.91762046810...|   BTC|1712204419037|crypto|
# |             ﷼|         yemeni-rial|0.003994009816030000|   YER|1712204419037|  fiat|
# |          null|     jordanian-dinar|1.410636196924813100|   JOD|1712204419037|  fiat|
# |          null|     congolese-franc|0.000354725385146700|   CDF|1712204419037|  fiat|
# |          null| turkmenistani-manat|0.285306704707560600|   TMT|1712204419037|  fiat|
# |           RD$|      dominican-peso|0.016910890077134500|   DOP|1712204419037|  fiat|
# |             ﷼|          omani-rial|2.597753462805366000|   OMR|1712204419037|  fiat|
# |             ƒ|netherlands-antil...|0.555234444968215600|   ANG|1712204419037|  fiat|
# |          null|                 eos|0.946393269578542500|   EOS|1712204419037|crypto|
# |             $|      colombian-peso|0.000263820948637300|   COP|1712204419037|  fiat|
# |          null|               zcash|27.29453790968068...|   ZEC|1712204419037|crypto|
# |             ֏|       armenian-dram|0.002590325907760000|   AMD|1712204419037|  fiat|
# +--------------+--------------------+--------------------+------+-------------+------+
# only showing top 20 rows
#
# [GLUE_JOB_SYSTEM] - The data was succefully loaded into /content/dataset/Trusted
# [GLUE_JOB_SYSTEM] -  Starting extracting the data from rates...
# 2024/04/04
# /content/dataset/Raw/JSON/Rates/2024/04/04/1712204419.127783-*
# [GLUE_JOB_SYSTEM] - The data extracted has the following scheme:
# root
#  |-- currencySymbol: string (nullable = true)
#  |-- id: string (nullable = true)
#  |-- rateUsd: string (nullable = true)
#  |-- symbol: string (nullable = true)
#  |-- timestamp: long (nullable = true)
#  |-- type: string (nullable = true)
#
# [GLUE_JOB_SYSTEM] - Starting transforming the data from rates...
# [GLUE_JOB_SYSTEM] - The data transformed has the following scheme:
# root
#  |-- currencySymbol: string (nullable = true)
#  |-- id: string (nullable = true)
#  |-- rateUsd: decimal(38,18) (nullable = true)
#  |-- symbol: string (nullable = true)
#  |-- timestamp: long (nullable = true)
#  |-- type: string (nullable = true)
#
# [GLUE_JOB_SYSTEM] - Starting to load the transformed data into /content/dataset/Trusted...
# /content/dataset/Trusted/Rates/
# +--------------+--------------------+--------------------+------+-------------+------+
# |currencySymbol|                  id|             rateUsd|symbol|    timestamp|  type|
# +--------------+--------------------+--------------------+------+-------------+------+
# |          null| mauritanian-ouguiya|0.025157232704402500|   MRU|1712204419037|  fiat|
# |          null|                dash|35.65184273049599...|  DASH|1712204419037|crypto|
# |             K|         myanma-kyat|0.000476495990671000|   MMK|1712204419037|  fiat|
# |           TT$|trinidad-and-toba...|0.147545833268782000|   TTD|1712204419037|  fiat|
# |             ₱|     philippine-peso|0.017719029351572100|   PHP|1712204419037|  fiat|
# |          null|        moldovan-leu|0.056707807803175800|   MDL|1712204419037|  fiat|
# |          null|               waves|2.832432419067936300| WAVES|1712204419037|crypto|
# |           UGX|    ugandan-shilling|0.000258578319257000|   UGX|1712204419037|  fiat|
# |             $|  new-zealand-dollar|0.602590052563930300|   NZD|1712204419037|  fiat|
# |          null|            ethereum|3264.523208617936...|   ETH|1712204419037|crypto|
# |          null|venezuelan-bolíva...|0.027625140435854500|   VES|1712204419037|  fiat|
# |             ₩|    north-korean-won|0.001111111111111100|   KPW|1712204419037|  fiat|
# |           B/.|   panamanian-balboa|1.000000000000000000|   PAB|1712204419037|  fiat|
# |           KSh|     kenyan-shilling|0.007633587786259500|   KES|1712204419037|  fiat|
# |             $|        mexican-peso|0.060443047538456900|   MXN|1712204419037|  fiat|
# |             ₼|   azerbaijani-manat|0.588235294117647100|   AZN|1712204419037|  fiat|
# |            Tk|    bangladeshi-taka|0.009117748177332500|   BDT|1712204419037|  fiat|
# |             K|papua-new-guinean...|0.262595042993373400|   PGK|1712204419037|  fiat|
# |            VT|        vanuatu-vatu|0.008423038695439800|   VUV|1712204419037|  fiat|
# |             ₡|   costa-rican-colón|0.001996417620236600|   CRC|1712204419037|  fiat|
# +--------------+--------------------+--------------------+------+-------------+------+
# only showing top 20 rows
#
# [GLUE_JOB_SYSTEM] - The data was succefully loaded into /content/dataset/Trusted

# %% [markdown]
# ### Refining data

# %%
REFINING_ENDPOINTS="assets,rates"
REFINING_INPUT_ZONE="Trusted"
REFINING_TARGET_ZONE="Refined"
REFINING_OBJECTS_KEY=','.join(objects_uploaded)

# %%
def getS3Path(prefix: str,
              endpoint: str,
              subdir:str = "",
              typeFile: str = "",
              filename:str = ""):

    endpoint = endpoint = '_'.join(map(lambda sub: sub.capitalize(),
                                       endpoint.lower().split('_'))) if '_' in endpoint else endpoint.lower().capitalize()

    filename = f'{subdir}/{filename}'

    return f"{prefix}/{endpoint}/{filename}"

def extractData(prefix: str,
                endpoint: str,
                subdir: str = "",
                filename: str = "",
                typeFile: str = "",
                deepRead: bool = False):
    objects_key = getS3Path(prefix=prefix,
                            endpoint=endpoint,
                            subdir=subdir,
                            filename=filename,
                            typeFile=typeFile)
    # the files are uploaded in the following path: Zone/Entity/Year/Month/Day/Timestamp
    # if deepRead on it will read all subdir within Entity
    return spark.read.parquet(objects_key if not deepRead else f"{objects_key}/*/*/*/*/")

def transformData(entity: str,
                  df: DataFrame) -> DataFrame:
    if entity.lower() == "currency":
        df = df.select(col('id').alias("currency_id"),
                  col('currencySymbol').alias("currency_special_symbol"),
                  col('symbol').alias("currency_symbol"),
                  col("type").alias("currency_type"))

        df = df.withColumn("currency_type", substring(col("currency_type"), 1, 1))

        df.show()
        return df
    if entity.lower() == "crypto_data":
        df = df.select(col('id').alias("currency_id"),
                       col('changePercent24Hr').alias("diff_percent_24hr"),
                       col('maxSupply').alias("max_supply"),
                       col('supply'),
                       col('vwap24Hr').alias("vwap_24hr"),
                       col('volumeUsd24Hr').alias("vol_usd_24hr"),
                       col("marketCapUsd").alias("market_cap_usd"),
                       col('timestamp'))

        return df
    if entity.lower() == "currency_value":
        df.show()
        df = df.select(col("id").alias("currency_id"),col('rateUsd').alias("rate_usd"),
                       col('timestamp'))

        return df

    raise Exception("Invalid endpoint")

# Since method Currency will almost always be the same
# This method avoid load duplicate data into Refined zone
def checkAndUpdateRowsWithinRefinedZone(load_prefix: str,
                                        entity: str,
                                        df: DataFrame):
  try:
    # extract data already saved
    # deepRead will allow the spark to read all the subdir within the /Zone/Entity/*
    df_saved = extractData(prefix=load_prefix,
                           endpoint=entity, deepRead=True)
    print("df_saved table: ")
    df_saved.show()
    if df.schema != df_saved.schema:
      df_saved.printSchema()
      df.printSchema()
      print("The data frames don't have the same schema")
      return
    else:
        diff_df = df.exceptAll(df_saved)
        if diff_df.count() == 0:
          print("The data frames has the same values.")

          return None
        else:
          print("The data frames has different values.")
          diff_df.show()
          return df.union(df_saved)

  except Exception as err:
    print(err)
    return df


# ETL functions
def loadData(prefix: str,
             entity: str,
             subdir_date: str,
             filename: str,
             df: DataFrame) -> DataFrame:

    path = getS3Path(prefix=prefix,
                     endpoint=entity)

    if entity.lower() == "currency":
        df = checkAndUpdateRowsWithinRefinedZone(load_prefix=prefix,
                                                 entity=entity,
                                                 df=df)
        if not df:
            print(f"{entity} wasn't uploaded into Refined zone 'cause there is no new data to update")
            return None

    df.write.parquet(f'{path}/{subdir_date}/{filename}',
                     mode="overwrite")

def getTimestampFromKeyObject(object_key: str):

    timestamp_prefix = object_key.split("/")[-1].split("-")[0]

    return timestamp_prefix

def getDateSubDirFromKeyObject(object_key: str):
    regex_pattern_extract_subdir = r'(\d{4}/\d{2}/\d{2})'
    match = re.search(regex_pattern_extract_subdir, object_key)
    if match:
        return match.group()
    else:
        raise ValueError("No date subdirectory found in object key: {}".format(object_key))

def execute_job():
    extract_prefix = f"/content/dataset/{REFINING_INPUT_ZONE}"

    load_prefix = f"/content/dataset/{REFINING_TARGET_ZONE}"

    print(f"[GLUE_JOB_SYSTEM] - Starting to processing data from {extract_prefix} to store into {load_prefix}...")

    print(TREATING_OBJECTS_KEY)
    objects_key = TREATING_OBJECTS_KEY.split(",")
    print(objects_key)
    for endpoint in TREATING_ENDPOINTS.split(","):
        _objects_key = filter(lambda object_key: endpoint.lower().capitalize() in object_key,
                              objects_key)

        print(f"[GLUE_JOB_SYSTEM] - Starting refining data stores in {endpoint}...")

        for object_key in _objects_key:
            filename = f'{getTimestampFromKeyObject(object_key=object_key)}'
            subdir= getDateSubDirFromKeyObject(object_key=object_key)

            print(f"[GLUE_JOB_SYSTEM] - The following pathfile within /{REFINING_INPUT_ZONE} will be processed: {subdir}/{filename}")

            print(f"[GLUE_JOB_SYSTEM] -  Starting extracting the data from {endpoint}...")

            df = extractData(prefix=extract_prefix,
                             subdir=subdir,
                             endpoint=endpoint,
                             filename=filename,)
            entities = []

            if endpoint.lower() == "rates":
                entities.append("Currency")
                entities.append("Currency_Value")

            if endpoint.lower() == "assets":
                entities.append("Crypto_Data")

            print("[GLUE_JOB_SYSTEM] - The data will be treat as source data for the following entities: {}".format(", ".join(entities)))

            for entity in entities:

                print(f"[GLUE_JOB_SYSTEM] - The data is being transformed into a {entity}'s data structured...")
                print(df)
                df_transformed = transformData(entity=entity,
                                               df=df)

                print(f"[GLUE_JOB_SYSTEM] - The data transformed has the following scheme:")
                df_transformed.printSchema()

                print(f"[GLUE_JOB_SYSTEM] - Starting to load the transformed data into {load_prefix}...")

                loadData(prefix=load_prefix,
                         entity=entity,
                         filename= filename,
                         subdir_date=subdir,
                         df=df_transformed)

                print(f"[GLUE_JOB_SYSTEM] - The data was succefully loaded into {load_prefix}")

execute_job()
# Out:
# [GLUE_JOB_SYSTEM] - Starting to processing data from /content/dataset/Trusted to store into /content/dataset/Refined...
# Assets/2024/04/04/1712204419.123182-batch_0.json,Rates/2024/04/04/1712204419.126377-batch_0.json,Rates/2024/04/04/1712204419.127783-batch_1.json
# ['Assets/2024/04/04/1712204419.123182-batch_0.json', 'Rates/2024/04/04/1712204419.126377-batch_0.json', 'Rates/2024/04/04/1712204419.127783-batch_1.json']
# [GLUE_JOB_SYSTEM] - Starting refining data stores in assets...
# [GLUE_JOB_SYSTEM] - The following pathfile within /Trusted will be processed: 2024/04/04/1712204419.123182
# [GLUE_JOB_SYSTEM] -  Starting extracting the data from assets...
# [GLUE_JOB_SYSTEM] - The data will be treat as source data for the following entities: Crypto_Data
# [GLUE_JOB_SYSTEM] - The data is being transformed into a Crypto_Data's data structured...
# DataFrame[changePercent24Hr: string, explorer: string, id: string, marketCapUsd: decimal(38,18), maxSupply: decimal(38,18), name: string, priceUsd: decimal(38,18), rank: string, supply: decimal(38,18), symbol: string, timestamp: bigint, volumeUsd24Hr: decimal(38,18), vwap24Hr: decimal(38,18)]
# [GLUE_JOB_SYSTEM] - The data transformed has the following scheme:
# root
#  |-- currency_id: string (nullable = true)
#  |-- diff_percent_24hr: string (nullable = true)
#  |-- max_supply: decimal(38,18) (nullable = true)
#  |-- supply: decimal(38,18) (nullable = true)
#  |-- vwap_24hr: decimal(38,18) (nullable = true)
#  |-- vol_usd_24hr: decimal(38,18) (nullable = true)
#  |-- market_cap_usd: decimal(38,18) (nullable = true)
#  |-- timestamp: long (nullable = true)
#
# [GLUE_JOB_SYSTEM] - Starting to load the transformed data into /content/dataset/Refined...
# [GLUE_JOB_SYSTEM] - The data was succefully loaded into /content/dataset/Refined
# [GLUE_JOB_SYSTEM] - Starting refining data stores in rates...
# [GLUE_JOB_SYSTEM] - The following pathfile within /Trusted will be processed: 2024/04/04/1712204419.126377
# [GLUE_JOB_SYSTEM] -  Starting extracting the data from rates...
# [GLUE_JOB_SYSTEM] - The data will be treat as source data for the following entities: Currency, Currency_Value
# [GLUE_JOB_SYSTEM] - The data is being transformed into a Currency's data structured...
# DataFrame[currencySymbol: string, id: string, rateUsd: decimal(38,18), symbol: string, timestamp: bigint, type: string]
# +--------------------+-----------------------+---------------+-------------+
# |         currency_id|currency_special_symbol|currency_symbol|currency_type|
# +--------------------+-----------------------+---------------+-------------+
# |      argentine-peso|                      $|            ARS|            f|
# |        binance-coin|                   null|            BNB|            c|
# |            dogecoin|                   null|           DOGE|            c|
# |   australian-dollar|                      $|            AUD|            f|
# |     norwegian-krone|                     kr|            NOK|            f|
# |    sri-lankan-rupee|                      ₨|            LKR|            f|
# |      afghan-afghani|                     ؋ |            AFN|            f|
# |       ghanaian-cedi|                      ¢|            GHS|            f|
# |             bitcoin|                      ₿|            BTC|            c|
# |         yemeni-rial|                      ﷼|            YER|            f|
# |     jordanian-dinar|                   null|            JOD|            f|
# |     congolese-franc|                   null|            CDF|            f|
# | turkmenistani-manat|                   null|            TMT|            f|
# |      dominican-peso|                    RD$|            DOP|            f|
# |          omani-rial|                      ﷼|            OMR|            f|
# |netherlands-antil...|                      ƒ|            ANG|            f|
# |                 eos|                   null|            EOS|            c|
# |      colombian-peso|                      $|            COP|            f|
# |               zcash|                   null|            ZEC|            c|
# |       armenian-dram|                      ֏|            AMD|            f|
# +--------------------+-----------------------+---------------+-------------+
# only showing top 20 rows
#
# [GLUE_JOB_SYSTEM] - The data transformed has the following scheme:
# root
#  |-- currency_id: string (nullable = true)
#  |-- currency_special_symbol: string (nullable = true)
#  |-- currency_symbol: string (nullable = true)
#  |-- currency_type: string (nullable = true)
#
# [GLUE_JOB_SYSTEM] - Starting to load the transformed data into /content/dataset/Refined...
# Path does not exist: file:/content/dataset/Refined/Currency/*/*/*/*
# [GLUE_JOB_SYSTEM] - The data was succefully loaded into /content/dataset/Refined
# [GLUE_JOB_SYSTEM] - The data is being transformed into a Currency_Value's data structured...
# DataFrame[currencySymbol: string, id: string, rateUsd: decimal(38,18), symbol: string, timestamp: bigint, type: string]
# +--------------+--------------------+--------------------+------+-------------+------+
# |currencySymbol|                  id|             rateUsd|symbol|    timestamp|  type|
# +--------------+--------------------+--------------------+------+-------------+------+
# |             $|      argentine-peso|0.001166167158400500|   ARS|1712204419037|  fiat|
# |          null|        binance-coin|576.3704085034755...|   BNB|1712204419037|crypto|
# |          null|            dogecoin|0.172908041963419500|  DOGE|1712204419037|crypto|
# |             $|   australian-dollar|0.658117284397487100|   AUD|1712204419037|  fiat|
# |            kr|     norwegian-krone|0.093440041861138800|   NOK|1712204419037|  fiat|
# |             ₨|    sri-lankan-rupee|0.003338798166879600|   LKR|1712204419037|  fiat|
# |            ؋ |      afghan-afghani|0.014139997370808900|   AFN|1712204419037|  fiat|
# |             ¢|       ghanaian-cedi|0.075377825697974200|   GHS|1712204419037|  fiat|
# |             ₿|             bitcoin|65419.91762046810...|   BTC|1712204419037|crypto|
# |             ﷼|         yemeni-rial|0.003994009816030000|   YER|1712204419037|  fiat|
# |          null|     jordanian-dinar|1.410636196924813100|   JOD|1712204419037|  fiat|
# |          null|     congolese-franc|0.000354725385146700|   CDF|1712204419037|  fiat|
# |          null| turkmenistani-manat|0.285306704707560600|   TMT|1712204419037|  fiat|
# |           RD$|      dominican-peso|0.016910890077134500|   DOP|1712204419037|  fiat|
# |             ﷼|          omani-rial|2.597753462805366000|   OMR|1712204419037|  fiat|
# |             ƒ|netherlands-antil...|0.555234444968215600|   ANG|1712204419037|  fiat|
# |          null|                 eos|0.946393269578542500|   EOS|1712204419037|crypto|
# |             $|      colombian-peso|0.000263820948637300|   COP|1712204419037|  fiat|
# |          null|               zcash|27.29453790968068...|   ZEC|1712204419037|crypto|
# |             ֏|       armenian-dram|0.002590325907760000|   AMD|1712204419037|  fiat|
# +--------------+--------------------+--------------------+------+-------------+------+
# only showing top 20 rows
#
# [GLUE_JOB_SYSTEM] - The data transformed has the following scheme:
# root
#  |-- currency_id: string (nullable = true)
#  |-- rate_usd: decimal(38,18) (nullable = true)
#  |-- timestamp: long (nullable = true)
#
# [GLUE_JOB_SYSTEM] - Starting to load the transformed data into /content/dataset/Refined...
# [GLUE_JOB_SYSTEM] - The data was succefully loaded into /content/dataset/Refined
# [GLUE_JOB_SYSTEM] - The following pathfile within /Trusted will be processed: 2024/04/04/1712204419.127783
# [GLUE_JOB_SYSTEM] -  Starting extracting the data from rates...
# [GLUE_JOB_SYSTEM] - The data will be treat as source data for the following entities: Currency, Currency_Value
# [GLUE_JOB_SYSTEM] - The data is being transformed into a Currency's data structured...
# DataFrame[currencySymbol: string, id: string, rateUsd: decimal(38,18), symbol: string, timestamp: bigint, type: string]
# +--------------------+-----------------------+---------------+-------------+
# |         currency_id|currency_special_symbol|currency_symbol|currency_type|
# +--------------------+-----------------------+---------------+-------------+
# | mauritanian-ouguiya|                   null|            MRU|            f|
# |                dash|                   null|           DASH|            c|
# |         myanma-kyat|                      K|            MMK|            f|
# |trinidad-and-toba...|                    TT$|            TTD|            f|
# |     philippine-peso|                      ₱|            PHP|            f|
# |        moldovan-leu|                   null|            MDL|            f|
# |               waves|                   null|          WAVES|            c|
# |    ugandan-shilling|                    UGX|            UGX|            f|
# |  new-zealand-dollar|                      $|            NZD|            f|
# |            ethereum|                   null|            ETH|            c|
# |venezuelan-bolíva...|                   null|            VES|            f|
# |    north-korean-won|                      ₩|            KPW|            f|
# |   panamanian-balboa|                    B/.|            PAB|            f|
# |     kenyan-shilling|                    KSh|            KES|            f|
# |        mexican-peso|                      $|            MXN|            f|
# |   azerbaijani-manat|                      ₼|            AZN|            f|
# |    bangladeshi-taka|                     Tk|            BDT|            f|
# |papua-new-guinean...|                      K|            PGK|            f|
# |        vanuatu-vatu|                     VT|            VUV|            f|
# |   costa-rican-colón|                      ₡|            CRC|            f|
# +--------------------+-----------------------+---------------+-------------+
# only showing top 20 rows
#
# [GLUE_JOB_SYSTEM] - The data transformed has the following scheme:
# root
#  |-- currency_id: string (nullable = true)
#  |-- currency_special_symbol: string (nullable = true)
#  |-- currency_symbol: string (nullable = true)
#  |-- currency_type: string (nullable = true)
#
# [GLUE_JOB_SYSTEM] - Starting to load the transformed data into /content/dataset/Refined...
# df_saved table:
# +--------------------+-----------------------+---------------+-------------+
# |         currency_id|currency_special_symbol|currency_symbol|currency_type|
# +--------------------+-----------------------+---------------+-------------+
# |      argentine-peso|                      $|            ARS|            f|
# |        binance-coin|                   null|            BNB|            c|
# |            dogecoin|                   null|           DOGE|            c|
# |   australian-dollar|                      $|            AUD|            f|
# |     norwegian-krone|                     kr|            NOK|            f|
# |    sri-lankan-rupee|                      ₨|            LKR|            f|
# |      afghan-afghani|                     ؋ |            AFN|            f|
# |       ghanaian-cedi|                      ¢|            GHS|            f|
# |             bitcoin|                      ₿|            BTC|            c|
# |         yemeni-rial|                      ﷼|            YER|            f|
# |     jordanian-dinar|                   null|            JOD|            f|
# |     congolese-franc|                   null|            CDF|            f|
# | turkmenistani-manat|                   null|            TMT|            f|
# |      dominican-peso|                    RD$|            DOP|            f|
# |          omani-rial|                      ﷼|            OMR|            f|
# |netherlands-antil...|                      ƒ|            ANG|            f|
# |                 eos|                   null|            EOS|            c|
# |      colombian-peso|                      $|            COP|            f|
# |               zcash|                   null|            ZEC|            c|
# |       armenian-dram|                      ֏|            AMD|            f|
# +--------------------+-----------------------+---------------+-------------+
# only showing top 20 rows
#
# The data frames has different values.
# +--------------------+-----------------------+---------------+-------------+
# |         currency_id|currency_special_symbol|currency_symbol|currency_type|
# +--------------------+-----------------------+---------------+-------------+
# |united-arab-emira...|                    فلس|            AED|            f|
# |venezuelan-bolíva...|                   null|            VES|            f|
# |   costa-rican-colón|                      ₡|            CRC|            f|
# |       kuwaiti-dinar|                      ك|            KWD|            f|
# |   azerbaijani-manat|                      ₼|            AZN|            f|
# |chinese-yuan-(off...|                   null|            CNH|            f|
# |     bermudan-dollar|                      $|            BMD|            f|
# |    belarusian-ruble|                     Br|            BYN|            f|
# |      eritrean-nakfa|                   null|            ERN|            f|
# |       guinean-franc|                   null|            GNF|            f|
# | cape-verdean-escudo|                      $|            CVE|            f|
# |     malawian-kwacha|                     MK|            MWK|            f|
# |        mexican-peso|                      $|            MXN|            f|
# |      nigerian-naira|                      ₦|            NGN|            f|
# |   maldivian-rufiyaa|                   null|            MVR|            f|
# |       swedish-krona|                     kr|            SEK|            f|
# |sierra-leonean-leone|                     Le|            SLL|            f|
# |  tanzanian-shilling|                   null|            TZS|            f|
# |        syrian-pound|                      £|            SYP|            f|
# |        indian-rupee|                      ₹|            INR|            f|
# +--------------------+-----------------------+---------------+-------------+
# only showing top 20 rows
#
# [GLUE_JOB_SYSTEM] - The data was succefully loaded into /content/dataset/Refined
# [GLUE_JOB_SYSTEM] - The data is being transformed into a Currency_Value's data structured...
# DataFrame[currencySymbol: string, id: string, rateUsd: decimal(38,18), symbol: string, timestamp: bigint, type: string]
# +--------------+--------------------+--------------------+------+-------------+------+
# |currencySymbol|                  id|             rateUsd|symbol|    timestamp|  type|
# +--------------+--------------------+--------------------+------+-------------+------+
# |          null| mauritanian-ouguiya|0.025157232704402500|   MRU|1712204419037|  fiat|
# |          null|                dash|35.65184273049599...|  DASH|1712204419037|crypto|
# |             K|         myanma-kyat|0.000476495990671000|   MMK|1712204419037|  fiat|
# |           TT$|trinidad-and-toba...|0.147545833268782000|   TTD|1712204419037|  fiat|
# |             ₱|     philippine-peso|0.017719029351572100|   PHP|1712204419037|  fiat|
# |          null|        moldovan-leu|0.056707807803175800|   MDL|1712204419037|  fiat|
# |          null|               waves|2.832432419067936300| WAVES|1712204419037|crypto|
# |           UGX|    ugandan-shilling|0.000258578319257000|   UGX|1712204419037|  fiat|
# |             $|  new-zealand-dollar|0.602590052563930300|   NZD|1712204419037|  fiat|
# |          null|            ethereum|3264.523208617936...|   ETH|1712204419037|crypto|
# |          null|venezuelan-bolíva...|0.027625140435854500|   VES|1712204419037|  fiat|
# |             ₩|    north-korean-won|0.001111111111111100|   KPW|1712204419037|  fiat|
# |           B/.|   panamanian-balboa|1.000000000000000000|   PAB|1712204419037|  fiat|
# |           KSh|     kenyan-shilling|0.007633587786259500|   KES|1712204419037|  fiat|
# |             $|        mexican-peso|0.060443047538456900|   MXN|1712204419037|  fiat|
# |             ₼|   azerbaijani-manat|0.588235294117647100|   AZN|1712204419037|  fiat|
# |            Tk|    bangladeshi-taka|0.009117748177332500|   BDT|1712204419037|  fiat|
# |             K|papua-new-guinean...|0.262595042993373400|   PGK|1712204419037|  fiat|
# |            VT|        vanuatu-vatu|0.008423038695439800|   VUV|1712204419037|  fiat|
# |             ₡|   costa-rican-colón|0.001996417620236600|   CRC|1712204419037|  fiat|
# +--------------+--------------------+--------------------+------+-------------+------+
# only showing top 20 rows
#
# [GLUE_JOB_SYSTEM] - The data transformed has the following scheme:
# root
#  |-- currency_id: string (nullable = true)
#  |-- rate_usd: decimal(38,18) (nullable = true)
#  |-- timestamp: long (nullable = true)
#
# [GLUE_JOB_SYSTEM] - Starting to load the transformed data into /content/dataset/Refined...
# [GLUE_JOB_SYSTEM] - The data was succefully loaded into /content/dataset/Refined

# %% [markdown]
# #### Testing Results

# %%
currency = spark.read.parquet("/content/dataset/Refined/Currency/2024/*/*/*/*")
crypto_data = spark.read.parquet("/content/dataset/Refined/Crypto_Data/*/*/*/*")
currency_value = spark.read.parquet("/content/dataset/Refined/Currency_Value/*/*/*/*")

currency.show()
crypto_data.show()
currency_value.show()
# Out:
# +--------------------+-----------------------+---------------+-------------+
# |         currency_id|currency_special_symbol|currency_symbol|currency_type|
# +--------------------+-----------------------+---------------+-------------+
# |      argentine-peso|                      $|            ARS|            f|
# |        binance-coin|                   null|            BNB|            c|
# |            dogecoin|                   null|           DOGE|            c|
# |   australian-dollar|                      $|            AUD|            f|
# |     norwegian-krone|                     kr|            NOK|            f|
# |    sri-lankan-rupee|                      ₨|            LKR|            f|
# |      afghan-afghani|                     ؋ |            AFN|            f|
# |       ghanaian-cedi|                      ¢|            GHS|            f|
# |             bitcoin|                      ₿|            BTC|            c|
# |         yemeni-rial|                      ﷼|            YER|            f|
# |     jordanian-dinar|                   null|            JOD|            f|
# |     congolese-franc|                   null|            CDF|            f|
# | turkmenistani-manat|                   null|            TMT|            f|
# |      dominican-peso|                    RD$|            DOP|            f|
# |          omani-rial|                      ﷼|            OMR|            f|
# |netherlands-antil...|                      ƒ|            ANG|            f|
# |                 eos|                   null|            EOS|            c|
# |      colombian-peso|                      $|            COP|            f|
# |               zcash|                   null|            ZEC|            c|
# |       armenian-dram|                      ֏|            AMD|            f|
# +--------------------+-----------------------+---------------+-------------+
# only showing top 20 rows
#
# +-----------------+-------------------+--------------------+--------------------+--------------------+--------------------+--------------------+-------------+
# |      currency_id|  diff_percent_24hr|          max_supply|              supply|           vwap_24hr|        vol_usd_24hr|      market_cap_usd|    timestamp|
# +-----------------+-------------------+--------------------+--------------------+--------------------+--------------------+--------------------+-------------+
# |         ethereum|-1.5500001114446777|                null|120069288.4506371...|3323.174426341411...|5961011343.973288...|392055139115.6319...|1712204418804|
# |           tether|-0.0542370947432367|                null|106149786847.0736...|1.001116853340361000|20918434581.77520...|106248583747.4410...|1712204418804|
# |     binance-coin| 3.0516055784743504|166801148.0000000...|166801148.0000000...|563.9876177804584...|635961667.9616051...|96031406438.85547...|1712204418804|
# |           solana|-3.4302642204895921|                null|444814259.0549971...|187.8447800915203...|1118161212.262894...|80518326399.12069...|1712204418804|
# |         usd-coin|-0.0593153914916286|                null|32873084251.45694...|1.000543725976649400|1917088233.752784...|32889636542.22813...|1712204418804|
# |              xrp|-3.4795299736998682|100000000000.0000...|45404028640.00000...|0.581433681660290800|526920985.3875760...|25648660272.97686...|1712204418804|
# |         dogecoin|-6.8427118251859948|                null|143741036383.7053...|0.179832936250370800|1091916708.979186...|24856144527.36582...|1712204418804|
# |          cardano|-4.0834634566650883|45000000000.00000...|35597279591.31900...|0.581613169446782700|192253375.1784538...|20062179747.82426...|1712204418804|
# |        avalanche|-4.0586224484431319|715748719.0000000...|377709834.5777809...|46.77484015292932...|188909196.9466287...|17251745524.13936...|1712204418804|
# |        shiba-inu|-4.4277286848057009|                null|589289410812691.0...|0.000026795145554800|276578934.7233604...|15316209835.14785...|1712204418804|
# |     bitcoin-cash|-3.1422153287787486|21000000.00000000...|19687515.62500000...|600.0848221737396...|582521462.9833124...|12061821952.76627...|1712204418804|
# |         polkadot|-4.1064863724490711|                null|1348608167.070560...|8.598038579959527900|109347280.9488019...|11184330602.44886...|1712204418804|
# |             tron|-0.1533705822377922|                null|87708300045.99403...|0.117770572317276000|132560785.5997803...|10283539335.39688...|1712204418804|
# |        chainlink|-3.4164416631492508|1000000000.000000...|587099970.4527867...|17.90660727113310...|180620278.6562776...|10264277294.17176...|1712204418804|
# |  wrapped-bitcoin|-1.2282419716016693|                null|155417.8146596400...|66268.73281942683...|71030063.18987485...|10173955210.88728...|1712204418804|
# |          polygon|-3.5590116452796168|10000000000.00000...|9902244238.788954...|0.905476793069751600|101595364.2344776...|8682195913.285101...|1712204418804|
# |internet-computer|-0.4282686870523165|                null|461614426.7208741...|18.23572141874460...|117581821.3734827...|8375580666.918358...|1712204418804|
# |         litecoin|-5.2180541951228828|84000000.00000000...|74383393.60750493...|100.1278472992571...|457689549.1612071...|7258787555.734381...|1712204418804|
# |    near-protocol|-0.5815965041883912|                null|1054016312.000000...|6.681045350075365900|189108801.3645544...|6696161915.605056...|1712204418804|
# |          uniswap|-2.1468938215969034|1000000000.000000...|598736139.7100000...|11.00912095437501...|93300759.09304664...|6445012634.584160...|1712204418804|
# +-----------------+-------------------+--------------------+--------------------+--------------------+--------------------+--------------------+-------------+
# only showing top 20 rows
#
# +--------------------+--------------------+-------------+
# |         currency_id|            rate_usd|    timestamp|
# +--------------------+--------------------+-------------+
# |      argentine-peso|0.001166167158400500|1712204419037|
# |        binance-coin|576.3704085034755...|1712204419037|
# |            dogecoin|0.172908041963419500|1712204419037|
# |   australian-dollar|0.658117284397487100|1712204419037|
# |     norwegian-krone|0.093440041861138800|1712204419037|
# |    sri-lankan-rupee|0.003338798166879600|1712204419037|
# |      afghan-afghani|0.014139997370808900|1712204419037|
# |       ghanaian-cedi|0.075377825697974200|1712204419037|
# |             bitcoin|65419.91762046810...|1712204419037|
# |         yemeni-rial|0.003994009816030000|1712204419037|
# |     jordanian-dinar|1.410636196924813100|1712204419037|
# |     congolese-franc|0.000354725385146700|1712204419037|
# | turkmenistani-manat|0.285306704707560600|1712204419037|
# |      dominican-peso|0.016910890077134500|1712204419037|
# |          omani-rial|2.597753462805366000|1712204419037|
# |netherlands-antil...|0.555234444968215600|1712204419037|
# |                 eos|0.946393269578542500|1712204419037|
# |      colombian-peso|0.000263820948637300|1712204419037|
# |               zcash|27.29453790968068...|1712204419037|
# |       armenian-dram|0.002590325907760000|1712204419037|
# +--------------------+--------------------+-------------+
# only showing top 20 rows
