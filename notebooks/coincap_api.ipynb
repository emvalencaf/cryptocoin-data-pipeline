# %% [markdown]
# # Data Visualization
#
# In this notebook we'll see the data that can be fetched from [CoinCap's API](https://docs.coincap.io/). The main goal of this notebook is to get some level of undestanding in order to build a Data Enginering Project.

# %% [markdown]
# First of, we'll import the necessaries libs to call the CoinCap's API:

# %%
import requests

# %% [markdown]
# The API config vars:

# %%
API_URL = "https://api.coincap.io/v2"

# %% [markdown]
# ## Get real-time data about cryptocurrencies

# %% [markdown]
# In this section we will fetch the `/assets` `endpoint` and see what was the fetched data. This `endpoint` can receive a `asset`.

# %%
def getCryptoCurrencyRealTimeData(asset: str = ""):
  try:
    res = requests.get(API_URL + f'/assets/{asset}')

    if res.status_code == 200:
      return res.json()
    else:
      print(f'Error: {res.status_code}')
  except requests.exceptions.RequestException as err:
    print(f'Error: {err}')

# %%
getCryptoCurrencyRealTimeData()
# Out:
# {'data': [{'id': 'bitcoin',
#    'rank': '1',
#    'symbol': 'BTC',
#    'name': 'Bitcoin',
#    'supply': '19658368.0000000000000000',
#    'maxSupply': '21000000.0000000000000000',
#    'marketCapUsd': '1384391894671.9349448302216576',
#    'volumeUsd24Hr': '8046840219.6769215210677368',
#    'priceUsd': '70422.5241216328306007',
#    'changePercent24Hr': '-1.2178332121447889',
#    'vwap24Hr': '70587.1399776516809779',
#    'explorer': 'https://blockchain.info/'},
#   {'id': 'ethereum',
#    'rank': '2',
#    'symbol': 'ETH',
#    'name': 'Ethereum',
#    'supply': '120077426.1898597300000000',
#    'maxSupply': None,
#    'marketCapUsd': '426734460156.4664170044950233',
#    'volumeUsd24Hr': '5389929800.6303830471443366',
#    'priceUsd': '3553.8275069432091763',
#    'changePercent24Hr': '-1.1956393520623787',
#    'vwap24Hr': '3560.7802342772447268',
#    'explorer': 'https://etherscan.io/'},
#   {'id': 'tether',
#    'rank': '3',
#    'symbol': 'USDT',
#    'name': 'Tether',
#    'supply': '103618183617.7160800000000000',
#    'maxSupply': None,
#    'marketCapUsd': '103697731844.2118909568144970',
#    'volumeUsd24Hr': '21293135630.8111905004541261',
#    'priceUsd': '1.0007677052783447',
#    'changePercent24Hr': '0.0344717007622659',
#    'vwap24Hr': '1.0003972484948264',
#    'explorer': 'https://www.omniexplorer.info/asset/31'},
#   {'id': 'binance-coin',
#    'rank': '4',
#    'symbol': 'BNB',
#    'name': 'BNB',
#    'supply': '166801148.0000000000000000',
#    'maxSupply': '166801148.0000000000000000',
#    'marketCapUsd': '103320220668.7702055418051792',
#    'volumeUsd24Hr': '782350624.9817048656275664',
#    'priceUsd': '619.4215202210131404',
#    'changePercent24Hr': '5.4788399585034593',
#    'vwap24Hr': '602.5335105717948235',
#    'explorer': 'https://etherscan.io/token/0xB8c77482e45F1F44dE1745F52C74426C631bDD52'},
#   {'id': 'solana',
#    'rank': '5',
#    'symbol': 'SOL',
#    'name': 'Solana',
#    'supply': '443884942.2473194000000000',
#    'maxSupply': None,
#    'marketCapUsd': '83357535240.6154083546352511',
#    'volumeUsd24Hr': '923474427.5271819531028559',
#    'priceUsd': '187.7908604391700348',
#    'changePercent24Hr': '0.3884389595500863',
#    'vwap24Hr': '187.1415327520950961',
#    'explorer': 'https://explorer.solana.com/'},
#   {'id': 'usd-coin',
#    'rank': '6',
#    'symbol': 'USDC',
#    'name': 'USDC',
#    'supply': '31402000743.4583700000000000',
#    'maxSupply': None,
#    'marketCapUsd': '31422529052.1777773417182438',
#    'volumeUsd24Hr': '1576981756.9244147088310412',
#    'priceUsd': '1.0006537261395258',
#    'changePercent24Hr': '-0.0492642162639513',
#    'vwap24Hr': '1.0001275632255578',
#    'explorer': 'https://etherscan.io/token/0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48'},
#   {'id': 'dogecoin',
#    'rank': '7',
#    'symbol': 'DOGE',
#    'name': 'Dogecoin',
#    'supply': '143530066383.7052000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '31235662256.2225527318378406',
#    'volumeUsd24Hr': '1911589170.3619382400075949',
#    'priceUsd': '0.2176245231624076',
#    'changePercent24Hr': '-1.1905498130182807',
#    'vwap24Hr': '0.2175951818704701',
#    'explorer': 'http://dogechain.info/chain/Dogecoin'},
#   {'id': 'xrp',
#    'rank': '8',
#    'symbol': 'XRP',
#    'name': 'XRP',
#    'supply': '45404028640.0000000000000000',
#    'maxSupply': '100000000000.0000000000000000',
#    'marketCapUsd': '29009457111.3141287625168000',
#    'volumeUsd24Hr': '651767008.8340782819565079',
#    'priceUsd': '0.6389181308408700',
#    'changePercent24Hr': '2.4427666590839277',
#    'vwap24Hr': '0.6250873260646093',
#    'explorer': 'https://xrpcharts.ripple.com/#/graph/'},
#   {'id': 'cardano',
#    'rank': '9',
#    'symbol': 'ADA',
#    'name': 'Cardano',
#    'supply': '35565639551.8750000000000000',
#    'maxSupply': '45000000000.0000000000000000',
#    'marketCapUsd': '23653950887.4528610677098474',
#    'volumeUsd24Hr': '213978520.1246451097487849',
#    'priceUsd': '0.6650787441331373',
#    'changePercent24Hr': '1.6284619177493674',
#    'vwap24Hr': '0.6502801754297079',
#    'explorer': 'https://cardanoexplorer.com/'},
#   {'id': 'avalanche',
#    'rank': '10',
#    'symbol': 'AVAX',
#    'name': 'Avalanche',
#    'supply': '377311201.7659915000000000',
#    'maxSupply': '720000000.0000000000000000',
#    'marketCapUsd': '20340128810.1582867034653842',
#    'volumeUsd24Hr': '171771307.7445201968873215',
#    'priceUsd': '53.9080968573343327',
#    'changePercent24Hr': '-1.1548161045094867',
#    'vwap24Hr': '54.1861248563012118',
#    'explorer': 'https://avascan.info/'},
#   {'id': 'shiba-inu',
#    'rank': '11',
#    'symbol': 'SHIB',
#    'name': 'Shiba Inu',
#    'supply': '589289410812691.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '18255240800.5412578573849132',
#    'volumeUsd24Hr': '508130222.1466590931007418',
#    'priceUsd': '0.0000309783961252',
#    'changePercent24Hr': '-4.2560099396736419',
#    'vwap24Hr': '0.0000314757627460',
#    'explorer': 'https://etherscan.io/token/0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce'},
#   {'id': 'polkadot',
#    'rank': '12',
#    'symbol': 'DOT',
#    'name': 'Polkadot',
#    'supply': '1346304754.6587900000000000',
#    'maxSupply': None,
#    'marketCapUsd': '13083336963.8813324369558260',
#    'volumeUsd24Hr': '162462041.0615526353681996',
#    'priceUsd': '9.7179608989772883',
#    'changePercent24Hr': '1.6265784998409371',
#    'vwap24Hr': '9.4994087078223870',
#    'explorer': 'https://polkascan.io/polkadot'},
#   {'id': 'bitcoin-cash',
#    'rank': '13',
#    'symbol': 'BCH',
#    'name': 'Bitcoin Cash',
#    'supply': '19672493.7500000000000000',
#    'maxSupply': '21000000.0000000000000000',
#    'marketCapUsd': '12174430969.3749809644047356',
#    'volumeUsd24Hr': '634013674.5773667006168714',
#    'priceUsd': '618.8555006848067223',
#    'changePercent24Hr': '7.9277046375680669',
#    'vwap24Hr': '591.7083785817433045',
#    'explorer': 'https://blockchair.com/bitcoin-cash/blocks'},
#   {'id': 'chainlink',
#    'rank': '14',
#    'symbol': 'LINK',
#    'name': 'Chainlink',
#    'supply': '587099970.4527867000000000',
#    'maxSupply': '1000000000.0000000000000000',
#    'marketCapUsd': '11252892875.8374287540145778',
#    'volumeUsd24Hr': '176282582.6834211830824337',
#    'priceUsd': '19.1669109898930950',
#    'changePercent24Hr': '-1.0737917557415584',
#    'vwap24Hr': '19.0890722119709905',
#    'explorer': 'https://etherscan.io/token/0x514910771af9ca656af840dff83e8264ecf986ca'},
#   {'id': 'wrapped-bitcoin',
#    'rank': '15',
#    'symbol': 'WBTC',
#    'name': 'Wrapped Bitcoin',
#    'supply': '155584.7087716400000000',
#    'maxSupply': None,
#    'marketCapUsd': '10960752203.1859866059974675',
#    'volumeUsd24Hr': '75917770.4839894065256432',
#    'priceUsd': '70448.7753952328885691',
#    'changePercent24Hr': '-1.1032521479739915',
#    'vwap24Hr': '70693.6560562680850542',
#    'explorer': 'https://etherscan.io/token/0x2260fac5e5542a773aa44fbcfedf7c193bc2c599'},
#   {'id': 'tron',
#    'rank': '16',
#    'symbol': 'TRX',
#    'name': 'TRON',
#    'supply': '87827583692.0204600000000000',
#    'maxSupply': None,
#    'marketCapUsd': '10610011644.3119206266586637',
#    'volumeUsd24Hr': '112757174.6155624147963788',
#    'priceUsd': '0.1208050045133587',
#    'changePercent24Hr': '0.1050722134376677',
#    'vwap24Hr': '0.1203550324424628',
#    'explorer': 'https://tronscan.org/#/'},
#   {'id': 'polygon',
#    'rank': '17',
#    'symbol': 'MATIC',
#    'name': 'Polygon',
#    'supply': '9906666473.1907880000000000',
#    'maxSupply': '10000000000.0000000000000000',
#    'marketCapUsd': '9942187706.4963796417514750',
#    'volumeUsd24Hr': '138748908.5351782486547872',
#    'priceUsd': '1.0035855888962971',
#    'changePercent24Hr': '-1.2130146504441606',
#    'vwap24Hr': '1.0049681952949619',
#    'explorer': 'https://etherscan.io/token/0x7D1AfA7B718fb893dB30A3aBc0Cfc608AaCfeBB0'},
#   {'id': 'internet-computer',
#    'rank': '18',
#    'symbol': 'ICP',
#    'name': 'Internet Computer',
#    'supply': '461012211.7845339000000000',
#    'maxSupply': None,
#    'marketCapUsd': '8162774290.4300718868135110',
#    'volumeUsd24Hr': '119840503.8699889415880079',
#    'priceUsd': '17.7061997096188803',
#    'changePercent24Hr': '0.9391840525888040',
#    'vwap24Hr': '17.7286410285260990',
#    'explorer': 'https://www.dfinityexplorer.org/#/'},
#   {'id': 'litecoin',
#    'rank': '19',
#    'symbol': 'LTC',
#    'name': 'Litecoin',
#    'supply': '74327168.6075049300000000',
#    'maxSupply': '84000000.0000000000000000',
#    'marketCapUsd': '7828322973.3176075903642586',
#    'volumeUsd24Hr': '706596864.6361481819432030',
#    'priceUsd': '105.3224967394650578',
#    'changePercent24Hr': '10.4879053535767104',
#    'vwap24Hr': '97.6783261356996669',
#    'explorer': 'http://explorer.litecoin.net/chain/Litecoin'},
#   {'id': 'uniswap',
#    'rank': '20',
#    'symbol': 'UNI',
#    'name': 'Uniswap',
#    'supply': '598736139.7100000000000000',
#    'maxSupply': '1000000000.0000000000000000',
#    'marketCapUsd': '7687674657.4689991883159962',
#    'volumeUsd24Hr': '123512379.8627502853957004',
#    'priceUsd': '12.8398373634044406',
#    'changePercent24Hr': '3.3033261956304698',
#    'vwap24Hr': '12.6966606085861407',
#    'explorer': 'https://etherscan.io/token/0x1f9840a85d5af5bf1d1762f925bdaddc4201f984'},
#   {'id': 'near-protocol',
#    'rank': '21',
#    'symbol': 'NEAR',
#    'name': 'NEAR Protocol',
#    'supply': '1053121449.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '7477628787.8151323327842632',
#    'volumeUsd24Hr': '105250667.3258833273999431',
#    'priceUsd': '7.1004429687720968',
#    'changePercent24Hr': '-2.2767230411350914',
#    'vwap24Hr': '7.1362971140522411',
#    'explorer': 'https://explorer.nearprotocol.com/'},
#   {'id': 'unus-sed-leo',
#    'rank': '22',
#    'symbol': 'LEO',
#    'name': 'UNUS SED LEO',
#    'supply': '926931427.9000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '5640094582.3065639947814445',
#    'volumeUsd24Hr': '185487.4825711736345095',
#    'priceUsd': '6.0846945227484869',
#    'changePercent24Hr': '-0.1692045606656144',
#    'vwap24Hr': '6.0550547926588802',
#    'explorer': 'https://eospark.com/account/bitfinexleo1'},
#   {'id': 'multi-collateral-dai',
#    'rank': '23',
#    'symbol': 'DAI',
#    'name': 'Multi Collateral DAI',
#    'supply': '5347888595.7464075000000000',
#    'maxSupply': None,
#    'marketCapUsd': '5350522552.2253504050508687',
#    'volumeUsd24Hr': '446917065.8824114260326355',
#    'priceUsd': '1.0004925226903638',
#    'changePercent24Hr': '0.1563927047491423',
#    'vwap24Hr': '0.9994966640136620',
#    'explorer': 'https://etherscan.io/token/0x89d24a6b4ccb1b6faa2625fe562bdd9a23260359'},
#   {'id': 'filecoin',
#    'rank': '24',
#    'symbol': 'FIL',
#    'name': 'Filecoin',
#    'supply': '525282244.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '5236966546.2970993897324640',
#    'volumeUsd24Hr': '271227164.9676702509052492',
#    'priceUsd': '9.9698145256497560',
#    'changePercent24Hr': '8.8525788511585353',
#    'vwap24Hr': '9.4743496534950545',
#    'explorer': 'https://protocol.ai'},
#   {'id': 'stacks',
#    'rank': '25',
#    'symbol': 'STX',
#    'name': 'Stacks',
#    'supply': '1446427874.4571350000000000',
#    'maxSupply': '1818000000.0000000000000000',
#    'marketCapUsd': '5173298124.2979630186738734',
#    'volumeUsd24Hr': '36078473.1141589338845683',
#    'priceUsd': '3.5766028957645576',
#    'changePercent24Hr': '3.3768792854777628',
#    'vwap24Hr': '3.5131393806157333',
#    'explorer': 'https://explorer.xinfin.network/'},
#   {'id': 'ethereum-classic',
#    'rank': '26',
#    'symbol': 'ETC',
#    'name': 'Ethereum Classic',
#    'supply': '146110555.5363162000000000',
#    'maxSupply': '210700000.0000000000000000',
#    'marketCapUsd': '5047530161.4466868101313858',
#    'volumeUsd24Hr': '145850887.7358434333155568',
#    'priceUsd': '34.5459651626066717',
#    'changePercent24Hr': '6.5205420959705598',
#    'vwap24Hr': '32.9679761083840965',
#    'explorer': 'http://gastracker.io/'},
#   {'id': 'stellar',
#    'rank': '27',
#    'symbol': 'XLM',
#    'name': 'Stellar',
#    'supply': '28681978352.6240540000000000',
#    'maxSupply': '50001806812.0000000000000000',
#    'marketCapUsd': '4135098680.1076553828192580',
#    'volumeUsd24Hr': '84430866.5180551657184504',
#    'priceUsd': '0.1441706227258673',
#    'changePercent24Hr': '4.5460537592492423',
#    'vwap24Hr': '0.1398417914364442',
#    'explorer': 'https://dashboard.stellar.org/'},
#   {'id': 'render-token',
#    'rank': '28',
#    'symbol': 'RNDR',
#    'name': 'Render Token',
#    'supply': '369614008.1087959400000000',
#    'maxSupply': '536870912.0000000000000000',
#    'marketCapUsd': '4067403792.6713940218898574',
#    'volumeUsd24Hr': '13523601.5338173324407610',
#    'priceUsd': '11.0044633142641961',
#    'changePercent24Hr': '-3.5972005256728180',
#    'vwap24Hr': '11.1344016773078883',
#    'explorer': 'https://etherscan.io/token/0x6de037ef9ad2725eb40118bb1702ebb27e4aeb24'},
#   {'id': 'crypto-com-coin',
#    'rank': '29',
#    'symbol': 'CRO',
#    'name': 'Crypto.com Coin',
#    'supply': '25263013692.0000000000000000',
#    'maxSupply': '30263013692.0000000000000000',
#    'marketCapUsd': '3923445571.6119778025772672',
#    'volumeUsd24Hr': '12049871.7761440331041153',
#    'priceUsd': '0.1553039403550816',
#    'changePercent24Hr': '1.0028573614348964',
#    'vwap24Hr': '0.1541434192260301',
#    'explorer': 'https://etherscan.io/token/0xa0b73e1ff0b80914ab6fe0444e65848c4c34450b'},
#   {'id': 'okb',
#    'rank': '30',
#    'symbol': 'OKB',
#    'name': 'OKB',
#    'supply': '60000000.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '3860708001.1311735420000000',
#    'volumeUsd24Hr': '1012632.8313706817097479',
#    'priceUsd': '64.3451333521862257',
#    'changePercent24Hr': '0.3298327634459832',
#    'vwap24Hr': '63.4217772905843502',
#    'explorer': 'https://etherscan.io/token/0x75231f58b43240c9718dd58b4967c5114342a86c'},
#   {'id': 'the-graph',
#    'rank': '31',
#    'symbol': 'GRT',
#    'name': 'The Graph',
#    'supply': '9456178825.3094500000000000',
#    'maxSupply': None,
#    'marketCapUsd': '3806306844.0502991665455694',
#    'volumeUsd24Hr': '52241557.1898880876542401',
#    'priceUsd': '0.4025206073580931',
#    'changePercent24Hr': '-3.3638972451899008',
#    'vwap24Hr': '0.4102209770656848',
#    'explorer': 'https://etherscan.io/token/0xc944e90c64b2c07662a292be6244bdf05cda44a7'},
#   {'id': 'vechain',
#    'rank': '32',
#    'symbol': 'VET',
#    'name': 'VeChain',
#    'supply': '72714516834.0000000000000000',
#    'maxSupply': '86712634466.0000000000000000',
#    'marketCapUsd': '3420482293.5906934333485162',
#    'volumeUsd24Hr': '52276143.7963874559561160',
#    'priceUsd': '0.0470398820279493',
#    'changePercent24Hr': '4.8416515365785683',
#    'vwap24Hr': '0.0461885834722852',
#    'explorer': 'https://explore.veforge.com/'},
#   {'id': 'maker',
#    'rank': '33',
#    'symbol': 'MKR',
#    'name': 'Maker',
#    'supply': '924359.6736397800000000',
#    'maxSupply': '1005577.0000000000000000',
#    'marketCapUsd': '3283963164.4574259144075938',
#    'volumeUsd24Hr': '163441841.0931208637719414',
#    'priceUsd': '3552.6897787810417036',
#    'changePercent24Hr': '1.1399839017793338',
#    'vwap24Hr': '3615.2295897625512305',
#    'explorer': 'https://etherscan.io/token/Maker'},
#   {'id': 'cosmos',
#    'rank': '34',
#    'symbol': 'ATOM',
#    'name': 'Cosmos',
#    'supply': '248453201.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '3124094953.9265858746417084',
#    'volumeUsd24Hr': '198629781.6518039068268762',
#    'priceUsd': '12.5741787240108284',
#    'changePercent24Hr': '2.0142874318464425',
#    'vwap24Hr': '12.3312020213477348',
#    'explorer': 'https://www.mintscan.io/'},
#   {'id': 'thorchain',
#    'rank': '35',
#    'symbol': 'RUNE',
#    'name': 'THORChain',
#    'supply': '336620216.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '3049558928.5258081363164560',
#    'volumeUsd24Hr': '103552381.6619258196500912',
#    'priceUsd': '9.0593457658698910',
#    'changePercent24Hr': '-4.4347451190564807',
#    'vwap24Hr': '9.2379000338677650',
#    'explorer': 'https://explorer.binance.org/asset/RUNE-B1A'},
#   {'id': 'theta',
#    'rank': '36',
#    'symbol': 'THETA',
#    'name': 'THETA',
#    'supply': '1000000000.0000000000000000',
#    'maxSupply': '1000000000.0000000000000000',
#    'marketCapUsd': '2996082682.8779741000000000',
#    'volumeUsd24Hr': '28220905.9073047579197184',
#    'priceUsd': '2.9960826828779741',
#    'changePercent24Hr': '0.1106237361223494',
#    'vwap24Hr': '2.9481679958189287',
#    'explorer': 'https://explorer.thetatoken.org/'},
#   {'id': 'fantom',
#    'rank': '37',
#    'symbol': 'FTM',
#    'name': 'Fantom',
#    'supply': '2803634835.5265927000000000',
#    'maxSupply': '3175000000.0000000000000000',
#    'marketCapUsd': '2782570193.5673623628603635',
#    'volumeUsd24Hr': '117365542.2849070825905709',
#    'priceUsd': '0.9924866670608072',
#    'changePercent24Hr': '-3.5676794195329992',
#    'vwap24Hr': '1.0019972930651413',
#    'explorer': 'https://etherscan.io/token/0x4e15361fd6b4bb609fa63c81a2be19d873717870'},
#   {'id': 'injective-protocol',
#    'rank': '38',
#    'symbol': 'INJ',
#    'name': 'Injective',
#    'supply': '73005554.3300000000000000',
#    'maxSupply': '100000000.0000000000000000',
#    'marketCapUsd': '2732522861.3113860841816004',
#    'volumeUsd24Hr': '51999024.9228218426808567',
#    'priceUsd': '37.4289721705258927',
#    'changePercent24Hr': '-1.0232913050961611',
#    'vwap24Hr': '37.7708593929545798',
#    'explorer': 'https://etherscan.io/token/0xe28b3b32b6c345a34ff64674606124dd5aceca30'},
#   {'id': 'arweave',
#    'rank': '39',
#    'symbol': 'AR',
#    'name': 'Arweave',
#    'supply': '65454185.0000000000000000',
#    'maxSupply': '66000000.0000000000000000',
#    'marketCapUsd': '2688305517.7978187331253150',
#    'volumeUsd24Hr': '35040704.8363215810650516',
#    'priceUsd': '41.0715604784906990',
#    'changePercent24Hr': '-3.5707885401629460',
#    'vwap24Hr': '41.5516813583406858',
#    'explorer': 'https://viewblock.io/arweave'},
#   {'id': 'fetch',
#    'rank': '40',
#    'symbol': 'FET',
#    'name': 'Fetch.ai',
#    'supply': '839758747.7594593000000000',
#    'maxSupply': None,
#    'marketCapUsd': '2659389863.3720892724361946',
#    'volumeUsd24Hr': '300435958.9863407177332681',
#    'priceUsd': '3.1668498488018675',
#    'changePercent24Hr': '-4.8396844074873221',
#    'vwap24Hr': '3.3201204330099717',
#    'explorer': 'https://etherscan.io/token/0x1d287cc25dad7ccaf76a26bc660c5f7c8e2a05bd'},
#   {'id': 'lido-dao',
#    'rank': '41',
#    'symbol': 'LDO',
#    'name': 'Lido DAO',
#    'supply': '891700325.0543096000000000',
#    'maxSupply': '1000000000.0000000000000000',
#    'marketCapUsd': '2575904405.5368750718862057',
#    'volumeUsd24Hr': '6980477.3290335748562962',
#    'priceUsd': '2.8887557099185625',
#    'changePercent24Hr': '-1.7590333622956092',
#    'vwap24Hr': '2.8814333905190393',
#    'explorer': 'https://etherscan.io/token/0x5a98fcbea516cf06857215779fd812ca3bef1b32'},
#   {'id': 'monero',
#    'rank': '42',
#    'symbol': 'XMR',
#    'name': 'Monero',
#    'supply': '18412233.1642821700000000',
#    'maxSupply': None,
#    'marketCapUsd': '2469686955.3249107466903661',
#    'volumeUsd24Hr': '27380524.4586769416971113',
#    'priceUsd': '134.1329394044307604',
#    'changePercent24Hr': '-1.5040315953081183',
#    'vwap24Hr': '135.5388018518847533',
#    'explorer': 'http://moneroblocks.info/'},
#   {'id': 'algorand',
#    'rank': '43',
#    'symbol': 'ALGO',
#    'name': 'Algorand',
#    'supply': '8066790016.0592870000000000',
#    'maxSupply': '10000000000.0000000000000000',
#    'marketCapUsd': '2267889899.9195391931835700',
#    'volumeUsd24Hr': '48888783.1171493785804253',
#    'priceUsd': '0.2811390770560094',
#    'changePercent24Hr': '3.3469850513683940',
#    'vwap24Hr': '0.2728310408530629',
#    'explorer': 'https://algoexplorer.io/'},
#   {'id': 'flow',
#    'rank': '44',
#    'symbol': 'FLOW',
#    'name': 'Flow',
#    'supply': '1494854696.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '2046755600.5664725770175896',
#    'volumeUsd24Hr': '25771437.8853370860772362',
#    'priceUsd': '1.3692003684660951',
#    'changePercent24Hr': '-1.7111019527283506',
#    'vwap24Hr': '1.3770295753113486',
#    'explorer': 'https://flowscan.org/'},
#   {'id': 'gala',
#    'rank': '45',
#    'symbol': 'GALA',
#    'name': 'Gala',
#    'supply': '29775512979.1718670000000000',
#    'maxSupply': None,
#    'marketCapUsd': '1961749403.6061158736062799',
#    'volumeUsd24Hr': '72755624.5585721320579639',
#    'priceUsd': '0.0658846551183978',
#    'changePercent24Hr': '-1.6883425215437572',
#    'vwap24Hr': '0.0664836925544903',
#    'explorer': 'https://ethplorer.io/es/address/0x15d4c048f83bd7e37d49ea4c83a07267ec4203da#chart=candlestick'},
#   {'id': 'aave',
#    'rank': '46',
#    'symbol': 'AAVE',
#    'name': 'Aave',
#    'supply': '14763809.3572999600000000',
#    'maxSupply': '16000000.0000000000000000',
#    'marketCapUsd': '1916129209.8165419340382777',
#    'volumeUsd24Hr': '44557628.3356708500249988',
#    'priceUsd': '129.7855562507052128',
#    'changePercent24Hr': '2.9061024766826533',
#    'vwap24Hr': '127.2271302475504053',
#    'explorer': 'https://etherscan.io/token/0x80fB784B7eD66730e8b1DBd9820aFD29931aab03'},
#   {'id': 'bitcoin-sv',
#    'rank': '47',
#    'symbol': 'BSV',
#    'name': 'Bitcoin SV',
#    'supply': '19664756.2500000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '1908625848.1646361115521056',
#    'volumeUsd24Hr': '27511513.9290879699508919',
#    'priceUsd': '97.0582001576874929',
#    'changePercent24Hr': '4.3884868346300274',
#    'vwap24Hr': '95.4387924487260552',
#    'explorer': 'https://bsvexplorer.io/'},
#   {'id': 'conflux-network',
#    'rank': '48',
#    'symbol': 'CFX',
#    'name': 'Conflux',
#    'supply': '3843897296.4700000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '1866464868.7269218369716218',
#    'volumeUsd24Hr': '54941084.4962830831030078',
#    'priceUsd': '0.4855657487105519',
#    'changePercent24Hr': '0.6639710194399671',
#    'vwap24Hr': '0.4793382876438748',
#    'explorer': 'http://www.confluxscan.io/'},
#   {'id': 'hedera-hashgraph',
#    'rank': '49',
#    'symbol': 'HBAR',
#    'name': 'Hedera Hashgraph',
#    'supply': '14832756028.0000000000000000',
#    'maxSupply': '50000000000.0000000000000000',
#    'marketCapUsd': '1746386629.0194469571035876',
#    'volumeUsd24Hr': '21522220.4528777810592748',
#    'priceUsd': '0.1177385123656567',
#    'changePercent24Hr': '1.9633860826124545',
#    'vwap24Hr': '0.1156069577531493',
#    'explorer': 'https://hash-hash.info/'},
#   {'id': 'singularitynet',
#    'rank': '50',
#    'symbol': 'AGIX',
#    'name': 'SingularityNET',
#    'supply': '1279380811.6426191000000000',
#    'maxSupply': '2000000000.0000000000000000',
#    'marketCapUsd': '1698314915.3502519117290593',
#    'volumeUsd24Hr': '10976453.4827476084254965',
#    'priceUsd': '1.3274506698046816',
#    'changePercent24Hr': '-3.3843079420206050',
#    'vwap24Hr': '1.3725586184963321',
#    'explorer': 'https://etherscan.io/token/0x8eb24319393716668d768dcec29356ae9cffe285'},
#   {'id': 'quant',
#    'rank': '51',
#    'symbol': 'QNT',
#    'name': 'Quant',
#    'supply': '12072738.0000000000000000',
#    'maxSupply': '14881364.0000000000000000',
#    'marketCapUsd': '1660891700.6934330036310998',
#    'volumeUsd24Hr': '12671420.1837409405078206',
#    'priceUsd': '137.5737385084835771',
#    'changePercent24Hr': '-1.3849444638937259',
#    'vwap24Hr': '138.1103414187033310',
#    'explorer': 'https://etherscan.io/token/0x4a220e6096b25eadb88358cb44068a3248254675'},
#   {'id': 'axie-infinity',
#    'rank': '52',
#    'symbol': 'AXS',
#    'name': 'Axie Infinity',
#    'supply': '142037746.2970986000000000',
#    'maxSupply': '270000000.0000000000000000',
#    'marketCapUsd': '1608041301.4704407389097324',
#    'volumeUsd24Hr': '26154648.9752247152162803',
#    'priceUsd': '11.3212251207289688',
#    'changePercent24Hr': '0.7366646930640508',
#    'vwap24Hr': '11.0968794094352839',
#    'explorer': 'https://etherscan.io/token/0xf5d669627376ebd411e34b98f19c868c8aba5ada'},
#   {'id': 'the-sandbox',
#    'rank': '53',
#    'symbol': 'SAND',
#    'name': 'The Sandbox',
#    'supply': '2251731926.2233224000000000',
#    'maxSupply': '3000000000.0000000000000000',
#    'marketCapUsd': '1605102016.9045855912160994',
#    'volumeUsd24Hr': '57430829.7547257393726965',
#    'priceUsd': '0.7128299768777159',
#    'changePercent24Hr': '2.9729058202174883',
#    'vwap24Hr': '0.6967385450715961',
#    'explorer': 'https://etherscan.io/token/0x3845badAde8e6dFF049820680d1F14bD3903a5d0'},
#   {'id': 'elrond-egld',
#    'rank': '54',
#    'symbol': 'EGLD',
#    'name': 'MultiversX',
#    'supply': '24184559.1898415400000000',
#    'maxSupply': '31415926.0000000000000000',
#    'marketCapUsd': '1483897526.8447095322684108',
#    'volumeUsd24Hr': '21537026.4399601502784150',
#    'priceUsd': '61.3572286017933494',
#    'changePercent24Hr': '0.3669913631047430',
#    'vwap24Hr': '60.7918788722871777',
#    'explorer': 'https://explorer.elrond.com/'},
#   {'id': 'tezos',
#    'rank': '55',
#    'symbol': 'XTZ',
#    'name': 'Tezos',
#    'supply': '974839642.9751710000000000',
#    'maxSupply': None,
#    'marketCapUsd': '1395290397.6801301233227725',
#    'volumeUsd24Hr': '27329889.5658904828448055',
#    'priceUsd': '1.4313024790639007',
#    'changePercent24Hr': '2.6580891488679689',
#    'vwap24Hr': '1.4101031628983988',
#    'explorer': 'https://tzkt.io/'},
#   {'id': 'ecash',
#    'rank': '56',
#    'symbol': 'XEC',
#    'name': 'eCash',
#    'supply': '19665554673092.0000000000000000',
#    'maxSupply': '21000000000000.0000000000000000',
#    'marketCapUsd': '1372550208.1093345678451048',
#    'volumeUsd24Hr': '36199383.6928359936006219',
#    'priceUsd': '0.0000697946348794',
#    'changePercent24Hr': '4.2880852746797358',
#    'vwap24Hr': '0.0000684386129026',
#    'explorer': 'https://explorer.bitcoinabc.org/'},
#   {'id': 'mina',
#    'rank': '57',
#    'symbol': 'MINA',
#    'name': 'Mina',
#    'supply': '1070802276.8400393000000000',
#    'maxSupply': None,
#    'marketCapUsd': '1332282770.8812883324268918',
#    'volumeUsd24Hr': '15719089.4073736062453484',
#    'priceUsd': '1.2441912010244166',
#    'changePercent24Hr': '-2.2588164549561339',
#    'vwap24Hr': '1.2496911898828664',
#    'explorer': 'https://minaexplorer.com/'},
#   {'id': 'chiliz',
#    'rank': '58',
#    'symbol': 'CHZ',
#    'name': 'Chiliz',
#    'supply': '8888290306.5249610000000000',
#    'maxSupply': '8888888888.0000000000000000',
#    'marketCapUsd': '1327724010.1793115725401710',
#    'volumeUsd24Hr': '36216918.1026875397582763',
#    'priceUsd': '0.1493790104048041',
#    'changePercent24Hr': '4.2684665309970103',
#    'vwap24Hr': '0.1446105636583750',
#    'explorer': 'https://etherscan.io/token/0x3506424f91fd33084466f402d5d97f05f8e3b4af'},
#   {'id': 'decentraland',
#    'rank': '59',
#    'symbol': 'MANA',
#    'name': 'Decentraland',
#    'supply': '1908319865.3915880000000000',
#    'maxSupply': None,
#    'marketCapUsd': '1302421435.4809910886050582',
#    'volumeUsd24Hr': '23081781.2502685380182334',
#    'priceUsd': '0.6824963985865827',
#    'changePercent24Hr': '1.5016955087627709',
#    'vwap24Hr': '0.6730908744097463',
#    'explorer': 'https://etherscan.io/token/decentraland'},
#   {'id': 'eos',
#    'rank': '60',
#    'symbol': 'EOS',
#    'name': 'EOS',
#    'supply': '1120460954.5722000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '1261223571.7781586311378203',
#    'volumeUsd24Hr': '106442379.9121904856881525',
#    'priceUsd': '1.1256292034377073',
#    'changePercent24Hr': '5.0757937021198898',
#    'vwap24Hr': '1.0990026442044155',
#    'explorer': 'https://bloks.io/'},
#   {'id': 'akash-network',
#    'rank': '61',
#    'symbol': 'AKT',
#    'name': 'Akash Network',
#    'supply': '230907433.3108150000000000',
#    'maxSupply': '388539008.0000000000000000',
#    'marketCapUsd': '1236014827.4867162236797840',
#    'volumeUsd24Hr': '1035858.4868561526576901',
#    'priceUsd': '5.3528585449346167',
#    'changePercent24Hr': '2.3493652793575394',
#    'vwap24Hr': '5.2895725443981907',
#    'explorer': 'https://akash.bigdipper.live/'},
#   {'id': 'kucoin-token',
#    'rank': '62',
#    'symbol': 'KCS',
#    'name': 'KuCoin Token',
#    'supply': '96287258.2890287500000000',
#    'maxSupply': '170118638.0000000000000000',
#    'marketCapUsd': '1161199182.4046015400624989',
#    'volumeUsd24Hr': '3540327.9280306657188402',
#    'priceUsd': '12.0597387758096748',
#    'changePercent24Hr': '-2.3298887577658471',
#    'vwap24Hr': '12.0779699879485631',
#    'explorer': 'https://etherscan.io/token/0xf34960d9d60be18cc1d5afc1a6f012a723a28811'},
#   {'id': 'neo',
#    'rank': '63',
#    'symbol': 'NEO',
#    'name': 'Neo',
#    'supply': '70538831.0000000000000000',
#    'maxSupply': '100000000.0000000000000000',
#    'marketCapUsd': '1161106241.1193093153228825',
#    'volumeUsd24Hr': '18063440.9933316802221338',
#    'priceUsd': '16.4605257084471575',
#    'changePercent24Hr': '3.1579670492755149',
#    'vwap24Hr': '16.0903273591481585',
#    'explorer': 'https://neotracker.io'},
#   {'id': 'pancakeswap',
#    'rank': '64',
#    'symbol': 'CAKE',
#    'name': 'PancakeSwap',
#    'supply': '244672128.8103295000000000',
#    'maxSupply': '450000000.0000000000000000',
#    'marketCapUsd': '1158550811.5833121953515018',
#    'volumeUsd24Hr': '42054270.1984213248241606',
#    'priceUsd': '4.7351155900614407',
#    'changePercent24Hr': '2.2858248798345900',
#    'vwap24Hr': '4.6710496997102762',
#    'explorer': 'https://bscscan.com/token/0x0e09fabb73bd3ade0a17ecc321fd13a19e81ce82'},
#   {'id': 'kava',
#    'rank': '65',
#    'symbol': 'KAVA',
#    'name': 'Kava',
#    'supply': '1082860636.0000000000000000',
#    'maxSupply': '1082860679.0000000000000000',
#    'marketCapUsd': '1156829089.5545709153315916',
#    'volumeUsd24Hr': '20245703.8874444325831046',
#    'priceUsd': '1.0683083779162981',
#    'changePercent24Hr': '4.9575933099256214',
#    'vwap24Hr': '1.0091832998731049',
#    'explorer': 'https://www.mintscan.io/kava'},
#   {'id': 'synthetix-network-token',
#    'rank': '66',
#    'symbol': 'SNX',
#    'name': 'Synthetix',
#    'supply': '233716733.4900000000000000',
#    'maxSupply': '212424133.0000000000000000',
#    'marketCapUsd': '1139358068.2956026119937197',
#    'volumeUsd24Hr': '33234841.8220817568614066',
#    'priceUsd': '4.8749529025244234',
#    'changePercent24Hr': '0.9247560356346191',
#    'vwap24Hr': '4.9294874691986024',
#    'explorer': 'https://etherscan.io/token/0xc011a72400e58ecd99ee497cf89e3775d4bd732f'},
#   {'id': 'iota',
#    'rank': '67',
#    'symbol': 'IOTA',
#    'name': 'IOTA',
#    'supply': '3172092163.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '1129916961.5161153150034395',
#    'volumeUsd24Hr': '11856883.4483703848559814',
#    'priceUsd': '0.3562055903342665',
#    'changePercent24Hr': '-0.4669517968639218',
#    'vwap24Hr': '0.3550471304373388',
#    'explorer': 'https://thetangle.org/'},
#   {'id': 'helium',
#    'rank': '68',
#    'symbol': 'HNT',
#    'name': 'Helium',
#    'supply': '160875441.8242133300000000',
#    'maxSupply': '223000000.0000000000000000',
#    'marketCapUsd': '1039661896.5236019489594978',
#    'volumeUsd24Hr': '4472670.9506196228182132',
#    'priceUsd': '6.4625270627671566',
#    'changePercent24Hr': '5.5797863968331873',
#    'vwap24Hr': '6.3664509575775912',
#    'explorer': 'https://explorer.helium.com/'},
#   {'id': 'pendle',
#    'rank': '69',
#    'symbol': 'PENDLE',
#    'name': 'Pendle',
#    'supply': '238185588.2446348700000000',
#    'maxSupply': '258446029.0000000000000000',
#    'marketCapUsd': '1015744897.5158085374171336',
#    'volumeUsd24Hr': '3339703.1564047534039248',
#    'priceUsd': '4.2645103131620231',
#    'changePercent24Hr': '4.8632434032283551',
#    'vwap24Hr': '4.2234032744986788',
#    'explorer': 'https://etherscan.io/token/0x808507121b80c02388fad14726482e061b8da827'},
#   {'id': 'gatetoken',
#    'rank': '70',
#    'symbol': 'GT',
#    'name': 'GateToken',
#    'supply': '96490073.1090052900000000',
#    'maxSupply': None,
#    'marketCapUsd': '1001127959.1611814741135339',
#    'volumeUsd24Hr': '42830149.1590394681206169',
#    'priceUsd': '10.3754503121808448',
#    'changePercent24Hr': '7.7803232733186019',
#    'vwap24Hr': '9.6855199571183012',
#    'explorer': None},
#   {'id': 'trueusd',
#    'rank': '71',
#    'symbol': 'TUSD',
#    'name': 'TrueUSD',
#    'supply': '988455467.0100000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '990243805.5626382633602858',
#    'volumeUsd24Hr': '9470503.7756084309259767',
#    'priceUsd': '1.0018092252127937',
#    'changePercent24Hr': '0.0338297063653497',
#    'vwap24Hr': '1.0028563166457052',
#    'explorer': 'https://etherscan.io/token/0x8dd5fbce2f6a956c3022ba3663759011dd51e73e'},
#   {'id': 'klaytn',
#    'rank': '72',
#    'symbol': 'KLAY',
#    'name': 'Klaytn',
#    'supply': '3569322484.4565535000000000',
#    'maxSupply': None,
#    'marketCapUsd': '977214737.0701571622591711',
#    'volumeUsd24Hr': '4924601.3746676004841352',
#    'priceUsd': '0.2737815765668881',
#    'changePercent24Hr': '1.5281875024144767',
#    'vwap24Hr': '0.2678027230954188',
#    'explorer': 'https://scope.klaytn.com/blocks'},
#   {'id': 'aioz-network',
#    'rank': '73',
#    'symbol': 'AIOZ',
#    'name': 'AIOZ Network',
#    'supply': '1080584737.2439904000000000',
#    'maxSupply': None,
#    'marketCapUsd': '942754562.5864782652474289',
#    'volumeUsd24Hr': '7826777.4980793234171550',
#    'priceUsd': '0.8724485272584497',
#    'changePercent24Hr': '-4.2001979742373395',
#    'vwap24Hr': '0.8951098958824851',
#    'explorer': 'https://etherscan.io/token/0x626e8036deb333b408be468f951bdb42433cbf18'},
#   {'id': 'gnosis-gno',
#    'rank': '74',
#    'symbol': 'GNO',
#    'name': 'Gnosis',
#    'supply': '2589588.0000000000000000',
#    'maxSupply': '3000000.0000000000000000',
#    'marketCapUsd': '940356673.2460548292037112',
#    'volumeUsd24Hr': '9204689.1579046647557178',
#    'priceUsd': '363.1298388956292774',
#    'changePercent24Hr': '-2.4787261134917984',
#    'vwap24Hr': '365.6340885178121342',
#    'explorer': 'https://etherscan.io/token/Gnosis'},
#   {'id': 'oasis-network',
#    'rank': '75',
#    'symbol': 'ROSE',
#    'name': 'Oasis Network',
#    'supply': '6713599876.0000000000000000',
#    'maxSupply': '10000000000.0000000000000000',
#    'marketCapUsd': '936397108.6692764692236828',
#    'volumeUsd24Hr': '13535491.0022359220055921',
#    'priceUsd': '0.1394776462649703',
#    'changePercent24Hr': '-1.3351881004566888',
#    'vwap24Hr': '0.1405228931825421',
#    'explorer': 'https://www.oasisscan.com/'},
#   {'id': 'ribbon-finance',
#    'rank': '76',
#    'symbol': 'RBN',
#    'name': 'Ribbon Finance',
#    'supply': '537093440.4611390000000000',
#    'maxSupply': None,
#    'marketCapUsd': '902296717.6177307865615101',
#    'volumeUsd24Hr': '4840366.7996562070391887',
#    'priceUsd': '1.6799622740561394',
#    'changePercent24Hr': '4.2526850601711785',
#    'vwap24Hr': '1.6565846400874635',
#    'explorer': 'https://etherscan.io/token/0x6123B0049F904d730dB3C36a31167D9d4121fA6B'},
#   {'id': 'wemix',
#    'rank': '77',
#    'symbol': 'WEMIX',
#    'name': 'WEMIX',
#    'supply': '365709618.3174209600000000',
#    'maxSupply': '980000000.0000000000000000',
#    'marketCapUsd': '857111137.5056860585744579',
#    'volumeUsd24Hr': '9635527.9399667696635964',
#    'priceUsd': '2.3436931777980986',
#    'changePercent24Hr': '-0.0540161574481335',
#    'vwap24Hr': '2.3213502090066253',
#    'explorer': 'https://scope.klaytn.com/token/0x5096db80b21ef45230c9e423c373f1fc9c0198dd?tabId=kctTransfer'},
#   {'id': 'nervos-network',
#    'rank': '78',
#    'symbol': 'CKB',
#    'name': 'Nervos Network',
#    'supply': '43772719517.4504200000000000',
#    'maxSupply': None,
#    'marketCapUsd': '847805809.5721558124102503',
#    'volumeUsd24Hr': '21700201.7161987870674633',
#    'priceUsd': '0.0193683604518602',
#    'changePercent24Hr': '-3.4068199565289764',
#    'vwap24Hr': '0.0195357652552166',
#    'explorer': 'https://explorer.nervos.org/'},
#   {'id': 'wootrade',
#    'rank': '79',
#    'symbol': 'WOO',
#    'name': 'WOO',
#    'supply': '1837867859.7621970000000000',
#    'maxSupply': None,
#    'marketCapUsd': '844408965.4751267899843101',
#    'volumeUsd24Hr': '12348177.9300444665386751',
#    'priceUsd': '0.4594503141180049',
#    'changePercent24Hr': '1.1041348843769875',
#    'vwap24Hr': '0.4587879031450060',
#    'explorer': 'https://etherscan.io/token/0x4691937a7508860f876c9c0a2a617e7d9e945d4b'},
#   {'id': 'curve-dao-token',
#    'rank': '80',
#    'symbol': 'CRV',
#    'name': 'Curve DAO Token',
#    'supply': '1156930125.0000000000000000',
#    'maxSupply': '3303030299.0000000000000000',
#    'marketCapUsd': '835375337.5674617415794250',
#    'volumeUsd24Hr': '7386910.6328378609467453',
#    'priceUsd': '0.7220620498298994',
#    'changePercent24Hr': '3.6984098883555987',
#    'vwap24Hr': '0.7017318151467260',
#    'explorer': 'https://etherscan.io/token/0xD533a949740bb3306d119CC777fa900bA034cd52'},
#   {'id': 'bitcoin-gold',
#    'rank': '81',
#    'symbol': 'BTG',
#    'name': 'Bitcoin Gold',
#    'supply': '17513923.5890000000000000',
#    'maxSupply': '21000000.0000000000000000',
#    'marketCapUsd': '827716299.8721046324020920',
#    'volumeUsd24Hr': '218801.2920099550856837',
#    'priceUsd': '47.2604722560266180',
#    'changePercent24Hr': '3.7525277860368385',
#    'vwap24Hr': '46.4306102860000543',
#    'explorer': 'https://explorer.bitcoingold.org/insight/'},
#   {'id': 'ocean-protocol',
#    'rank': '82',
#    'symbol': 'OCEAN',
#    'name': 'Ocean Protocol',
#    'supply': '568381102.7486407000000000',
#    'maxSupply': '1410000000.0000000000000000',
#    'marketCapUsd': '785912854.2952668761794590',
#    'volumeUsd24Hr': '76899214.5729187098160686',
#    'priceUsd': '1.3827216466111591',
#    'changePercent24Hr': '-5.1615991059544956',
#    'vwap24Hr': '1.4676410668709387',
#    'explorer': 'https://etherscan.io/token/0x7AFeBBB46fDb47ed17b22ed075Cde2447694fB9e'},
#   {'id': '0x',
#    'rank': '83',
#    'symbol': 'ZRX',
#    'name': '0x Protocol',
#    'supply': '847496054.8027713000000000',
#    'maxSupply': '1000000000.0000000000000000',
#    'marketCapUsd': '754152224.9331761970470589',
#    'volumeUsd24Hr': '73768196.9522776882021090',
#    'priceUsd': '0.8898592750484036',
#    'changePercent24Hr': '-17.4298130337218887',
#    'vwap24Hr': '0.9475385765608928',
#    'explorer': 'https://etherscan.io/token/ZRX'},
#   {'id': 'iotex',
#    'rank': '84',
#    'symbol': 'IOTX',
#    'name': 'IoTeX',
#    'supply': '9441378955.0000000000000000',
#    'maxSupply': '10000000000.0000000000000000',
#    'marketCapUsd': '752455432.9180112272685290',
#    'volumeUsd24Hr': '16209036.5202660716213184',
#    'priceUsd': '0.0796976200727038',
#    'changePercent24Hr': '1.3970031915387328',
#    'vwap24Hr': '0.0781164883074740',
#    'explorer': 'https://etherscan.io/token/0x6fb3e0a217407efff7ca062d46c26e5d60a14d69'},
#   {'id': 'nexo',
#    'rank': '85',
#    'symbol': 'NEXO',
#    'name': 'Nexo',
#    'supply': '560000011.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '751181194.6015884921226478',
#    'volumeUsd24Hr': '1362490.8068532893324286',
#    'priceUsd': '1.3413949640111498',
#    'changePercent24Hr': '-0.8392769355859919',
#    'vwap24Hr': '1.3370516454462332',
#    'explorer': 'https://etherscan.io/token/0xb62132e35a6c13ee1ee0f84dc5d40bad8d815206'},
#   {'id': 'enjin-coin',
#    'rank': '86',
#    'symbol': 'ENJ',
#    'name': 'Enjin Coin',
#    'supply': '1379841765.7600000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '694484703.8282194313959179',
#    'volumeUsd24Hr': '10778959.7449736735328608',
#    'priceUsd': '0.5033074958748663',
#    'changePercent24Hr': '0.1637079930722059',
#    'vwap24Hr': '0.4980923123571664',
#    'explorer': 'https://etherscan.io/token/0xf629cbd94d3791c9250152bd8dfbdf380e2a3b9c'},
#   {'id': '1inch',
#    'rank': '87',
#    'symbol': '1INCH',
#    'name': '1inch Network',
#    'supply': '1143723500.7828507000000000',
#    'maxSupply': None,
#    'marketCapUsd': '690438749.8350888404582769',
#    'volumeUsd24Hr': '19785269.4803471459622727',
#    'priceUsd': '0.6036762813411637',
#    'changePercent24Hr': '0.4804404096606310',
#    'vwap24Hr': '0.5991946994451972',
#    'explorer': 'https://etherscan.io/token/0x111111111117dc0aa78b770fa6a738034120c302'},
#   {'id': 'skale-network',
#    'rank': '88',
#    'symbol': 'SKL',
#    'name': 'SKALE',
#    'supply': '5179144337.0000000000000000',
#    'maxSupply': '7000000000.0000000000000000',
#    'marketCapUsd': '682194659.2888186184424997',
#    'volumeUsd24Hr': '53412560.2782200141524053',
#    'priceUsd': '0.1317195688900181',
#    'changePercent24Hr': '10.2900260052251051',
#    'vwap24Hr': '0.1184085512748301',
#    'explorer': 'https://etherscan.io/token/0x00c83aecc790e8a4453e5dd3b0b4b3680501a7a7'},
#   {'id': 'celo',
#    'rank': '89',
#    'symbol': 'CELO',
#    'name': 'Celo',
#    'supply': '530956100.0000000000000000',
#    'maxSupply': '1000000000.0000000000000000',
#    'marketCapUsd': '675093283.4502680562405100',
#    'volumeUsd24Hr': '11655707.1043263494577191',
#    'priceUsd': '1.2714672332614091',
#    'changePercent24Hr': '-2.2193094130029137',
#    'vwap24Hr': '1.2802216340900433',
#    'explorer': 'https://explorer.celo.org/blocks'},
#   {'id': 'superfarm',
#    'rank': '90',
#    'symbol': 'SUPER',
#    'name': 'SuperVerse',
#    'supply': '487776093.4169172600000000',
#    'maxSupply': '1000000000.0000000000000000',
#    'marketCapUsd': '672305706.0912256755979846',
#    'volumeUsd24Hr': '5910664.6366962650296063',
#    'priceUsd': '1.3783080293699127',
#    'changePercent24Hr': '2.6667384196714191',
#    'vwap24Hr': '1.3614596431675499',
#    'explorer': 'https://etherscan.io/token/0xe53ec727dbdeb9e2d5456c3be40cff031ab40a55'},
#   {'id': 'ravencoin',
#    'rank': '91',
#    'symbol': 'RVN',
#    'name': 'Ravencoin',
#    'supply': '13638061257.3639180000000000',
#    'maxSupply': '21000000000.0000000000000000',
#    'marketCapUsd': '662902754.0926387928557635',
#    'volumeUsd24Hr': '159822104.7243508039634495',
#    'priceUsd': '0.0486068174634941',
#    'changePercent24Hr': '39.3494651731203699',
#    'vwap24Hr': '0.0432877857586089',
#    'explorer': 'https://ravencoin.network/'},
#   {'id': 'compound',
#    'rank': '92',
#    'symbol': 'COMP',
#    'name': 'Compound',
#    'supply': '8094883.9148963500000000',
#    'maxSupply': '10000000.0000000000000000',
#    'marketCapUsd': '651580105.8920549843645375',
#    'volumeUsd24Hr': '31104167.0957464579913217',
#    'priceUsd': '80.4928288956689833',
#    'changePercent24Hr': '3.0663607739377934',
#    'vwap24Hr': '79.2033611858360503',
#    'explorer': 'https://etherscan.io/token/0xc00e94cb662c3520282e6f5717214004a7f26888'},
#   {'id': 'dydx',
#    'rank': '93',
#    'symbol': 'DYDX',
#    'name': 'dYdX',
#    'supply': '183765523.0000000000000000',
#    'maxSupply': '1000000000.0000000000000000',
#    'marketCapUsd': '647256614.8452222487091224',
#    'volumeUsd24Hr': '27881575.6330651226910395',
#    'priceUsd': '3.5221874281892488',
#    'changePercent24Hr': '2.1332968834307579',
#    'vwap24Hr': '3.4787714550649476',
#    'explorer': None},
#   {'id': 'zilliqa',
#    'rank': '94',
#    'symbol': 'ZIL',
#    'name': 'Zilliqa',
#    'supply': '17372203179.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '646108983.7152288787702488',
#    'volumeUsd24Hr': '22145778.1173554929116278',
#    'priceUsd': '0.0371921153038472',
#    'changePercent24Hr': '0.3039639301335561',
#    'vwap24Hr': '0.0367996283165552',
#    'explorer': 'https://etherscan.io/token/0x05f4a42e251f2d52b8ed15e9fedaacfcef1fad27'},
#   {'id': 'golem-network-tokens',
#    'rank': '95',
#    'symbol': 'GLM',
#    'name': 'Golem',
#    'supply': '1000000000.0000000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '639314661.6851494000000000',
#    'volumeUsd24Hr': '5426696.2924601481510023',
#    'priceUsd': '0.6393146616851494',
#    'changePercent24Hr': '7.4232615860498514',
#    'vwap24Hr': '0.6487672213343867',
#    'explorer': 'https://etherscan.io/token/Golem'},
#   {'id': 'ftx-token',
#    'rank': '96',
#    'symbol': 'FTT',
#    'name': 'FTX Token',
#    'supply': '328895103.8132070000000000',
#    'maxSupply': '352170015.0000000000000000',
#    'marketCapUsd': '632234100.7861646358201083',
#    'volumeUsd24Hr': '40838937.9750131195166618',
#    'priceUsd': '1.9222970894247069',
#    'changePercent24Hr': '-12.8188357408933342',
#    'vwap24Hr': '2.0054541388672770',
#    'explorer': 'https://etherscan.io/token/0x50d1c9771902476076ecfc8b2a83ad6b9355a4c9'},
#   {'id': 'rocket-pool',
#    'rank': '97',
#    'symbol': 'RPL',
#    'name': 'Rocket Pool',
#    'supply': '20217174.1801535400000000',
#    'maxSupply': None,
#    'marketCapUsd': '626891937.2292967636395169',
#    'volumeUsd24Hr': '775676.9076817041891927',
#    'priceUsd': '31.0078911940469720',
#    'changePercent24Hr': '-3.9387817646296936',
#    'vwap24Hr': '31.3048512616430348',
#    'explorer': 'https://etherscan.io/token/0xb4efd85c19999d84251304bda99e90b92300bd93'},
#   {'id': 'xinfin-network',
#    'rank': '98',
#    'symbol': 'XDC',
#    'name': 'XinFin Network',
#    'supply': '12293293518.5500000000000000',
#    'maxSupply': None,
#    'marketCapUsd': '617158519.0518956759589872',
#    'volumeUsd24Hr': '3208546.5002690545653388',
#    'priceUsd': '0.0502028620825357',
#    'changePercent24Hr': '1.5689393108174541',
#    'vwap24Hr': '0.0507950279982544',
#    'explorer': 'https://etherscan.io/token/0x41ab1b6fcbb2fa9dced81acbdec13ea6315f2bf2'},
#   {'id': 'mask-network',
#    'rank': '99',
#    'symbol': 'MASK',
#    'name': 'Mask Network',
#    'supply': '96025000.0000000000000000',
#    'maxSupply': '100000000.0000000000000000',
#    'marketCapUsd': '615650356.4692225478275000',
#    'volumeUsd24Hr': '177179987.1819319444408594',
#    'priceUsd': '6.4113549228765691',
#    'changePercent24Hr': '20.6894294838624456',
#    'vwap24Hr': '5.6332635503784981',
#    'explorer': 'https://etherscan.io/token/0x69af81e73a73b40adf4f3d4223cd9b1ece623074'},
#   {'id': 'frax-share',
#    'rank': '100',
#    'symbol': 'FXS',
#    'name': 'Frax Share',
#    'supply': '78569938.8041846500000000',
#    'maxSupply': None,
#    'marketCapUsd': '611941293.9818157896980802',
#    'volumeUsd24Hr': '573638.1333740584509145',
#    'priceUsd': '7.7884914166335545',
#    'changePercent24Hr': '1.0592082011696185',
#    'vwap24Hr': '7.6715208429580407',
#    'explorer': 'https://etherscan.io/token/0x3432b6a60d23ca0dfca7761b7ab56459d9c964d0'}],
#  'timestamp': 1711723088665}

# %%
getCryptoCurrencyRealTimeData("bitcoin")
# Out:
# {'data': {'id': 'bitcoin',
#   'rank': '1',
#   'symbol': 'BTC',
#   'name': 'Bitcoin',
#   'supply': '19658368.0000000000000000',
#   'maxSupply': '21000000.0000000000000000',
#   'marketCapUsd': '1384391894671.9349448302216576',
#   'volumeUsd24Hr': '8046840219.6769215210677368',
#   'priceUsd': '70422.5241216328306007',
#   'changePercent24Hr': '-1.2178332121447889',
#   'vwap24Hr': '70587.1399776516809779',
#   'explorer': 'https://blockchain.info/'},
#  'timestamp': 1711723088997}

# %% [markdown]
# According with the [API's documentation](https://docs.coincap.io/), this is what each column mean:
#
# | Key              | Description                                                                     |
# |------------------|---------------------------------------------------------------------------------|
# | id               | Unique identifier for asset                                                     |
# | rank             | Rank is in ascending order - this number is directly associated with the marketcap whereas the highest marketcap receives rank 1 |
# | symbol           | Most common symbol used to identify this asset on an exchange                   |
# | name             | Proper name for asset                                                           |
# | supply           | Available supply for trading                                                    |
# | maxSupply        | Total quantity of asset issued                                                  |
# | marketCapUsd     | Supply multiplied by price                                                      |
# | volumeUsd24Hr    | Quantity of trading volume represented in USD over the last 24 hours            |
# | priceUsd         | Volume-weighted price based on real-time market data, translated to USD          |
# | changePercent24Hr| The direction and value change in the last 24 hours                              |
# | vwap24Hr         | Volume Weighted Average Price in the last 24 hours                               |

# %% [markdown]
# ## Get real-time data history within a period

# %%
def getCryptoCurrencyDataWithinPeriod(asset: str, interval: str):
  try:
    res = requests.get(API_URL + f'/assets/{asset}/history?interval={interval}')
    print(res)
    if res.status_code == 200:
      return res.json()
    else:
      print(f'Error: {res.status_code}')
  except requests.exceptions.RequestException as err:
    print(f'Error: {err}')

# %%
getCryptoCurrencyDataWithinPeriod("bitcoin","d1")
# Out:
# <Response [200]>
# {'data': [{'priceUsd': '28240.9604785536354686',
#    'time': 1680220800000,
#    'date': '2023-03-31T00:00:00.000Z'},
#   {'priceUsd': '28503.4131407150636311',
#    'time': 1680307200000,
#    'date': '2023-04-01T00:00:00.000Z'},
#   {'priceUsd': '28348.9536914941676999',
#    'time': 1680393600000,
#    'date': '2023-04-02T00:00:00.000Z'},
#   {'priceUsd': '28022.5329918991818367',
#    'time': 1680480000000,
#    'date': '2023-04-03T00:00:00.000Z'},
#   {'priceUsd': '28109.3957987353541417',
#    'time': 1680566400000,
#    'date': '2023-04-04T00:00:00.000Z'},
#   {'priceUsd': '28388.4814692914645986',
#    'time': 1680652800000,
#    'date': '2023-04-05T00:00:00.000Z'},
#   {'priceUsd': '28069.0058759817607304',
#    'time': 1680739200000,
#    'date': '2023-04-06T00:00:00.000Z'},
#   {'priceUsd': '27990.5747619648380118',
#    'time': 1680825600000,
#    'date': '2023-04-07T00:00:00.000Z'},
#   {'priceUsd': '28089.6538928897815714',
#    'time': 1680912000000,
#    'date': '2023-04-08T00:00:00.000Z'},
#   {'priceUsd': '28140.6397728016233982',
#    'time': 1680998400000,
#    'date': '2023-04-09T00:00:00.000Z'},
#   {'priceUsd': '28645.1442691189378943',
#    'time': 1681084800000,
#    'date': '2023-04-10T00:00:00.000Z'},
#   {'priceUsd': '30144.7338213132436418',
#    'time': 1681171200000,
#    'date': '2023-04-11T00:00:00.000Z'},
#   {'priceUsd': '30039.7781101534723216',
#    'time': 1681257600000,
#    'date': '2023-04-12T00:00:00.000Z'},
#   {'priceUsd': '30292.1687100302474579',
#    'time': 1681344000000,
#    'date': '2023-04-13T00:00:00.000Z'},
#   {'priceUsd': '30650.6777384198965982',
#    'time': 1681430400000,
#    'date': '2023-04-14T00:00:00.000Z'},
#   {'priceUsd': '30434.8639371663871582',
#    'time': 1681516800000,
#    'date': '2023-04-15T00:00:00.000Z'},
#   {'priceUsd': '30393.8554698417893432',
#    'time': 1681603200000,
#    'date': '2023-04-16T00:00:00.000Z'},
#   {'priceUsd': '29735.3273542551182441',
#    'time': 1681689600000,
#    'date': '2023-04-17T00:00:00.000Z'},
#   {'priceUsd': '29980.3234918104349582',
#    'time': 1681776000000,
#    'date': '2023-04-18T00:00:00.000Z'},
#   {'priceUsd': '29599.2320278270652858',
#    'time': 1681862400000,
#    'date': '2023-04-19T00:00:00.000Z'},
#   {'priceUsd': '28693.5871089640283995',
#    'time': 1681948800000,
#    'date': '2023-04-20T00:00:00.000Z'},
#   {'priceUsd': '27989.4523414564250888',
#    'time': 1682035200000,
#    'date': '2023-04-21T00:00:00.000Z'},
#   {'priceUsd': '27514.0917220757787835',
#    'time': 1682121600000,
#    'date': '2023-04-22T00:00:00.000Z'},
#   {'priceUsd': '27697.6193626705667123',
#    'time': 1682208000000,
#    'date': '2023-04-23T00:00:00.000Z'},
#   {'priceUsd': '27571.8147575613960808',
#    'time': 1682294400000,
#    'date': '2023-04-24T00:00:00.000Z'},
#   {'priceUsd': '27583.3504320693820584',
#    'time': 1682380800000,
#    'date': '2023-04-25T00:00:00.000Z'},
#   {'priceUsd': '28875.2734589306436740',
#    'time': 1682467200000,
#    'date': '2023-04-26T00:00:00.000Z'},
#   {'priceUsd': '29169.9905443212808708',
#    'time': 1682553600000,
#    'date': '2023-04-27T00:00:00.000Z'},
#   {'priceUsd': '29360.8496777050860638',
#    'time': 1682640000000,
#    'date': '2023-04-28T00:00:00.000Z'},
#   {'priceUsd': '29400.2775133618514419',
#    'time': 1682726400000,
#    'date': '2023-04-29T00:00:00.000Z'},
#   {'priceUsd': '29482.7793309489858169',
#    'time': 1682812800000,
#    'date': '2023-04-30T00:00:00.000Z'},
#   {'priceUsd': '28480.6684927539377623',
#    'time': 1682899200000,
#    'date': '2023-05-01T00:00:00.000Z'},
#   {'priceUsd': '28305.9784040535584856',
#    'time': 1682985600000,
#    'date': '2023-05-02T00:00:00.000Z'},
#   {'priceUsd': '28610.5412483375626674',
#    'time': 1683072000000,
#    'date': '2023-05-03T00:00:00.000Z'},
#   {'priceUsd': '29021.6970269700923502',
#    'time': 1683158400000,
#    'date': '2023-05-04T00:00:00.000Z'},
#   {'priceUsd': '29307.2147017422079682',
#    'time': 1683244800000,
#    'date': '2023-05-05T00:00:00.000Z'},
#   {'priceUsd': '29274.1760660042434561',
#    'time': 1683331200000,
#    'date': '2023-05-06T00:00:00.000Z'},
#   {'priceUsd': '29043.8697650102163587',
#    'time': 1683417600000,
#    'date': '2023-05-07T00:00:00.000Z'},
#   {'priceUsd': '28012.1958023564619499',
#    'time': 1683504000000,
#    'date': '2023-05-08T00:00:00.000Z'},
#   {'priceUsd': '27673.4221659808497250',
#    'time': 1683590400000,
#    'date': '2023-05-09T00:00:00.000Z'},
#   {'priceUsd': '27762.6623411514198371',
#    'time': 1683676800000,
#    'date': '2023-05-10T00:00:00.000Z'},
#   {'priceUsd': '27307.2347387629391758',
#    'time': 1683763200000,
#    'date': '2023-05-11T00:00:00.000Z'},
#   {'priceUsd': '26523.1284778230188642',
#    'time': 1683849600000,
#    'date': '2023-05-12T00:00:00.000Z'},
#   {'priceUsd': '26896.0815183706594169',
#    'time': 1683936000000,
#    'date': '2023-05-13T00:00:00.000Z'},
#   {'priceUsd': '26926.7558515533275456',
#    'time': 1684022400000,
#    'date': '2023-05-14T00:00:00.000Z'},
#   {'priceUsd': '27339.9820751478798675',
#    'time': 1684108800000,
#    'date': '2023-05-15T00:00:00.000Z'},
#   {'priceUsd': '27081.4480564020283787',
#    'time': 1684195200000,
#    'date': '2023-05-16T00:00:00.000Z'},
#   {'priceUsd': '27011.0568221391760637',
#    'time': 1684281600000,
#    'date': '2023-05-17T00:00:00.000Z'},
#   {'priceUsd': '27155.4262555060583744',
#    'time': 1684368000000,
#    'date': '2023-05-18T00:00:00.000Z'},
#   {'priceUsd': '26873.9850308907029237',
#    'time': 1684454400000,
#    'date': '2023-05-19T00:00:00.000Z'},
#   {'priceUsd': '26955.6689536055746336',
#    'time': 1684540800000,
#    'date': '2023-05-20T00:00:00.000Z'},
#   {'priceUsd': '26987.7819028325305641',
#    'time': 1684627200000,
#    'date': '2023-05-21T00:00:00.000Z'},
#   {'priceUsd': '26818.8643382866466116',
#    'time': 1684713600000,
#    'date': '2023-05-22T00:00:00.000Z'},
#   {'priceUsd': '27253.2635210140161639',
#    'time': 1684800000000,
#    'date': '2023-05-23T00:00:00.000Z'},
#   {'priceUsd': '26628.1357072600056109',
#    'time': 1684886400000,
#    'date': '2023-05-24T00:00:00.000Z'},
#   {'priceUsd': '26305.3007797090265223',
#    'time': 1684972800000,
#    'date': '2023-05-25T00:00:00.000Z'},
#   {'priceUsd': '26578.9597929258862306',
#    'time': 1685059200000,
#    'date': '2023-05-26T00:00:00.000Z'},
#   {'priceUsd': '26728.6316336335670061',
#    'time': 1685145600000,
#    'date': '2023-05-27T00:00:00.000Z'},
#   {'priceUsd': '27305.3452724645652638',
#    'time': 1685232000000,
#    'date': '2023-05-28T00:00:00.000Z'},
#   {'priceUsd': '27862.8275891200714598',
#    'time': 1685318400000,
#    'date': '2023-05-29T00:00:00.000Z'},
#   {'priceUsd': '27799.5587363620457328',
#    'time': 1685404800000,
#    'date': '2023-05-30T00:00:00.000Z'},
#   {'priceUsd': '27236.2075146675573982',
#    'time': 1685491200000,
#    'date': '2023-05-31T00:00:00.000Z'},
#   {'priceUsd': '26934.8017157384688131',
#    'time': 1685577600000,
#    'date': '2023-06-01T00:00:00.000Z'},
#   {'priceUsd': '27090.6745121911658697',
#    'time': 1685664000000,
#    'date': '2023-06-02T00:00:00.000Z'},
#   {'priceUsd': '27178.7232129039627469',
#    'time': 1685750400000,
#    'date': '2023-06-03T00:00:00.000Z'},
#   {'priceUsd': '27189.6598551795523701',
#    'time': 1685836800000,
#    'date': '2023-06-04T00:00:00.000Z'},
#   {'priceUsd': '26458.1576646589126630',
#    'time': 1685923200000,
#    'date': '2023-06-05T00:00:00.000Z'},
#   {'priceUsd': '26129.3111591056609014',
#    'time': 1686009600000,
#    'date': '2023-06-06T00:00:00.000Z'},
#   {'priceUsd': '26720.3553223378340561',
#    'time': 1686096000000,
#    'date': '2023-06-07T00:00:00.000Z'},
#   {'priceUsd': '26495.8343757687501609',
#    'time': 1686182400000,
#    'date': '2023-06-08T00:00:00.000Z'},
#   {'priceUsd': '26538.9702969847713147',
#    'time': 1686268800000,
#    'date': '2023-06-09T00:00:00.000Z'},
#   {'priceUsd': '25894.2170781330051201',
#    'time': 1686355200000,
#    'date': '2023-06-10T00:00:00.000Z'},
#   {'priceUsd': '25903.2390325000871091',
#    'time': 1686441600000,
#    'date': '2023-06-11T00:00:00.000Z'},
#   {'priceUsd': '25902.5208857331035753',
#    'time': 1686528000000,
#    'date': '2023-06-12T00:00:00.000Z'},
#   {'priceUsd': '26010.0722911230186964',
#    'time': 1686614400000,
#    'date': '2023-06-13T00:00:00.000Z'},
#   {'priceUsd': '25848.2449122047394167',
#    'time': 1686700800000,
#    'date': '2023-06-14T00:00:00.000Z'},
#   {'priceUsd': '25118.2129299484302041',
#    'time': 1686787200000,
#    'date': '2023-06-15T00:00:00.000Z'},
#   {'priceUsd': '25779.0451053741975048',
#    'time': 1686873600000,
#    'date': '2023-06-16T00:00:00.000Z'},
#   {'priceUsd': '26499.4431965284123932',
#    'time': 1686960000000,
#    'date': '2023-06-17T00:00:00.000Z'},
#   {'priceUsd': '26576.9131429623725830',
#    'time': 1687046400000,
#    'date': '2023-06-18T00:00:00.000Z'},
#   {'priceUsd': '26530.5790877017900706',
#    'time': 1687132800000,
#    'date': '2023-06-19T00:00:00.000Z'},
#   {'priceUsd': '27191.1124554268946774',
#    'time': 1687219200000,
#    'date': '2023-06-20T00:00:00.000Z'},
#   {'priceUsd': '29250.0900894396389465',
#    'time': 1687305600000,
#    'date': '2023-06-21T00:00:00.000Z'},
#   {'priceUsd': '30076.9881784360109979',
#    'time': 1687392000000,
#    'date': '2023-06-22T00:00:00.000Z'},
#   {'priceUsd': '30331.4280335901839315',
#    'time': 1687478400000,
#    'date': '2023-06-23T00:00:00.000Z'},
#   {'priceUsd': '30648.9290773959818333',
#    'time': 1687564800000,
#    'date': '2023-06-24T00:00:00.000Z'},
#   {'priceUsd': '30641.1924404527579699',
#    'time': 1687651200000,
#    'date': '2023-06-25T00:00:00.000Z'},
#   {'priceUsd': '30290.2076445941653384',
#    'time': 1687737600000,
#    'date': '2023-06-26T00:00:00.000Z'},
#   {'priceUsd': '30552.7981056875506234',
#    'time': 1687824000000,
#    'date': '2023-06-27T00:00:00.000Z'},
#   {'priceUsd': '30312.5439578440851164',
#    'time': 1687910400000,
#    'date': '2023-06-28T00:00:00.000Z'},
#   {'priceUsd': '30411.9233852278433866',
#    'time': 1687996800000,
#    'date': '2023-06-29T00:00:00.000Z'},
#   {'priceUsd': '30573.5636669455804196',
#    'time': 1688083200000,
#    'date': '2023-06-30T00:00:00.000Z'},
#   {'priceUsd': '30519.9335697349331812',
#    'time': 1688169600000,
#    'date': '2023-07-01T00:00:00.000Z'},
#   {'priceUsd': '30561.6882488573282100',
#    'time': 1688256000000,
#    'date': '2023-07-02T00:00:00.000Z'},
#   {'priceUsd': '30831.7341380762814073',
#    'time': 1688342400000,
#    'date': '2023-07-03T00:00:00.000Z'},
#   {'priceUsd': '30997.7300350900505459',
#    'time': 1688428800000,
#    'date': '2023-07-04T00:00:00.000Z'},
#   {'priceUsd': '30611.0546255291806892',
#    'time': 1688515200000,
#    'date': '2023-07-05T00:00:00.000Z'},
#   {'priceUsd': '30526.9556091448293380',
#    'time': 1688601600000,
#    'date': '2023-07-06T00:00:00.000Z'},
#   {'priceUsd': '30205.6444368176208664',
#    'time': 1688688000000,
#    'date': '2023-07-07T00:00:00.000Z'},
#   {'priceUsd': '30256.2745307334418754',
#    'time': 1688774400000,
#    'date': '2023-07-08T00:00:00.000Z'},
#   {'priceUsd': '30307.3076639148772146',
#    'time': 1688860800000,
#    'date': '2023-07-09T00:00:00.000Z'},
#   {'priceUsd': '30283.8862485422843191',
#    'time': 1688947200000,
#    'date': '2023-07-10T00:00:00.000Z'},
#   {'priceUsd': '30519.8890693370755967',
#    'time': 1689033600000,
#    'date': '2023-07-11T00:00:00.000Z'},
#   {'priceUsd': '30601.4490775432855811',
#    'time': 1689120000000,
#    'date': '2023-07-12T00:00:00.000Z'},
#   {'priceUsd': '30733.1142765322879841',
#    'time': 1689206400000,
#    'date': '2023-07-13T00:00:00.000Z'},
#   {'priceUsd': '31028.6314871212227586',
#    'time': 1689292800000,
#    'date': '2023-07-14T00:00:00.000Z'},
#   {'priceUsd': '30357.2079754463762817',
#    'time': 1689379200000,
#    'date': '2023-07-15T00:00:00.000Z'},
#   {'priceUsd': '30353.9990090120557902',
#    'time': 1689465600000,
#    'date': '2023-07-16T00:00:00.000Z'},
#   {'priceUsd': '30213.3789577714659458',
#    'time': 1689552000000,
#    'date': '2023-07-17T00:00:00.000Z'},
#   {'priceUsd': '29977.0992342493234124',
#    'time': 1689638400000,
#    'date': '2023-07-18T00:00:00.000Z'},
#   {'priceUsd': '30011.8872166318353992',
#    'time': 1689724800000,
#    'date': '2023-07-19T00:00:00.000Z'},
#   {'priceUsd': '30023.1559018313651546',
#    'time': 1689811200000,
#    'date': '2023-07-20T00:00:00.000Z'},
#   {'priceUsd': '29880.5254300118545855',
#    'time': 1689897600000,
#    'date': '2023-07-21T00:00:00.000Z'},
#   {'priceUsd': '29913.6143500216032869',
#    'time': 1689984000000,
#    'date': '2023-07-22T00:00:00.000Z'},
#   {'priceUsd': '29985.5024893939962183',
#    'time': 1690070400000,
#    'date': '2023-07-23T00:00:00.000Z'},
#   {'priceUsd': '29472.1474647005832902',
#    'time': 1690156800000,
#    'date': '2023-07-24T00:00:00.000Z'},
#   {'priceUsd': '29204.0492745381253884',
#    'time': 1690243200000,
#    'date': '2023-07-25T00:00:00.000Z'},
#   {'priceUsd': '29304.4661085451208628',
#    'time': 1690329600000,
#    'date': '2023-07-26T00:00:00.000Z'},
#   {'priceUsd': '29373.0641345634279093',
#    'time': 1690416000000,
#    'date': '2023-07-27T00:00:00.000Z'},
#   {'priceUsd': '29277.9995244746840846',
#    'time': 1690502400000,
#    'date': '2023-07-28T00:00:00.000Z'},
#   {'priceUsd': '29358.8160738782921644',
#    'time': 1690588800000,
#    'date': '2023-07-29T00:00:00.000Z'},
#   {'priceUsd': '29348.7109283422096871',
#    'time': 1690675200000,
#    'date': '2023-07-30T00:00:00.000Z'},
#   {'priceUsd': '29346.3547882488295488',
#    'time': 1690761600000,
#    'date': '2023-07-31T00:00:00.000Z'},
#   {'priceUsd': '29024.8796937471207170',
#    'time': 1690848000000,
#    'date': '2023-08-01T00:00:00.000Z'},
#   {'priceUsd': '29435.9107486407214418',
#    'time': 1690934400000,
#    'date': '2023-08-02T00:00:00.000Z'},
#   {'priceUsd': '29178.8610013741602034',
#    'time': 1691020800000,
#    'date': '2023-08-03T00:00:00.000Z'},
#   {'priceUsd': '29166.1970816610706998',
#    'time': 1691107200000,
#    'date': '2023-08-04T00:00:00.000Z'},
#   {'priceUsd': '29076.6102331162330878',
#    'time': 1691193600000,
#    'date': '2023-08-05T00:00:00.000Z'},
#   {'priceUsd': '29089.5837685994929229',
#    'time': 1691280000000,
#    'date': '2023-08-06T00:00:00.000Z'},
#   {'priceUsd': '29071.9605202236879330',
#    'time': 1691366400000,
#    'date': '2023-08-07T00:00:00.000Z'},
#   {'priceUsd': '29451.0061363304197404',
#    'time': 1691452800000,
#    'date': '2023-08-08T00:00:00.000Z'},
#   {'priceUsd': '29709.9547782023410143',
#    'time': 1691539200000,
#    'date': '2023-08-09T00:00:00.000Z'},
#   {'priceUsd': '29497.2999652918718355',
#    'time': 1691625600000,
#    'date': '2023-08-10T00:00:00.000Z'},
#   {'priceUsd': '29397.4821589846689379',
#    'time': 1691712000000,
#    'date': '2023-08-11T00:00:00.000Z'},
#   {'priceUsd': '29425.9587746108491754',
#    'time': 1691798400000,
#    'date': '2023-08-12T00:00:00.000Z'},
#   {'priceUsd': '29408.9912267162156710',
#    'time': 1691884800000,
#    'date': '2023-08-13T00:00:00.000Z'},
#   {'priceUsd': '29386.5392227606320752',
#    'time': 1691971200000,
#    'date': '2023-08-14T00:00:00.000Z'},
#   {'priceUsd': '29321.7098058078183624',
#    'time': 1692057600000,
#    'date': '2023-08-15T00:00:00.000Z'},
#   {'priceUsd': '29112.5222954964648562',
#    'time': 1692144000000,
#    'date': '2023-08-16T00:00:00.000Z'},
#   {'priceUsd': '28196.2269621538203570',
#    'time': 1692230400000,
#    'date': '2023-08-17T00:00:00.000Z'},
#   {'priceUsd': '26325.8736729156684410',
#    'time': 1692316800000,
#    'date': '2023-08-18T00:00:00.000Z'},
#   {'priceUsd': '26040.4555011756934265',
#    'time': 1692403200000,
#    'date': '2023-08-19T00:00:00.000Z'},
#   {'priceUsd': '26169.6683130664172812',
#    'time': 1692489600000,
#    'date': '2023-08-20T00:00:00.000Z'},
#   {'priceUsd': '26086.8708467624457058',
#    'time': 1692576000000,
#    'date': '2023-08-21T00:00:00.000Z'},
#   {'priceUsd': '25996.1678558690215052',
#    'time': 1692662400000,
#    'date': '2023-08-22T00:00:00.000Z'},
#   {'priceUsd': '26182.3974386279154810',
#    'time': 1692748800000,
#    'date': '2023-08-23T00:00:00.000Z'},
#   {'priceUsd': '26300.1973186642227508',
#    'time': 1692835200000,
#    'date': '2023-08-24T00:00:00.000Z'},
#   {'priceUsd': '26066.1381557210542763',
#    'time': 1692921600000,
#    'date': '2023-08-25T00:00:00.000Z'},
#   {'priceUsd': '26061.5780512258384801',
#    'time': 1693008000000,
#    'date': '2023-08-26T00:00:00.000Z'},
#   {'priceUsd': '26103.9787671058646142',
#    'time': 1693094400000,
#    'date': '2023-08-27T00:00:00.000Z'},
#   {'priceUsd': '26047.4301031244520170',
#    'time': 1693180800000,
#    'date': '2023-08-28T00:00:00.000Z'},
#   {'priceUsd': '26708.7388216107508114',
#    'time': 1693267200000,
#    'date': '2023-08-29T00:00:00.000Z'},
#   {'priceUsd': '27362.3057766821912755',
#    'time': 1693353600000,
#    'date': '2023-08-30T00:00:00.000Z'},
#   {'priceUsd': '26887.8176361001758242',
#    'time': 1693440000000,
#    'date': '2023-08-31T00:00:00.000Z'},
#   {'priceUsd': '25912.0303471176786984',
#    'time': 1693526400000,
#    'date': '2023-09-01T00:00:00.000Z'},
#   {'priceUsd': '25878.3858105495857011',
#    'time': 1693612800000,
#    'date': '2023-09-02T00:00:00.000Z'},
#   {'priceUsd': '25969.5502360120592645',
#    'time': 1693699200000,
#    'date': '2023-09-03T00:00:00.000Z'},
#   {'priceUsd': '25908.6767757674315272',
#    'time': 1693785600000,
#    'date': '2023-09-04T00:00:00.000Z'},
#   {'priceUsd': '25733.2722925631518065',
#    'time': 1693872000000,
#    'date': '2023-09-05T00:00:00.000Z'},
#   {'priceUsd': '25727.0012144723375560',
#    'time': 1693958400000,
#    'date': '2023-09-06T00:00:00.000Z'},
#   {'priceUsd': '25839.0158231695259869',
#    'time': 1694044800000,
#    'date': '2023-09-07T00:00:00.000Z'},
#   {'priceUsd': '26030.2478072764390064',
#    'time': 1694131200000,
#    'date': '2023-09-08T00:00:00.000Z'},
#   {'priceUsd': '25898.2892609457348544',
#    'time': 1694217600000,
#    'date': '2023-09-09T00:00:00.000Z'},
#   {'priceUsd': '25858.6944030609274382',
#    'time': 1694304000000,
#    'date': '2023-09-10T00:00:00.000Z'},
#   {'priceUsd': '25511.7752750638237807',
#    'time': 1694390400000,
#    'date': '2023-09-11T00:00:00.000Z'},
#   {'priceUsd': '25879.1768348288589738',
#    'time': 1694476800000,
#    'date': '2023-09-12T00:00:00.000Z'},
#   {'priceUsd': '26096.8788628015324588',
#    'time': 1694563200000,
#    'date': '2023-09-13T00:00:00.000Z'},
#   {'priceUsd': '26446.3362929297572705',
#    'time': 1694649600000,
#    'date': '2023-09-14T00:00:00.000Z'},
#   {'priceUsd': '26510.4314351716293025',
#    'time': 1694736000000,
#    'date': '2023-09-15T00:00:00.000Z'},
#   {'priceUsd': '26577.1922340030258502',
#    'time': 1694822400000,
#    'date': '2023-09-16T00:00:00.000Z'},
#   {'priceUsd': '26555.0321941269644673',
#    'time': 1694908800000,
#    'date': '2023-09-17T00:00:00.000Z'},
#   {'priceUsd': '26864.2172945820459788',
#    'time': 1694995200000,
#    'date': '2023-09-18T00:00:00.000Z'},
#   {'priceUsd': '27054.3847558361218322',
#    'time': 1695081600000,
#    'date': '2023-09-19T00:00:00.000Z'},
#   {'priceUsd': '27132.7386852925797623',
#    'time': 1695168000000,
#    'date': '2023-09-20T00:00:00.000Z'},
#   {'priceUsd': '26783.6390291869927454',
#    'time': 1695254400000,
#    'date': '2023-09-21T00:00:00.000Z'},
#   {'priceUsd': '26624.8625680721836917',
#    'time': 1695340800000,
#    'date': '2023-09-22T00:00:00.000Z'},
#   {'priceUsd': '26614.3694697262163558',
#    'time': 1695427200000,
#    'date': '2023-09-23T00:00:00.000Z'},
#   {'priceUsd': '26617.3911735338932169',
#    'time': 1695513600000,
#    'date': '2023-09-24T00:00:00.000Z'},
#   {'priceUsd': '26217.4358905877166737',
#    'time': 1695600000000,
#    'date': '2023-09-25T00:00:00.000Z'},
#   {'priceUsd': '26248.0193562106946221',
#    'time': 1695686400000,
#    'date': '2023-09-26T00:00:00.000Z'},
#   {'priceUsd': '26321.9361321909366204',
#    'time': 1695772800000,
#    'date': '2023-09-27T00:00:00.000Z'},
#   {'priceUsd': '26670.8377093458274102',
#    'time': 1695859200000,
#    'date': '2023-09-28T00:00:00.000Z'},
#   {'priceUsd': '26962.0268756516319905',
#    'time': 1695945600000,
#    'date': '2023-09-29T00:00:00.000Z'},
#   {'priceUsd': '26986.2881351848382115',
#    'time': 1696032000000,
#    'date': '2023-09-30T00:00:00.000Z'},
#   {'priceUsd': '27186.3576570406634493',
#    'time': 1696118400000,
#    'date': '2023-10-01T00:00:00.000Z'},
#   {'priceUsd': '28052.2728035314008618',
#    'time': 1696204800000,
#    'date': '2023-10-02T00:00:00.000Z'},
#   {'priceUsd': '27487.8722015619162402',
#    'time': 1696291200000,
#    'date': '2023-10-03T00:00:00.000Z'},
#   {'priceUsd': '27521.1704964166629634',
#    'time': 1696377600000,
#    'date': '2023-10-04T00:00:00.000Z'},
#   {'priceUsd': '27646.4225242068473924',
#    'time': 1696464000000,
#    'date': '2023-10-05T00:00:00.000Z'},
#   {'priceUsd': '27723.4267189845388261',
#    'time': 1696550400000,
#    'date': '2023-10-06T00:00:00.000Z'},
#   {'priceUsd': '27974.0368162355534056',
#    'time': 1696636800000,
#    'date': '2023-10-07T00:00:00.000Z'},
#   {'priceUsd': '27977.0713012788858468',
#    'time': 1696723200000,
#    'date': '2023-10-08T00:00:00.000Z'},
#   {'priceUsd': '27705.0786874915061576',
#    'time': 1696809600000,
#    'date': '2023-10-09T00:00:00.000Z'},
#   {'priceUsd': '27546.9373410252341725',
#    'time': 1696896000000,
#    'date': '2023-10-10T00:00:00.000Z'},
#   {'priceUsd': '27039.8786177970951217',
#    'time': 1696982400000,
#    'date': '2023-10-11T00:00:00.000Z'},
#   {'priceUsd': '26781.2977671380416781',
#    'time': 1697068800000,
#    'date': '2023-10-12T00:00:00.000Z'},
#   {'priceUsd': '26829.7786353395618383',
#    'time': 1697155200000,
#    'date': '2023-10-13T00:00:00.000Z'},
#   {'priceUsd': '26905.3950924400433811',
#    'time': 1697241600000,
#    'date': '2023-10-14T00:00:00.000Z'},
#   {'priceUsd': '26978.4430744588506102',
#    'time': 1697328000000,
#    'date': '2023-10-15T00:00:00.000Z'},
#   {'priceUsd': '27920.0497840546018590',
#    'time': 1697414400000,
#    'date': '2023-10-16T00:00:00.000Z'},
#   {'priceUsd': '28406.5070062175288549',
#    'time': 1697500800000,
#    'date': '2023-10-17T00:00:00.000Z'},
#   {'priceUsd': '28425.9390384788394190',
#    'time': 1697587200000,
#    'date': '2023-10-18T00:00:00.000Z'},
#   {'priceUsd': '28501.6212051095234723',
#    'time': 1697673600000,
#    'date': '2023-10-19T00:00:00.000Z'},
#   {'priceUsd': '29441.7760382822791118',
#    'time': 1697760000000,
#    'date': '2023-10-20T00:00:00.000Z'},
#   {'priceUsd': '29809.0678067372593164',
#    'time': 1697846400000,
#    'date': '2023-10-21T00:00:00.000Z'},
#   {'priceUsd': '29932.5120323615626651',
#    'time': 1697932800000,
#    'date': '2023-10-22T00:00:00.000Z'},
#   {'priceUsd': '30903.0017370652849999',
#    'time': 1698019200000,
#    'date': '2023-10-23T00:00:00.000Z'},
#   {'priceUsd': '34091.9383246364581846',
#    'time': 1698105600000,
#    'date': '2023-10-24T00:00:00.000Z'},
#   {'priceUsd': '34343.0471117549479106',
#    'time': 1698192000000,
#    'date': '2023-10-25T00:00:00.000Z'},
#   {'priceUsd': '34350.9392214659616005',
#    'time': 1698278400000,
#    'date': '2023-10-26T00:00:00.000Z'},
#   {'priceUsd': '33985.1472264457187908',
#    'time': 1698364800000,
#    'date': '2023-10-27T00:00:00.000Z'},
#   {'priceUsd': '34123.2722850980651721',
#    'time': 1698451200000,
#    'date': '2023-10-28T00:00:00.000Z'},
#   {'priceUsd': '34354.8022947671993728',
#    'time': 1698537600000,
#    'date': '2023-10-29T00:00:00.000Z'},
#   {'priceUsd': '34471.3275246322109777',
#    'time': 1698624000000,
#    'date': '2023-10-30T00:00:00.000Z'},
#   {'priceUsd': '34413.3070554705949182',
#    'time': 1698710400000,
#    'date': '2023-10-31T00:00:00.000Z'},
#   {'priceUsd': '34607.0677355180851426',
#    'time': 1698796800000,
#    'date': '2023-11-01T00:00:00.000Z'},
#   {'priceUsd': '35177.3832458012234328',
#    'time': 1698883200000,
#    'date': '2023-11-02T00:00:00.000Z'},
#   {'priceUsd': '34563.5532465571055289',
#    'time': 1698969600000,
#    'date': '2023-11-03T00:00:00.000Z'},
#   {'priceUsd': '34826.4546374635572579',
#    'time': 1699056000000,
#    'date': '2023-11-04T00:00:00.000Z'},
#   {'priceUsd': '35110.8217103843360742',
#    'time': 1699142400000,
#    'date': '2023-11-05T00:00:00.000Z'},
#   {'priceUsd': '35040.0742017895141288',
#    'time': 1699228800000,
#    'date': '2023-11-06T00:00:00.000Z'},
#   {'priceUsd': '34994.8558604560943283',
#    'time': 1699315200000,
#    'date': '2023-11-07T00:00:00.000Z'},
#   {'priceUsd': '35415.1134040432485539',
#    'time': 1699401600000,
#    'date': '2023-11-08T00:00:00.000Z'},
#   {'priceUsd': '36619.7969979913497339',
#    'time': 1699488000000,
#    'date': '2023-11-09T00:00:00.000Z'},
#   {'priceUsd': '36956.0655929144745678',
#    'time': 1699574400000,
#    'date': '2023-11-10T00:00:00.000Z'},
#   {'priceUsd': '37121.5786948729279853',
#    'time': 1699660800000,
#    'date': '2023-11-11T00:00:00.000Z'},
#   {'priceUsd': '37125.9240158940541215',
#    'time': 1699747200000,
#    'date': '2023-11-12T00:00:00.000Z'},
#   {'priceUsd': '36908.2864224197280018',
#    'time': 1699833600000,
#    'date': '2023-11-13T00:00:00.000Z'},
#   {'priceUsd': '36251.0097195252428471',
#    'time': 1699920000000,
#    'date': '2023-11-14T00:00:00.000Z'},
#   {'priceUsd': '36287.7956709925924620',
#    'time': 1700006400000,
#    'date': '2023-11-15T00:00:00.000Z'},
#   {'priceUsd': '36969.4808619708601625',
#    'time': 1700092800000,
#    'date': '2023-11-16T00:00:00.000Z'},
#   {'priceUsd': '36391.5984300551089224',
#    'time': 1700179200000,
#    'date': '2023-11-17T00:00:00.000Z'},
#   {'priceUsd': '36557.9607721388641034',
#    'time': 1700265600000,
#    'date': '2023-11-18T00:00:00.000Z'},
#   {'priceUsd': '36725.4416297342921940',
#    'time': 1700352000000,
#    'date': '2023-11-19T00:00:00.000Z'},
#   {'priceUsd': '37331.2831703552880339',
#    'time': 1700438400000,
#    'date': '2023-11-20T00:00:00.000Z'},
#   {'priceUsd': '37167.2648266813555410',
#    'time': 1700524800000,
#    'date': '2023-11-21T00:00:00.000Z'},
#   {'priceUsd': '36682.4888928504973248',
#    'time': 1700611200000,
#    'date': '2023-11-22T00:00:00.000Z'},
#   {'priceUsd': '37337.9933862211805353',
#    'time': 1700697600000,
#    'date': '2023-11-23T00:00:00.000Z'},
#   {'priceUsd': '37666.1628469066091762',
#    'time': 1700784000000,
#    'date': '2023-11-24T00:00:00.000Z'},
#   {'priceUsd': '37789.3701996484272278',
#    'time': 1700870400000,
#    'date': '2023-11-25T00:00:00.000Z'},
#   {'priceUsd': '37630.6275401392342547',
#    'time': 1700956800000,
#    'date': '2023-11-26T00:00:00.000Z'},
#   {'priceUsd': '37189.3250453775848872',
#    'time': 1701043200000,
#    'date': '2023-11-27T00:00:00.000Z'},
#   {'priceUsd': '37460.9035926164658388',
#    'time': 1701129600000,
#    'date': '2023-11-28T00:00:00.000Z'},
#   {'priceUsd': '37969.4409805100882553',
#    'time': 1701216000000,
#    'date': '2023-11-29T00:00:00.000Z'},
#   {'priceUsd': '37802.6628264019303419',
#    'time': 1701302400000,
#    'date': '2023-11-30T00:00:00.000Z'},
#   {'priceUsd': '38421.5898069308691141',
#    'time': 1701388800000,
#    'date': '2023-12-01T00:00:00.000Z'},
#   {'priceUsd': '38922.4031717420200894',
#    'time': 1701475200000,
#    'date': '2023-12-02T00:00:00.000Z'},
#   {'priceUsd': '39555.5380539894593364',
#    'time': 1701561600000,
#    'date': '2023-12-03T00:00:00.000Z'},
#   {'priceUsd': '41426.6137148647091060',
#    'time': 1701648000000,
#    'date': '2023-12-04T00:00:00.000Z'},
#   {'priceUsd': '42395.4455517196840090',
#    'time': 1701734400000,
#    'date': '2023-12-05T00:00:00.000Z'},
#   {'priceUsd': '43890.2960798644536200',
#    'time': 1701820800000,
#    'date': '2023-12-06T00:00:00.000Z'},
#   {'priceUsd': '43576.4224068905565264',
#    'time': 1701907200000,
#    'date': '2023-12-07T00:00:00.000Z'},
#   {'priceUsd': '43676.2340255806035068',
#    'time': 1701993600000,
#    'date': '2023-12-08T00:00:00.000Z'},
#   {'priceUsd': '44063.2224793669540796',
#    'time': 1702080000000,
#    'date': '2023-12-09T00:00:00.000Z'},
#   {'priceUsd': '43867.3353692102375040',
#    'time': 1702166400000,
#    'date': '2023-12-10T00:00:00.000Z'},
#   {'priceUsd': '41962.5124907982164251',
#    'time': 1702252800000,
#    'date': '2023-12-11T00:00:00.000Z'},
#   {'priceUsd': '41553.5497718130035325',
#    'time': 1702339200000,
#    'date': '2023-12-12T00:00:00.000Z'},
#   {'priceUsd': '41635.0049092946691479',
#    'time': 1702425600000,
#    'date': '2023-12-13T00:00:00.000Z'},
#   {'priceUsd': '42880.0736868400962232',
#    'time': 1702512000000,
#    'date': '2023-12-14T00:00:00.000Z'},
#   {'priceUsd': '42506.9600720255274322',
#    'time': 1702598400000,
#    'date': '2023-12-15T00:00:00.000Z'},
#   {'priceUsd': '42324.9262740399445725',
#    'time': 1702684800000,
#    'date': '2023-12-16T00:00:00.000Z'},
#   {'priceUsd': '41986.7967739139916574',
#    'time': 1702771200000,
#    'date': '2023-12-17T00:00:00.000Z'},
#   {'priceUsd': '41423.4686975751589499',
#    'time': 1702857600000,
#    'date': '2023-12-18T00:00:00.000Z'},
#   {'priceUsd': '42723.5946056835346422',
#    'time': 1702944000000,
#    'date': '2023-12-19T00:00:00.000Z'},
#   {'priceUsd': '43187.1925776292592223',
#    'time': 1703030400000,
#    'date': '2023-12-20T00:00:00.000Z'},
#   {'priceUsd': '43746.6020074329801401',
#    'time': 1703116800000,
#    'date': '2023-12-21T00:00:00.000Z'},
#   {'priceUsd': '43835.8718142425035133',
#    'time': 1703203200000,
#    'date': '2023-12-22T00:00:00.000Z'},
#   {'priceUsd': '43745.3766619516230749',
#    'time': 1703289600000,
#    'date': '2023-12-23T00:00:00.000Z'},
#   {'priceUsd': '43694.1889016889053210',
#    'time': 1703376000000,
#    'date': '2023-12-24T00:00:00.000Z'},
#   {'priceUsd': '43390.6881361074810484',
#    'time': 1703462400000,
#    'date': '2023-12-25T00:00:00.000Z'},
#   {'priceUsd': '42756.7684054338627830',
#    'time': 1703548800000,
#    'date': '2023-12-26T00:00:00.000Z'},
#   {'priceUsd': '42872.3273377344803037',
#    'time': 1703635200000,
#    'date': '2023-12-27T00:00:00.000Z'},
#   {'priceUsd': '42975.6724065153042318',
#    'time': 1703721600000,
#    'date': '2023-12-28T00:00:00.000Z'},
#   {'priceUsd': '42476.7388521388294522',
#    'time': 1703808000000,
#    'date': '2023-12-29T00:00:00.000Z'},
#   {'priceUsd': '42186.1645540081704579',
#    'time': 1703894400000,
#    'date': '2023-12-30T00:00:00.000Z'},
#   {'priceUsd': '42508.9987225886389493',
#    'time': 1703980800000,
#    'date': '2023-12-31T00:00:00.000Z'},
#   {'priceUsd': '42882.0241324512749539',
#    'time': 1704067200000,
#    'date': '2024-01-01T00:00:00.000Z'},
#   {'priceUsd': '45295.3793761098254187',
#    'time': 1704153600000,
#    'date': '2024-01-02T00:00:00.000Z'},
#   {'priceUsd': '43982.9758403569529833',
#    'time': 1704240000000,
#    'date': '2024-01-03T00:00:00.000Z'},
#   {'priceUsd': '43541.2853649349322795',
#    'time': 1704326400000,
#    'date': '2024-01-04T00:00:00.000Z'},
#   {'priceUsd': '43824.2328353415807355',
#    'time': 1704412800000,
#    'date': '2024-01-05T00:00:00.000Z'},
#   {'priceUsd': '43904.4209083737294678',
#    'time': 1704499200000,
#    'date': '2024-01-06T00:00:00.000Z'},
#   {'priceUsd': '44154.0207689800633058',
#    'time': 1704585600000,
#    'date': '2024-01-07T00:00:00.000Z'},
#   {'priceUsd': '44899.6724598853065677',
#    'time': 1704672000000,
#    'date': '2024-01-08T00:00:00.000Z'},
#   {'priceUsd': '46672.6044466241583809',
#    'time': 1704758400000,
#    'date': '2024-01-09T00:00:00.000Z'},
#   {'priceUsd': '45846.9768982283541765',
#    'time': 1704844800000,
#    'date': '2024-01-10T00:00:00.000Z'},
#   {'priceUsd': '46600.2520088552543371',
#    'time': 1704931200000,
#    'date': '2024-01-11T00:00:00.000Z'},
#   {'priceUsd': '45135.5907655611770882',
#    'time': 1705017600000,
#    'date': '2024-01-12T00:00:00.000Z'},
#   {'priceUsd': '42920.9744150825963876',
#    'time': 1705104000000,
#    'date': '2024-01-13T00:00:00.000Z'},
#   {'priceUsd': '42835.4641168239972576',
#    'time': 1705190400000,
#    'date': '2024-01-14T00:00:00.000Z'},
#   {'priceUsd': '42642.9773182746929694',
#    'time': 1705276800000,
#    'date': '2024-01-15T00:00:00.000Z'},
#   {'priceUsd': '42954.1577420245380403',
#    'time': 1705363200000,
#    'date': '2024-01-16T00:00:00.000Z'},
#   {'priceUsd': '42734.1413839470980566',
#    'time': 1705449600000,
#    'date': '2024-01-17T00:00:00.000Z'},
#   {'priceUsd': '42249.7689493455336525',
#    'time': 1705536000000,
#    'date': '2024-01-18T00:00:00.000Z'},
#   {'priceUsd': '41292.9456464617577848',
#    'time': 1705622400000,
#    'date': '2024-01-19T00:00:00.000Z'},
#   {'priceUsd': '41644.2092420286040112',
#    'time': 1705708800000,
#    'date': '2024-01-20T00:00:00.000Z'},
#   {'priceUsd': '41752.7036163357142977',
#    'time': 1705795200000,
#    'date': '2024-01-21T00:00:00.000Z'},
#   {'priceUsd': '40750.5511169927535262',
#    'time': 1705881600000,
#    'date': '2024-01-22T00:00:00.000Z'},
#   {'priceUsd': '39426.2888797589715741',
#    'time': 1705968000000,
#    'date': '2024-01-23T00:00:00.000Z'},
#   {'priceUsd': '39923.0779032058142342',
#    'time': 1706054400000,
#    'date': '2024-01-24T00:00:00.000Z'},
#   {'priceUsd': '39959.2251889117165198',
#    'time': 1706140800000,
#    'date': '2024-01-25T00:00:00.000Z'},
#   {'priceUsd': '40944.0230367632647221',
#    'time': 1706227200000,
#    'date': '2024-01-26T00:00:00.000Z'},
#   {'priceUsd': '41869.6434722358804698',
#    'time': 1706313600000,
#    'date': '2024-01-27T00:00:00.000Z'},
#   {'priceUsd': '42308.2263356055494046',
#    'time': 1706400000000,
#    'date': '2024-01-28T00:00:00.000Z'},
#   {'priceUsd': '42501.1352717502097791',
#    'time': 1706486400000,
#    'date': '2024-01-29T00:00:00.000Z'},
#   {'priceUsd': '43433.5539051986146210',
#    'time': 1706572800000,
#    'date': '2024-01-30T00:00:00.000Z'},
#   {'priceUsd': '42929.7497513612171043',
#    'time': 1706659200000,
#    'date': '2024-01-31T00:00:00.000Z'},
#   {'priceUsd': '42449.5061455846631616',
#    'time': 1706745600000,
#    'date': '2024-02-01T00:00:00.000Z'},
#   {'priceUsd': '43068.4165562140582646',
#    'time': 1706832000000,
#    'date': '2024-02-02T00:00:00.000Z'},
#   {'priceUsd': '43119.7728950375307723',
#    'time': 1706918400000,
#    'date': '2024-02-03T00:00:00.000Z'},
#   {'priceUsd': '42921.8981910496239967',
#    'time': 1707004800000,
#    'date': '2024-02-04T00:00:00.000Z'},
#   {'priceUsd': '42777.9715955795554565',
#    'time': 1707091200000,
#    'date': '2024-02-05T00:00:00.000Z'},
#   {'priceUsd': '42945.8170917554553896',
#    'time': 1707177600000,
#    'date': '2024-02-06T00:00:00.000Z'},
#   {'priceUsd': '43269.3646238641213654',
#    'time': 1707264000000,
#    'date': '2024-02-07T00:00:00.000Z'},
#   {'priceUsd': '44888.8894571515165287',
#    'time': 1707350400000,
#    'date': '2024-02-08T00:00:00.000Z'},
#   {'priceUsd': '46754.9475959414135485',
#    'time': 1707436800000,
#    'date': '2024-02-09T00:00:00.000Z'},
#   {'priceUsd': '47333.9040742004549034',
#    'time': 1707523200000,
#    'date': '2024-02-10T00:00:00.000Z'},
#   {'priceUsd': '48113.8617533797252148',
#    'time': 1707609600000,
#    'date': '2024-02-11T00:00:00.000Z'},
#   {'priceUsd': '48749.6733912588612728',
#    'time': 1707696000000,
#    'date': '2024-02-12T00:00:00.000Z'},
#   {'priceUsd': '49622.3707852790009105',
#    'time': 1707782400000,
#    'date': '2024-02-13T00:00:00.000Z'},
#   {'priceUsd': '50836.5301554886981502',
#    'time': 1707868800000,
#    'date': '2024-02-14T00:00:00.000Z'},
#   {'priceUsd': '52093.3543734658352799',
#    'time': 1707955200000,
#    'date': '2024-02-15T00:00:00.000Z'},
#   {'priceUsd': '52056.7618527630734521',
#    'time': 1708041600000,
#    'date': '2024-02-16T00:00:00.000Z'},
#   {'priceUsd': '51666.6504492246211445',
#    'time': 1708128000000,
#    'date': '2024-02-17T00:00:00.000Z'},
#   {'priceUsd': '51783.7491439705363238',
#    'time': 1708214400000,
#    'date': '2024-02-18T00:00:00.000Z'},
#   {'priceUsd': '52150.0206145320602345',
#    'time': 1708300800000,
#    'date': '2024-02-19T00:00:00.000Z'},
#   {'priceUsd': '51895.2167137575213125',
#    'time': 1708387200000,
#    'date': '2024-02-20T00:00:00.000Z'},
#   {'priceUsd': '51502.8886060567538861',
#    'time': 1708473600000,
#    'date': '2024-02-21T00:00:00.000Z'},
#   {'priceUsd': '51599.6970311376692613',
#    'time': 1708560000000,
#    'date': '2024-02-22T00:00:00.000Z'},
#   {'priceUsd': '51116.4874678234782071',
#    'time': 1708646400000,
#    'date': '2024-02-23T00:00:00.000Z'},
#   {'priceUsd': '51214.1260407364692910',
#    'time': 1708732800000,
#    'date': '2024-02-24T00:00:00.000Z'},
#   {'priceUsd': '51698.2389156709794566',
#    'time': 1708819200000,
#    'date': '2024-02-25T00:00:00.000Z'},
#   {'priceUsd': '52328.3731366862078182',
#    'time': 1708905600000,
#    'date': '2024-02-26T00:00:00.000Z'},
#   {'priceUsd': '56480.0340965222265921',
#    'time': 1708992000000,
#    'date': '2024-02-27T00:00:00.000Z'},
#   {'priceUsd': '59281.7558798187187953',
#    'time': 1709078400000,
#    'date': '2024-02-28T00:00:00.000Z'},
#   {'priceUsd': '62076.9613099177974190',
#    'time': 1709164800000,
#    'date': '2024-02-29T00:00:00.000Z'},
#   {'priceUsd': '61884.4000339159686509',
#    'time': 1709251200000,
#    'date': '2024-03-01T00:00:00.000Z'},
#   {'priceUsd': '62041.6146065690709492',
#    'time': 1709337600000,
#    'date': '2024-03-02T00:00:00.000Z'},
#   {'priceUsd': '62254.4847193408764953',
#    'time': 1709424000000,
#    'date': '2024-03-03T00:00:00.000Z'},
#   {'priceUsd': '65368.1463978254245408',
#    'time': 1709510400000,
#    'date': '2024-03-04T00:00:00.000Z'},
#   {'priceUsd': '66243.3714587520513205',
#    'time': 1709596800000,
#    'date': '2024-03-05T00:00:00.000Z'},
#   {'priceUsd': '65975.3265830731290141',
#    'time': 1709683200000,
#    'date': '2024-03-06T00:00:00.000Z'},
#   {'priceUsd': '66864.7265443507504318',
#    'time': 1709769600000,
#    'date': '2024-03-07T00:00:00.000Z'},
#   {'priceUsd': '67809.1300030730139082',
#    'time': 1709856000000,
#    'date': '2024-03-08T00:00:00.000Z'},
#   {'priceUsd': '68444.1201726538698843',
#    'time': 1709942400000,
#    'date': '2024-03-09T00:00:00.000Z'},
#   {'priceUsd': '69421.2795983134664003',
#    'time': 1710028800000,
#    'date': '2024-03-10T00:00:00.000Z'},
#   {'priceUsd': '70994.0820868836153086',
#    'time': 1710115200000,
#    'date': '2024-03-11T00:00:00.000Z'},
#   {'priceUsd': '71694.1344201773214719',
#    'time': 1710201600000,
#    'date': '2024-03-12T00:00:00.000Z'},
#   {'priceUsd': '72745.5004089688029287',
#    'time': 1710288000000,
#    'date': '2024-03-13T00:00:00.000Z'},
#   {'priceUsd': '72217.4510414771524697',
#    'time': 1710374400000,
#    'date': '2024-03-14T00:00:00.000Z'},
#   {'priceUsd': '68636.7353587442880852',
#    'time': 1710460800000,
#    'date': '2024-03-15T00:00:00.000Z'},
#   {'priceUsd': '68280.1394510307842304',
#    'time': 1710547200000,
#    'date': '2024-03-16T00:00:00.000Z'},
#   {'priceUsd': '67075.3668427080323642',
#    'time': 1710633600000,
#    'date': '2024-03-17T00:00:00.000Z'},
#   {'priceUsd': '67803.7699030507299503',
#    'time': 1710720000000,
#    'date': '2024-03-18T00:00:00.000Z'},
#   {'priceUsd': '64392.5597340121776520',
#    'time': 1710806400000,
#    'date': '2024-03-19T00:00:00.000Z'},
#   {'priceUsd': '63887.7759899047468910',
#    'time': 1710892800000,
#    'date': '2024-03-20T00:00:00.000Z'},
#   {'priceUsd': '66707.0217079743811348',
#    'time': 1710979200000,
#    'date': '2024-03-21T00:00:00.000Z'},
#   {'priceUsd': '64714.6953358887556760',
#    'time': 1711065600000,
#    'date': '2024-03-22T00:00:00.000Z'},
#   {'priceUsd': '64691.9331450614895371',
#    'time': 1711152000000,
#    'date': '2024-03-23T00:00:00.000Z'},
#   {'priceUsd': '65329.9376779046429836',
#    'time': 1711238400000,
#    'date': '2024-03-24T00:00:00.000Z'},
#   {'priceUsd': '68340.5154047072738535',
#    'time': 1711324800000,
#    'date': '2024-03-25T00:00:00.000Z'},
#   {'priceUsd': '70338.8914341490255375',
#    'time': 1711411200000,
#    'date': '2024-03-26T00:00:00.000Z'},
#   {'priceUsd': '69775.6294174263544807',
#    'time': 1711497600000,
#    'date': '2024-03-27T00:00:00.000Z'},
#   {'priceUsd': '70407.2566875819605764',
#    'time': 1711584000000,
#    'date': '2024-03-28T00:00:00.000Z'}],
#  'timestamp': 1711723089316}

# %% [markdown]
# According with the [API's documentation](https://docs.coincap.io/), this is what each column mean:
#
# | Key       | Description                                                      |
# |-----------|------------------------------------------------------------------|
# | priceUsd  | Volume-weighted price based on real-time market data, translated to USD |
# | time      | Timestamp in UNIX in milliseconds                                |

# %% [markdown]
# ## Get real-time data fiat currency

# %%
def getCryptoCurrencyDataRates(asset: str = ""):
  try:
    res = requests.get(API_URL + f'/rates/{asset}')
    print(res)
    if res.status_code == 200:
      return res.json()
    else:
      print(f'Error: {res.status_code}')
  except requests.exceptions.RequestException as err:
    print(f'Error: {err}')

# %%
getCryptoCurrencyDataRates(asset='russian-ruble')
# Out:
# <Response [200]>
# {'data': {'id': 'russian-ruble',
#   'symbol': 'RUB',
#   'currencySymbol': '₽',
#   'type': 'fiat',
#   'rateUsd': '0.0107999999524800'},
#  'timestamp': 1711723250932}

# %%
getCryptoCurrencyDataRates()
# Out:
# <Response [200]>
# {'data': [{'id': 'libyan-dinar',
#    'symbol': 'LYD',
#    'currencySymbol': 'LD',
#    'type': 'fiat',
#    'rateUsd': '0.2066966831589950'},
#   {'id': 'comorian-franc',
#    'symbol': 'KMF',
#    'currencySymbol': None,
#    'type': 'fiat',
#    'rateUsd': '0.0021975617797137'},
#   {'id': 'ethiopian-birr',
#    'symbol': 'ETB',
#    'currencySymbol': 'Br',
#    'type': 'fiat',
#    'rateUsd': '0.0175971032352538'},
#   {'id': 'chinese-yuan-renminbi',
#    'symbol': 'CNY',
#    'currencySymbol': '¥',
#    'type': 'fiat',
#    'rateUsd': '0.1385079919111333'},
#   {'id': 'special-drawing-rights',
#    'symbol': 'XDR',
#    'currencySymbol': None,
#    'type': 'fiat',
#    'rateUsd': '1.3239439230311962'},
#   {'id': 'saudi-riyal',
#    'symbol': 'SAR',
#    'currencySymbol': '﷼',
#    'type': 'fiat',
#    'rateUsd': '0.2663911826649668'},
#   {'id': 'singapore-dollar',
#    'symbol': 'SGD',
#    'currencySymbol': '$',
#    'type': 'fiat',
#    'rateUsd': '0.7419096606282639'},
#   {'id': 'norwegian-krone',
#    'symbol': 'NOK',
#    'currencySymbol': 'kr',
#    'type': 'fiat',
#    'rateUsd': '0.0923259160231166'},
#   {'id': 'bosnia-herzegovina-convertible-mark',
#    'symbol': 'BAM',
#    'currencySymbol': 'KM',
#    'type': 'fiat',
#    'rateUsd': '0.5515646786804808'},
#   {'id': 'thai-baht',
#    'symbol': 'THB',
#    'currencySymbol': '฿',
#    'type': 'fiat',
#    'rateUsd': '0.0275330396475771'},
#   {'id': 'jordanian-dinar',
#    'symbol': 'JOD',
#    'currencySymbol': None,
#    'type': 'fiat',
#    'rateUsd': '1.4106361969248131'},
#   {'id': 'bhutanese-ngultrum',
#    'symbol': 'BTN',
#    'currencySymbol': None,
#    'type': 'fiat',
#    'rateUsd': '0.0119979406254793'},
#   {'id': 'armenian-dram',
#    'symbol': 'AMD',
#    'currencySymbol': '֏',
#    'type': 'fiat',
#    'rateUsd': '0.0025354881371964'},
#   {'id': 'burundian-franc',
#    'symbol': 'BIF',
#    'currencySymbol': None,
#    'type': 'fiat',
#    'rateUsd': '0.0003492910622687'},
#   {'id': 'thorchain',
#    'symbol': 'RUNE',
#    'currencySymbol': None,
#    'type': 'crypto',
#    'rateUsd': '9.0557442969214330'},
#   {'id': 'seychellois-rupee',
#    'symbol': 'SCR',
#    'currencySymbol': '₨',
#    'type': 'fiat',
#    'rateUsd': '0.0739116709706665'},
#   {'id': 'pakistani-rupee',
#    'symbol': 'PKR',
#    'currencySymbol': '₨',
#    'type': 'fiat',
#    'rateUsd': '0.0035978552422156'},
#   {'id': 'multi-collateral-dai',
#    'symbol': 'DAI',
#    'currencySymbol': None,
#    'type': 'crypto',
#    'rateUsd': '1.0004881641524883'},
#   {'id': 'guinean-franc',
#    'symbol': 'GNF',
#    'currencySymbol': None,
#    'type': 'fiat',
#    'rateUsd': '0.0001163469675172'},
#   {'id': 'croatian-kuna',
#    'symbol': 'HRK',
#    'currencySymbol': 'kn',
#    'type': 'fiat',
#    'rateUsd': '0.1433109677460037'},
#   {'id': 'são-tomé-and-príncipe-dobra',
#    'symbol': 'STN',
#    'currencySymbol': None,
#    'type': 'fiat',
#    'rateUsd': '0.0440306114900875'},
#   {'id': 'zcash',
#    'symbol': 'ZEC',
#    'currencySymbol': None,
#    'type': 'crypto',
#    'rateUsd': '31.1020943062236090'},
#   {'id': 'russian-ruble',
#    'symbol': 'RUB',
#    'currencySymbol': '₽',
#    'type': 'fiat',
#    'rateUsd': '0.0107999999524800'},
#   {'id': 'euro',
#    'symbol': 'EUR',
#    'currencySymbol': '€',
#    'type': 'fiat',
#    'rateUsd': '1.0798751232407484'},
#   {'id': 'djiboutian-franc',
#    'symbol': 'DJF',
#    'currencySymbol': '$',
#    'type': 'fiat',
#    'rateUsd': '0.0056158568164972'},
#   {'id': 'kyrgystani-som',
#    'symbol': 'KGS',
#    'currencySymbol': 'лв',
#    'type': 'fiat',
#    'rateUsd': '0.0111768308766659'},
#   {'id': 'icelandic-króna',
#    'symbol': 'ISK',
#    'currencySymbol': 'kr',
#    'type': 'fiat',
#    'rateUsd': '0.0071849403649950'},
#   {'id': 'hong-kong-dollar',
#    'symbol': 'HKD',
#    'currencySymbol': '$',
#    'type': 'fiat',
#    'rateUsd': '0.1277783811756889'},
#   {'id': 'sri-lankan-rupee',
#    'symbol': 'LKR',
#    'currencySymbol': '₨',
#    'type': 'fiat',
#    'rateUsd': '0.0033284271872803'},
#   {'id': 'swiss-franc',
#    'symbol': 'CHF',
#    'currencySymbol': 'CHF',
#    'type': 'fiat',
#    'rateUsd': '1.1091393078970720'},
#   {'id': 'costa-rican-colón',
#    'symbol': 'CRC',
#    'currencySymbol': '₡',
#    'type': 'fiat',
#    'rateUsd': '0.0019881141984327'},
#   {'id': 'mongolian-tugrik',
#    'symbol': 'MNT',
#    'currencySymbol': '₮',
#    'type': 'fiat',
#    'rateUsd': '0.0002898550724638'},
#   {'id': 'tajikistani-somoni',
#    'symbol': 'TJS',
#    'currencySymbol': None,
#    'type': 'fiat',
#    'rateUsd': '0.0914094245493355'},
#   {'id': 'netherlands-antillean-guilder',
#    'symbol': 'ANG',
#    'currencySymbol': 'ƒ',
#    'type': 'fiat',
#    'rateUsd': '0.5548841457392111'},
#   {'id': 'persistence',
#    'symbol': 'XPRT',
#    'currencySymbol': None,
#    'type': 'crypto',
#    'rateUsd': '0.3735746100208221'},
#   {'id': 'turkish-lira',
#    'symbol': 'TRY',
#    'currencySymbol': 'Kr',
#    'type': 'fiat',
#    'rateUsd': '0.0308788745267812'},
#   {'id': 'cfp-franc',
#    'symbol': 'XPF',
#    'currencySymbol': None,
#    'type': 'fiat',
#    'rateUsd': '0.0090493524898714'},
#   {'id': 'algerian-dinar',
#    'symbol': 'DZD',
#    'currencySymbol': None,
#    'type': 'fiat',
#    'rateUsd': '0.0074176713216337'},
#   {'id': 'somali-shilling',
#    'symbol': 'SOS',
#    'currencySymbol': 'S',
#    'type': 'fiat',
#    'rateUsd': '0.0017499612952311'},
#   {'id': 'ethereum',
#    'symbol': 'ETH',
#    'currencySymbol': None,
#    'type': 'crypto',
#    'rateUsd': '3553.7194061011263835'},
#   {'id': 'zambian-kwacha',
#    'symbol': 'ZMW',
#    'currencySymbol': 'ZK',
#    'type': 'fiat',
#    'rateUsd': '0.0399477866449436'},
#   {'id': 'philippine-peso',
#    'symbol': 'PHP',
#    'currencySymbol': '₱',
#    'type': 'fiat',
#    'rateUsd': '0.0178157844679176'},
#   {'id': 'cayman-islands-dollar',
#    'symbol': 'KYD',
#    'currencySymbol': '$',
#    'type': 'fiat',
#    'rateUsd': '1.1999443225834320'},
#   {'id': 'papua-new-guinean-kina',
#    'symbol': 'PGK',
#    'currencySymbol': 'K',
#    'type': 'fiat',
#    'rateUsd': '0.2613251116968859'},
#   {'id': 'uzbekistan-som',
#    'symbol': 'UZS',
#    'currencySymbol': 'лв',
#    'type': 'fiat',
#    'rateUsd': '0.0000791931088643'},
#   {'id': 'ugandan-shilling',
#    'symbol': 'UGX',
#    'currencySymbol': 'UGX',
#    'type': 'fiat',
#    'rateUsd': '0.0002572115356359'},
#   {'id': 'chilean-unit-of-account-(uf)',
#    'symbol': 'CLF',
#    'currencySymbol': None,
#    'type': 'fiat',
#    'rateUsd': '28.0685996575630840'},
#   {'id': 'bulgarian-lev',
#    'symbol': 'BGN',
#    'currencySymbol': 'лв',
#    'type': 'fiat',
#    'rateUsd': '0.5531530275724659'},
#   {'id': 'rwandan-franc',
#    'symbol': 'RWF',
#    'currencySymbol': None,
#    'type': 'fiat',
#    'rateUsd': '0.0007776473372871'},
#   {'id': 'mauritian-rupee',
#    'symbol': 'MUR',
#    'currencySymbol': '₨',
#    'type': 'fiat',
#    'rateUsd': '0.0215377993008357'},
#   {'id': 'barbadian-dollar',
#    'symbol': 'BBD',
#    'currencySymbol': '$',
#    'type': 'fiat',
#    'rateUsd': '0.5000000000000000'},
#   {'id': 'jersey-pound',
#    'symbol': 'JEP',
#    'currencySymbol': '£',
#    'type': 'fiat',
#    'rateUsd': '1.2644846719168070'},
#   {'id': 'samoan-tala',
#    'symbol': 'WST',
#    'currencySymbol': '$',
#    'type': 'fiat',
#    'rateUsd': '0.3571428571428572'},
#   {'id': 'kenyan-shilling',
#    'symbol': 'KES',
#    'currencySymbol': 'KSh',
#    'type': 'fiat',
#    'rateUsd': '0.0075471698113208'},
#   {'id': 'colombian-peso',
#    'symbol': 'COP',
#    'currencySymbol': '$',
#    'type': 'fiat',
#    'rateUsd': '0.0002591926891306'},
#   {'id': 'japanese-yen',
#    'symbol': 'JPY',
#    'currencySymbol': '¥',
#    'type': 'fiat',
#    'rateUsd': '0.0066127069777284'},
#   {'id': 'new-taiwan-dollar',
#    'symbol': 'TWD',
#    'currencySymbol': 'NT$',
#    'type': 'fiat',
#    'rateUsd': '0.0312866640594447'},
#   {'id': 'dogecoin',
#    'symbol': 'DOGE',
#    'currencySymbol': None,
#    'type': 'crypto',
#    'rateUsd': '0.2175187251201462'},
#   {'id': 'cuban-convertible-peso',
#    'symbol': 'CUC',
#    'currencySymbol': '$',
#    'type': 'fiat',
#    'rateUsd': '1.0000000000000000'},
#   {'id': 'ghanaian-cedi',
#    'symbol': 'GHS',
#    'currencySymbol': '¢',
#    'type': 'fiat',
#    'rateUsd': '0.0754740107508200'},
#   {'id': 'moldovan-leu',
#    'symbol': 'MDL',
#    'currencySymbol': None,
#    'type': 'fiat',
#    'rateUsd': '0.0566950440480806'},
#   {'id': 'liberian-dollar',
#    'symbol': 'LRD',
#    'currencySymbol': '$',
#    'type': 'fiat',
#    'rateUsd': '0.0051880681716101'},
#   {'id': 'cfa-franc-beac',
#    'symbol': 'XAF',
#    'currencySymbol': None,
#    'type': 'fiat',
#    'rateUsd': '0.0016462588219244'},
#   {'id': 'angolan-kwanza',
#    'symbol': 'AOA',
#    'currencySymbol': 'Kz',
#    'type': 'fiat',
#    'rateUsd': '0.0011984343653451'},
#   {'id': 'peruvian-nuevo-sol',
#    'symbol': 'PEN',
#    'currencySymbol': 'S/.',
#    'type': 'fiat',
#    'rateUsd': '0.2689009828599825'},
#   {'id': 'uruguayan-peso',
#    'symbol': 'UYU',
#    'currencySymbol': '$U',
#    'type': 'fiat',
#    'rateUsd': '0.0266226562212143'},
#   {'id': 'macedonian-denar',
#    'symbol': 'MKD',
#    'currencySymbol': 'ден',
#    'type': 'fiat',
#    'rateUsd': '0.0175356037638139'},
#   {'id': 'egyptian-pound',
#    'symbol': 'EGP',
#    'currencySymbol': '£',
#    'type': 'fiat',
#    'rateUsd': '0.0210979428535212'},
#   {'id': 'afghan-afghani',
#    'symbol': 'AFN',
#    'currencySymbol': '؋ ',
#    'type': 'fiat',
#    'rateUsd': '0.0140261344193751'},
#   {'id': 'dominican-peso',
#    'symbol': 'DOP',
#    'currencySymbol': 'RD$',
#    'type': 'fiat',
#    'rateUsd': '0.0168818474778089'},
#   {'id': 'litecoin',
#    'symbol': 'LTC',
#    'currencySymbol': None,
#    'type': 'crypto',
#    'rateUsd': '105.3888095627245137'},
#   {'id': 'paraguayan-guarani',
#    'symbol': 'PYG',
#    'currencySymbol': 'Gs',
#    'type': 'fiat',
#    'rateUsd': '0.0001352492797517'},
#   {'id': 'malawian-kwacha',
#    'symbol': 'MWK',
#    'currencySymbol': 'MK',
#    'type': 'fiat',
#    'rateUsd': '0.0005769871142818'},
#   {'id': 'united-arab-emirates-dirham',
#    'symbol': 'AED',
#    'currencySymbol': 'فلس',
#    'type': 'fiat',
#    'rateUsd': '0.2723089072243553'},
#   {'id': 'maldivian-rufiyaa',
#    'symbol': 'MVR',
#    'currencySymbol': None,
#    'type': 'fiat',
#    'rateUsd': '0.0646830530401035'},
#   {'id': 'honduran-lempira',
#    'symbol': 'HNL',
#    'currencySymbol': 'L',
#    'type': 'fiat',
#    'rateUsd': '0.0405118658039584'},
#   {'id': 'iranian-rial',
#    'symbol': 'IRR',
#    'currencySymbol': '﷼',
#    'type': 'fiat',
#    'rateUsd': '0.0000237896990603'},
#   {'id': 'chinese-yuan-(offshore)',
#    'symbol': 'CNH',
#    'currencySymbol': None,
#    'type': 'fiat',
#    'rateUsd': '0.1378531712088138'},
#   {'id': 'united-states-dollar',
#    'symbol': 'USD',
#    'currencySymbol': '$',
#    'type': 'fiat',
#    'rateUsd': '1.0000000000000000'},
#   {'id': 'manx-pound',
#    'symbol': 'IMP',
#    'currencySymbol': '£',
#    'type': 'fiat',
#    'rateUsd': '1.2644846719168070'},
#   {'id': 'bitcoin',
#    'symbol': 'BTC',
#    'currencySymbol': '₿',
#    'type': 'crypto',
#    'rateUsd': '70415.3406080352363473'},
#   {'id': 'polish-zloty',
#    'symbol': 'PLN',
#    'currencySymbol': 'zł',
#    'type': 'fiat',
#    'rateUsd': '0.2512115935155254'},
#   {'id': 'qtum',
#    'symbol': 'QTUM',
#    'currencySymbol': None,
#    'type': 'crypto',
#    'rateUsd': '4.8903954122093354'},
#   {'id': 'gambian-dalasi',
#    'symbol': 'GMD',
#    'currencySymbol': None,
#    'type': 'fiat',
#    'rateUsd': '0.0147221199852779'},
#   {'id': 'saint-helena-pound',
#    'symbol': 'SHP',
#    'currencySymbol': '£',
#    'type': 'fiat',
#    'rateUsd': '1.2644846719168070'},
#   {'id': 'salvadoran-colón',
#    'symbol': 'SVC',
#    'currencySymbol': '$',
#    'type': 'fiat',
#    'rateUsd': '0.1142864718417562'},
#   {'id': 'georgian-lari',
#    'symbol': 'GEL',
#    'currencySymbol': None,
#    'type': 'fiat',
#    'rateUsd': '0.3703703703703704'},
#   {'id': 'brunei-dollar',
#    'symbol': 'BND',
#    'currencySymbol': '$',
#    'type': 'fiat',
#    'rateUsd': '0.7413579899116005'},
#   {'id': 'trinidad-and-tobago-dollar',
#    'symbol': 'TTD',
#    'currencySymbol': 'TT$',
#    'type': 'fiat',
#    'rateUsd': '0.1472093234141728'},
#   {'id': 'lebanese-pound',
#    'symbol': 'LBP',
#    'currencySymbol': '£',
#    'type': 'fiat',
#    'rateUsd': '0.0000111661024430'},
#   {'id': 'south-african-rand',
#    'symbol': 'ZAR',
#    'currencySymbol': 'R',
#    'type': 'fiat',
#    'rateUsd': '0.0529792903953844'},
#   {'id': 'mexican-peso',
#    'symbol': 'MXN',
#    'currencySymbol': '$',
#    'type': 'fiat',
#    'rateUsd': '0.0603551295824632'},
#   {'id': 'swedish-krona',
#    'symbol': 'SEK',
#    'currencySymbol': 'kr',
#    'type': 'fiat',
#    'rateUsd': '0.0936011974962803'},
#   {'id': 'tunisian-dinar',
#    'symbol': 'TND',
#    'currencySymbol': None,
#    'type': 'fiat',
#    'rateUsd': '0.3201536737634064'},
#   {'id': 'waves',
#    'symbol': 'WAVES',
#    'currencySymbol': None,
#    'type': 'crypto',
#    'rateUsd': '3.9214544187725250'},
#   {'id': 'palladium-ounce',
#    'symbol': 'XPD',
#    'currencySymbol': None,
#    'type': 'fiat',
#    'rateUsd': '1014.9708195889368000'},
#   {'id': 'platinum-ounce',
#    'symbol': 'XPT',
#    'currencySymbol': None,
#    'type': 'fiat',
#    'rateUsd': '908.6035671776048000'},
#   {'id': 'north-korean-won',
#    'symbol': 'KPW',
#    'currencySymbol': '₩',
#    'type': 'fiat',
#    'rateUsd': '0.0011111111111111'},
#   {'id': 'panamanian-balboa',
#    'symbol': 'PAB',
#    'currencySymbol': 'B/.',
#    'type': 'fiat',
#    'rateUsd': '1.0000000000000000'},
#   {'id': 'botswanan-pula',
#    'symbol': 'BWP',
#    'currencySymbol': 'P',
#    'type': 'fiat',
#    'rateUsd': '0.0727508757568546'},
#   {'id': 'sudanese-pound',
#    'symbol': 'SDG',
#    'currencySymbol': None,
#    'type': 'fiat',
#    'rateUsd': '0.0016638935108153'},
#   {'id': 'bitcoin-cash',
#    'symbol': 'BCH',
#    'currencySymbol': None,
#    'type': 'crypto',
#    'rateUsd': '618.6393966458198327'},
#   {'id': 'azerbaijani-manat',
#    'symbol': 'AZN',
#    'currencySymbol': '₼',
#    'type': 'fiat',
#    'rateUsd': '0.5882352941176471'},
#   {'id': 'solomon-islands-dollar',
#    'symbol': 'SBD',
#    'currencySymbol': '$',
#    'type': 'fiat',
#    'rateUsd': '0.1181296671554872'},
#   {'id': 'macanese-pataca',
#    'symbol': 'MOP',
#    'currencySymbol': 'MOP$',
#    'type': 'fiat',
#    'rateUsd': '0.1240727731480712'},
#   {'id': 'belarusian-ruble',
#    'symbol': 'BYN',
#    'currencySymbol': 'Br',
#    'type': 'fiat',
#    'rateUsd': '0.3055776165618179'},
#   {'id': 'vanuatu-vatu',
#    'symbol': 'VUV',
#    'currencySymbol': 'VT',
#    'type': 'fiat',
#    'rateUsd': '0.0084230386954398'},
#   {'id': 'australian-dollar',
#    'symbol': 'AUD',
#    'currencySymbol': '$',
#    'type': 'fiat',
#    'rateUsd': '0.6528599837307292'},
#   {'id': 'nicaraguan-córdoba',
#    'symbol': 'NIO',
#    'currencySymbol': 'C$',
#    'type': 'fiat',
#    'rateUsd': '0.0271725440788934'},
#   {'id': 'brazilian-real',
#    'symbol': 'BRL',
#    'currencySymbol': 'R$',
#    'type': 'fiat',
#    'rateUsd': '0.1993779408246272'},
#   {'id': 'bolivian-boliviano',
#    'symbol': 'BOB',
#    'currencySymbol': '$b',
#    'type': 'fiat',
#    'rateUsd': '0.1441986434368420'},
#   {'id': 'venezuelan-bolívar-soberano',
#    'symbol': 'VES',
#    'currencySymbol': None,
#    'type': 'fiat',
#    'rateUsd': '0.0275568567535890'},
#   {'id': 'tanzanian-shilling',
#    'symbol': 'TZS',
#    'currencySymbol': None,
#    'type': 'fiat',
#    'rateUsd': '0.0003873701825676'},
#   {'id': 'hungarian-forint',
#    'symbol': 'HUF',
#    'currencySymbol': 'Ft',
#    'type': 'fiat',
#    'rateUsd': '0.0027434842249657'},
#   {'id': 'cuban-peso',
#    'symbol': 'CUP',
#    'currencySymbol': '₱',
#    'type': 'fiat',
#    'rateUsd': '0.0388349514563107'},
#   {'id': 'cambodian-riel',
#    'symbol': 'KHR',
#    'currencySymbol': '៛',
#    'type': 'fiat',
#    'rateUsd': '0.0002473639317540'},
#   {'id': 'romanian-leu',
#    'symbol': 'RON',
#    'currencySymbol': 'lei',
#    'type': 'fiat',
#    'rateUsd': '0.2173062714589943'},
#   {'id': 'cfa-franc-bceao',
#    'symbol': 'XOF',
#    'currencySymbol': None,
#    'type': 'fiat',
#    'rateUsd': '0.0016462588219244'},
#   {'id': 'guernsey-pound',
#    'symbol': 'GGP',
#    'currencySymbol': '£',
#    'type': 'fiat',
#    'rateUsd': '1.2644846719168070'},
#   {'id': 'yemeni-rial',
#    'symbol': 'YER',
#    'currencySymbol': '﷼',
#    'type': 'fiat',
#    'rateUsd': '0.0039944084512959'},
#   {'id': 'eritrean-nakfa',
#    'symbol': 'ERN',
#    'currencySymbol': None,
#    'type': 'fiat',
#    'rateUsd': '0.0666666666666667'},
#   {'id': 'zimbabwean-dollar',
#    'symbol': 'ZWL',
#    'currencySymbol': '$',
#    'type': 'fiat',
#    'rateUsd': '0.0031055900621118'},
#   {'id': 'gold-ounce',
#    'symbol': 'XAU',
#    'currencySymbol': None,
#    'type': 'fiat',
#    'rateUsd': '2230.0024530026985000'},
#   {'id': 'namibian-dollar',
#    'symbol': 'NAD',
#    'currencySymbol': '$',
#    'type': 'fiat',
#    'rateUsd': '0.0529323124878123'},
#   {'id': 'new-zealand-dollar',
#    'symbol': 'NZD',
#    'currencySymbol': '$',
#    'type': 'fiat',
#    'rateUsd': '0.5985199797939655'},
#   {'id': 'ukrainian-hryvnia',
#    'symbol': 'UAH',
#    'currencySymbol': '₴',
#    'type': 'fiat',
#    'rateUsd': '0.0254942883616126'},
#   {'id': 'iraqi-dinar',
#    'symbol': 'IQD',
#    'currencySymbol': 'د.ع',
#    'type': 'fiat',
#    'rateUsd': '0.0007633916382654'},
#   {'id': 'nigerian-naira',
#    'symbol': 'NGN',
#    'currencySymbol': '₦',
#    'type': 'fiat',
#    'rateUsd': '0.0007166095767704'},
#   {'id': 'bahraini-dinar',
#    'symbol': 'BHD',
#    'currencySymbol': 'BD',
#    'type': 'fiat',
#    'rateUsd': '2.6493715690638180'},
#   {'id': 'chilean-peso',
#    'symbol': 'CLP',
#    'currencySymbol': '$',
#    'type': 'fiat',
#    'rateUsd': '0.0010172939979654'},
#   {'id': 'laotian-kip',
#    'symbol': 'LAK',
#    'currencySymbol': '₭',
#    'type': 'fiat',
#    'rateUsd': '0.0000473638723704'},
#   {'id': 'malagasy-ariary',
#    'symbol': 'MGA',
#    'currencySymbol': 'Ar',
#    'type': 'fiat',
#    'rateUsd': '0.0002289354832945'},
#   {'id': 'aruban-florin',
#    'symbol': 'AWG',
#    'currencySymbol': 'ƒ',
#    'type': 'fiat',
#    'rateUsd': '0.5547850208044383'},
#   {'id': 'kazakhstani-tenge',
#    'symbol': 'KZT',
#    'currencySymbol': 'лв',
#    'type': 'fiat',
#    'rateUsd': '0.0022288923559557'},
#   {'id': 'east-caribbean-dollar',
#    'symbol': 'XCD',
#    'currencySymbol': '$',
#    'type': 'fiat',
#    'rateUsd': '0.3700209061811993'},
#   {'id': 'moroccan-dirham',
#    'symbol': 'MAD',
#    'currencySymbol': None,
#    'type': 'fiat',
#    'rateUsd': '0.0990751434434696'},
#   {'id': 'serbian-dinar',
#    'symbol': 'RSD',
#    'currencySymbol': 'Дин.',
#    'type': 'fiat',
#    'rateUsd': '0.0092189663158423'},
#   {'id': 'gibraltar-pound',
#    'symbol': 'GIP',
#    'currencySymbol': '£',
#    'type': 'fiat',
#    'rateUsd': '1.2644846719168070'},
#   {'id': 'myanma-kyat',
#    'symbol': 'MMK',
#    'currencySymbol': 'K',
#    'type': 'fiat',
#    'rateUsd': '0.0004762081666436'},
#   {'id': 'south-sudanese-pound',
#    'symbol': 'SSP',
#    'currencySymbol': None,
#    'type': 'fiat',
#    'rateUsd': '0.0076769537847382'},
#   {'id': 'eos',
#    'symbol': 'EOS',
#    'currencySymbol': None,
#    'type': 'crypto',
#    'rateUsd': '1.1256168898001769'},
#   {'id': 'sentinel',
#    'symbol': 'DVPN',
#    'currencySymbol': None,
#    'type': 'crypto',
#    'rateUsd': '0.0022292308399745'},
#   {'id': 'nepalese-rupee',
#    'symbol': 'NPR',
#    'currencySymbol': '₨',
#    'type': 'fiat',
#    'rateUsd': '0.0074980347088675'},
#   {'id': 'british-pound-sterling',
#    'symbol': 'GBP',
#    'currencySymbol': '£',
#    'type': 'fiat',
#    'rateUsd': '1.2644846719168070'},
#   {'id': 'syrian-pound',
#    'symbol': 'SYP',
#    'currencySymbol': '£',
#    'type': 'fiat',
#    'rateUsd': '0.0003980051979479'},
#   {'id': 'haitian-gourde',
#    'symbol': 'HTG',
#    'currencySymbol': 'G',
#    'type': 'fiat',
#    'rateUsd': '0.0075426513362278'},
#   {'id': 'canadian-dollar',
#    'symbol': 'CAD',
#    'currencySymbol': '$',
#    'type': 'fiat',
#    'rateUsd': '0.7382988855378323'},
#   {'id': 'lesotho-loti',
#    'symbol': 'LSL',
#    'currencySymbol': None,
#    'type': 'fiat',
#    'rateUsd': '0.0529323124878123'},
#   {'id': 'dash',
#    'symbol': 'DASH',
#    'currencySymbol': None,
#    'type': 'crypto',
#    'rateUsd': '40.0538052090455470'},
#   {'id': 'argentine-peso',
#    'symbol': 'ARS',
#    'currencySymbol': '$',
#    'type': 'fiat',
#    'rateUsd': '0.0011673786873114'},
#   {'id': 'são-tomé-and-príncipe-dobra-(pre-2018)',
#    'symbol': 'STD',
#    'currencySymbol': None,
#    'type': 'fiat',
#    'rateUsd': '0.0000448796775844'},
#   {'id': 'falkland-islands-pound',
#    'symbol': 'FKP',
#    'currencySymbol': '£',
#    'type': 'fiat',
#    'rateUsd': '1.2644846719168070'},
#   {'id': 'omani-rial',
#    'symbol': 'OMR',
#    'currencySymbol': '﷼',
#    'type': 'fiat',
#    'rateUsd': '2.5949424571510127'},
#   {'id': 'israeli-new-sheqel',
#    'symbol': 'ILS',
#    'currencySymbol': '₪',
#    'type': 'fiat',
#    'rateUsd': '0.2713646766771287'},
#   {'id': 'danish-krone',
#    'symbol': 'DKK',
#    'currencySymbol': 'kr',
#    'type': 'fiat',
#    'rateUsd': '0.1447638900952546'},
#   {'id': 'crypto-com-coin',
#    'symbol': 'CRO',
#    'currencySymbol': None,
#    'type': 'crypto',
#    'rateUsd': '0.1552979315918940'},
#   {'id': 'malaysian-ringgit',
#    'symbol': 'MYR',
#    'currencySymbol': 'RM',
#    'type': 'fiat',
#    'rateUsd': '0.2116626097999788'},
#   {'id': 'bangladeshi-taka',
#    'symbol': 'BDT',
#    'currencySymbol': 'Tk',
#    'type': 'fiat',
#    'rateUsd': '0.0091118334223453'},
#   {'id': 'qatari-rial',
#    'symbol': 'QAR',
#    'currencySymbol': '﷼',
#    'type': 'fiat',
#    'rateUsd': '0.2742259424322964'},
#   {'id': 'indian-rupee',
#    'symbol': 'INR',
#    'currencySymbol': '₹',
#    'type': 'fiat',
#    'rateUsd': '0.0120028732477981'},
#   {'id': 'kuwaiti-dinar',
#    'symbol': 'KWD',
#    'currencySymbol': 'ك',
#    'type': 'fiat',
#    'rateUsd': '3.2459839064117920'},
#   {'id': 'swazi-lilangeni',
#    'symbol': 'SZL',
#    'currencySymbol': None,
#    'type': 'fiat',
#    'rateUsd': '0.0529214100126461'},
#   {'id': 'sierra-leonean-leone',
#    'symbol': 'SLL',
#    'currencySymbol': 'Le',
#    'type': 'fiat',
#    'rateUsd': '0.0000476883092110'},
#   {'id': 'guatemalan-quetzal',
#    'symbol': 'GTQ',
#    'currencySymbol': 'Q',
#    'type': 'fiat',
#    'rateUsd': '0.1282546706824059'},
#   {'id': 'czech-republic-koruna',
#    'symbol': 'CZK',
#    'currencySymbol': 'Kč',
#    'type': 'fiat',
#    'rateUsd': '0.0427322121825264'},
#   {'id': 'cape-verdean-escudo',
#    'symbol': 'CVE',
#    'currencySymbol': '$',
#    'type': 'fiat',
#    'rateUsd': '0.0097832497537263'},
#   {'id': 'congolese-franc',
#    'symbol': 'CDF',
#    'currencySymbol': None,
#    'type': 'fiat',
#    'rateUsd': '0.0003597149819060'},
#   {'id': 'south-korean-won',
#    'symbol': 'KRW',
#    'currencySymbol': None,
#    'type': 'fiat',
#    'rateUsd': '0.0007439856567779'},
#   {'id': 'surinamese-dollar',
#    'symbol': 'SRD',
#    'currencySymbol': '$',
#    'type': 'fiat',
#    'rateUsd': '0.0284050560999858'},
#   {'id': 'belize-dollar',
#    'symbol': 'BZD',
#    'currencySymbol': 'BZ$',
#    'type': 'fiat',
#    'rateUsd': '0.4961139395118041'},
#   {'id': 'tether',
#    'symbol': 'USDT',
#    'currencySymbol': None,
#    'type': 'crypto',
#    'rateUsd': '1.0007649603337186'},
#   {'id': 'binance-coin',
#    'symbol': 'BNB',
#    'currencySymbol': None,
#    'type': 'crypto',
#    'rateUsd': '619.4068664494903025'},
#   {'id': 'mozambican-metical',
#    'symbol': 'MZN',
#    'currencySymbol': 'MT',
#    'type': 'fiat',
#    'rateUsd': '0.0156494520242652'},
#   {'id': 'silver-ounce',
#    'symbol': 'XAG',
#    'currencySymbol': None,
#    'type': 'fiat',
#    'rateUsd': '24.9652421416283200'},
#   {'id': 'bermudan-dollar',
#    'symbol': 'BMD',
#    'currencySymbol': '$',
#    'type': 'fiat',
#    'rateUsd': '1.0000000000000000'},
#   {'id': 'jamaican-dollar',
#    'symbol': 'JMD',
#    'currencySymbol': 'J$',
#    'type': 'fiat',
#    'rateUsd': '0.0064973205050237'},
#   {'id': 'mauritanian-ouguiya',
#    'symbol': 'MRU',
#    'currencySymbol': None,
#    'type': 'fiat',
#    'rateUsd': '0.0252250668754360'},
#   {'id': 'turkmenistani-manat',
#    'symbol': 'TMT',
#    'currencySymbol': None,
#    'type': 'fiat',
#    'rateUsd': '0.2857142857142857'},
#   {'id': 'fijian-dollar',
#    'symbol': 'FJD',
#    'currencySymbol': '$',
#    'type': 'fiat',
#    'rateUsd': '0.4430856484558465'},
#   {'id': 'vietnamese-dong',
#    'symbol': 'VND',
#    'currencySymbol': '₫',
#    'type': 'fiat',
#    'rateUsd': '0.0000403049993802'},
#   {'id': 'indonesian-rupiah',
#    'symbol': 'IDR',
#    'currencySymbol': 'Rp',
#    'type': 'fiat',
#    'rateUsd': '0.0000630168564186'},
#   {'id': 'guyanaese-dollar',
#    'symbol': 'GYD',
#    'currencySymbol': '$',
#    'type': 'fiat',
#    'rateUsd': '0.0047766321423637'}],
#  'timestamp': 1711723089675}

# %% [markdown]
# According with the [API's documentation](https://docs.coincap.io/), this is what each column mean:
#
# | Key             | Description                                                      |
# |-----------------|------------------------------------------------------------------|
# | id              | Unique identifier for asset or fiat                              |
# | symbol          | Most common symbol used to identify asset or fiat                |
# | currencySymbol  | Currency symbol used to identify asset or fiat                   |
# | rateUsd         | Rate conversion to USD                                           |
# | type            | Type of currency - fiat or crypto                                |
